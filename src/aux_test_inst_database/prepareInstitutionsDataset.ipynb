# %%
import os
import pandas as pd
import numpy as np

# %%
# Path to the .csv files with articles' information
DF_input = input().strip()
# Out:
#  D:\Data_40_years_cancer_studies\BERT_NER_parsedXMLs_combined_until_Oct2025_base\

# %%
# Import list of csvs to parse
list_csvs = []

for file in os.listdir(DF_input):
    if file[-4:] == ".csv":
        list_csvs.append(file)

n_csvs = len(list_csvs)

# %%
list_rows = []

for csv in list_csvs:
    print(f"Parsing csv {csv}")
    df = pd.read_csv(DF_input + csv)
    df = df.loc[df["Authors"].notna()]
    df = df.iloc[:2]
    list_rows.append(df)
# Out:
# Parsing csv BERT_NER_parsedXMLs_first_pred_26400.csv
# Parsing csv BERT_NER_parsedXMLs_first_upd_100000.csv
# C:\Users\svalb\AppData\Local\Temp\ipykernel_8792\1112344367.py:5: DtypeWarning: Columns (2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(DF_input + csv)
# Parsing csv BERT_NER_parsedXMLs_first_upd_200000.csv
# C:\Users\svalb\AppData\Local\Temp\ipykernel_8792\1112344367.py:5: DtypeWarning: Columns (13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(DF_input + csv)
# Parsing csv BERT_NER_parsedXMLs_first_upd_300000.csv
# C:\Users\svalb\AppData\Local\Temp\ipykernel_8792\1112344367.py:5: DtypeWarning: Columns (13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(DF_input + csv)
# Parsing csv BERT_NER_parsedXMLs_first_upd_340800.csv
# ...

# %%
df = pd.concat(list_rows)
df = df.reset_index()[["PMID", "Authors", "NER_BERT", "Country"]]

# %%
df["Institutions_man"] = None
df["Institutions_man"] = df["Institutions_man"].astype("object")
df["Countries_man"] = None
df["Countries_man"] = df["Countries_man"].astype("object")

# %%
df
# Out:
#          PMID                                            Authors  \
# 0     6083417  [{'Name': 'R L Momparler', 'Affiliation': []},...
# 1     6083438  [{'Name': 'Y Tanaka', 'Affiliation': []}, {'Na...
# 2    20301318  [{'Name': 'Rita Barbosa-Matos', 'Affiliation':...
# 3    20301357  [{'Name': 'Sharat Chandra', 'Affiliation': ["A...
# 4    39290086  [{'Name': 'Amy M Cohn', 'Affiliation': ['Depar...
# ..        ...                                                ...
# 97    8823338  [{'Name': 'J A Sparano', 'Affiliation': ['Albe...
# 98    9556116  [{'Name': 'L Waxtein', 'Affiliation': ['Depart...
# 99    9556142  [{'Name': 'R C Pelger', 'Affiliation': ['Depar...
# 100  10524426  [{'Name': 'N E Crompton', 'Affiliation': ['Rad...
# 101  10524427  [{'Name': 'E Ben-Josef', 'Affiliation': ['Depa...
#
#                                               NER_BERT        Country  \
# 0                                                   []            NaN
# ...

# %%
df.iloc[90]["Authors"]
# Out:
# '[{\'Name\': \'Xin Miao\', \'Affiliation\': [\'Department of Hepatology, Chongqing University Three Gorges Hospital, Chongqing, China.\']}, {\'Name\': \'ChuYan Peng\', \'Affiliation\': [\'Department of Hepatology, Chongqing University Three Gorges Hospital, Chongqing, China.\']}, {\'Name\': \'Fang Yan\', \'Affiliation\': ["Center for Medicine Research and Translation, Chengdu Fifth People\'s Hospital, Chengdu, Sichuan Province, China."]}, {\'Name\': \'XiQing Guo\', \'Affiliation\': [\'Department of Hepatology, Chongqing University Three Gorges Hospital, Chongqing, China.\']}, {\'Name\': \'LiNa Xia\', \'Affiliation\': [\'Department of Hepatology, Chongqing University Three Gorges Hospital, Chongqing, China.\']}, {\'Name\': \'Qiang Song\', \'Affiliation\': [\'Department of Hepatology, Chongqing University Three Gorges Hospital, Chongqing, China.\']}, {\'Name\': \'Xuan An\', \'Affiliation\': [\'Department of Hepatology, Chongqing University Three Gorges Hospital, Chongqing, China.\']}, 
# ...

# %%
df.loc[86, ["Institutions_man", "Countries_man"]] = pd.Series([["Norwegian University of Science and Technology", "St. Olavs Hospital", "Center for Oral Health Services and Research Mid-Norway (TkMidt)", "Clinic of Medicine", "K.G. Jebsen Centre for Genetic Epidemiology"], ["Norway", "Norway", "Norway", "Norway", "Norway"]],index=["Institutions_man", "Countries_man"])
df.loc[87, ["Institutions_man", "Countries_man"]] = pd.Series([["Mayo Clinic"], ["United States"]],index=["Institutions_man", "Countries_man"])
df.loc[88, ["Institutions_man", "Countries_man"]] = pd.Series([["University of Agricultural Sciences and Veterinary Medicine of Cluj-Napoca", "Biotechnology Research Center", "Life Sciences Institute King Michael I of Romania", "Babeș-Bolyai University"], ["Romania", "Romania", "Romania", "Romania"]],index=["Institutions_man", "Countries_man"])
df.loc[89, ["Institutions_man", "Countries_man"]] = pd.Series([["Graduate Institute of Biomedical Science", "China Medical University", "Taichung Tzu Chi Hospital", "Buddhist Tzu Chi Medical Foundation", "China Medical University Hospital", "Asia University", "Institute of New Drug Development"], ["Taiwan", "Taiwan", "Taiwan", "Taiwan", "Taiwan", "Taiwan", "Taiwan"]],index=["Institutions_man", "Countries_man"])
df.loc[90, ["Institutions_man", "Countries_man"]] = pd.Series([["Chongqing University Three Gorges Hospital", "Center for Medicine Research and Translation", "Chengdu Fifth People's Hospital"], ["China", "China", "China"]],index=["Institutions_man", "Countries_man"])

#df.loc[, ["Institutions_man", "Countries_man"]] = pd.Series([[], []],index=["Institutions_man", "Countries_man"])

# %%
df.loc[0, ["Institutions_man", "Countries_man"]] = [np.nan, np.nan]
df.loc[1, ["Institutions_man", "Countries_man"]] = [np.nan, np.nan]
df.loc[2, ["Institutions_man", "Countries_man"]] = pd.Series([["Instituto de Investigação e Inovação em Saúde", "University of Porto", "University of British Columbia", "BC Cancer", "Institute of Molecular Pathology and Immunology"], ["Portugal", "Portugal", "Canada", "Canada", "Portugal"]],index=["Institutions_man", "Countries_man"])
df.loc[3, ["Institutions_man", "Countries_man"]] = pd.Series([["Cincinnati Children's Hospital Medical Center", "University of Cincinnati", "Children's Hospital Los Angeles", "USC", "Aflac Cancer and Blood Disorders Center", "Children's Healthcare of Atlanta", "Emory University", "GoBroad Healthcare Group", "GoBroad Hospital"], ["United States", "United States", "United States", "United States", "United States", "United States", "United States", "China", "China"]],index=["Institutions_man", "Countries_man"])
df.loc[4, ["Institutions_man", "Countries_man"]] = pd.Series([["University of Oklahoma Health Sciences Center", "University at Buffalo", "Battelle Memorial Institute", "University of Memphis", "Rutgers Institute for Nicotine & Tobacco Studies", "Rutgers Biomedical and Health Sciences", "University of Chicago", "TSET Health Promotion Research Center", "Stephenson Cancer Center", "University of Pennsylvania"], ["United States", "United States", "United States", "United States", "United States", "United States", "United States", "United States", "United States", "United States"]],index=["Institutions_man", "Countries_man"])
df.loc[5, ["Institutions_man", "Countries_man"]] = pd.Series([["Center for Research on Population Health", "National Institute of Public Health", "CONAHCYT", "Institute for Research in Applied Mathematics and Systems", "Universidad Nacional Autonoma de Mexico", "Center for Research on Evaluation and Surveys", "Harvard"], ["Mexico", "Mexico", "Mexico", "Mexico", "Mexico", "Mexico", "United States"]],index=["Institutions_man", "Countries_man"])
df.loc[6, ["Institutions_man", "Countries_man"]] = pd.Series([["CRCT", "Université de Toulouse", "Inserm", "CNRS", "Centre de Recherches en Cancérologie de Toulouse", "Labex TOUCAN", "Institut Universitaire du Cancer de Toulouse-Oncopole (IUCT-O)"], ["France", "France", "France", "France", "France", "France", "France"]],index=["Institutions_man", "Countries_man"])
df.loc[7, ["Institutions_man", "Countries_man"]] = pd.Series([["First Affiliated Hospital of Xinjiang Medical University"], ["China"]],index=["Institutions_man", "Countries_man"])
df.loc[8, ["Institutions_man", "Countries_man"]] = pd.Series([["Institute of Developmental Biology and Biomedical Sciences", "University of Warsaw"], ["Poland", "Poland"]],index=["Institutions_man", "Countries_man"])
df.loc[9, ["Institutions_man", "Countries_man"]] = pd.Series([["Chang Gung Memorial Hospital-Linkou", "Chang Gung University"], ["Taiwan", "Taiwan"]],index=["Institutions_man", "Countries_man"])
df.loc[10, ["Institutions_man", "Countries_man"]] = pd.Series([["Ruhr University Bochum", "BG University Hospital Bergmannsheil", "Friedrich-Baur-Institute", "Ludwig-Maximilians University", "Medical Genetics Center Munich", "University Hospital of Bonn", "Hannover Medical School", "Clinic and Policlinic for Radiation Therapy and Radiooncology", "University of Düsseldorf", "Kantonsspital St. Gallen", "University of Würzburg", "University of Bonn Medical Center", "University Medical Center Göttingen"], ["Germany", "Germany", "Germany", "Germany", "Germany", "Germany", "Germany", "Germany", "Germany", "Switzerland", "Germany", "Germany", "Germany"]],index=["Institutions_man", "Countries_man"])
df.loc[11, ["Institutions_man", "Countries_man"]] = pd.Series([["IRCCS", "Ospedale San Raffaele", "Vita-Salute San Raffaele University"], ["Italy", "Italy", "Italy"]],index=["Institutions_man", "Countries_man"])
df.loc[12, ["Institutions_man", "Countries_man"]] = pd.Series([["University of Adelaide", "Queen Elizabeth Hospital"], ["Autralia", "Autralia"]],index=["Institutions_man", "Countries_man"])
df.loc[13, ["Institutions_man", "Countries_man"]] = pd.Series([["University of Zimbabwe"], ["Zimbabwe"]],index=["Institutions_man", "Countries_man"])
df.loc[14, ["Institutions_man", "Countries_man"]] = pd.Series([["University of Tokyo Hospital"], ["Japan"]],index=["Institutions_man", "Countries_man"])
df.loc[15, ["Institutions_man", "Countries_man"]] = pd.Series([["University Hospital Centre of Grenoble"], ["France"]],index=["Institutions_man", "Countries_man"])
df.loc[16, ["Institutions_man", "Countries_man"]] = pd.Series([["Harvard"], ["United States"]],index=["Institutions_man", "Countries_man"])
df.loc[17, ["Institutions_man", "Countries_man"]] = pd.Series([["University of Washington"], ["United States"]],index=["Institutions_man", "Countries_man"])
df.loc[18, ["Institutions_man", "Countries_man"]] = pd.Series([["University of Würzburg"], ["Germany"]],index=["Institutions_man", "Countries_man"])
df.loc[19, ["Institutions_man", "Countries_man"]] = pd.Series([["Mannheim Medical Center", "University of Heidelberg"], ["Germany", "Germany"]],index=["Institutions_man", "Countries_man"])
df.loc[20, ["Institutions_man", "Countries_man"]] = [np.nan, np.nan]
df.loc[21, ["Institutions_man", "Countries_man"]] = pd.Series([["Norwegian University of Science and Technology"], ["Norway"]],index=["Institutions_man", "Countries_man"])
df.loc[22, ["Institutions_man", "Countries_man"]] = pd.Series([["Duke University Medical Center"], ["United States"]],index=["Institutions_man", "Countries_man"])
df.loc[23, ["Institutions_man", "Countries_man"]] = pd.Series([["Hewitt Centre for Reproductive Medicine", "Liverpool Women's Hospital"], ["United Kingdom", "United Kingdom"]],index=["Institutions_man", "Countries_man"])
df.loc[24, ["Institutions_man", "Countries_man"]] = pd.Series([["University of Rochester"], ["United States"]],index=["Institutions_man", "Countries_man"])
df.loc[25, ["Institutions_man", "Countries_man"]] = pd.Series([["Stavanger University Hospital"], ["Norway"]],index=["Institutions_man", "Countries_man"])
df.loc[26, ["Institutions_man", "Countries_man"]] = pd.Series([["Klinika Nowotworów Układowych i Uogólnionych Centrum Onkologii"], ["Poland"]],index=["Institutions_man", "Countries_man"])
df.loc[27, ["Institutions_man", "Countries_man"]] = pd.Series([["Akademii Medycznej w Gdańsku"], ["Poland"]],index=["Institutions_man", "Countries_man"])
df.loc[28, ["Institutions_man", "Countries_man"]] = pd.Series([["Vienna Medical University"], ["Austria"]],index=["Institutions_man", "Countries_man"])
df.loc[29, ["Institutions_man", "Countries_man"]] = pd.Series([["Eastern Hepatobiliary Surgery Hospital", "Second Military Medical University"], ["China", "China"]],index=["Institutions_man", "Countries_man"])
df.loc[30, ["Institutions_man", "Countries_man"]] = [np.nan, np.nan]
df.loc[31, ["Institutions_man", "Countries_man"]] = pd.Series([["Center for Gerontology and Health Care Research", "Brown University"], ["United States", "United States"]],index=["Institutions_man", "Countries_man"])
df.loc[32, ["Institutions_man", "Countries_man"]] = pd.Series([["Tianjin Lung Cancer Institute", "Tianjin Medical University General Hospital"], ["China", "China"]],index=["Institutions_man", "Countries_man"])
df.loc[33, ["Institutions_man", "Countries_man"]] = pd.Series([["Evidence Based Medicine Center", "Lanzhou University"], ["China", "China"]],index=["Institutions_man", "Countries_man"])
df.loc[34, ["Institutions_man", "Countries_man"]] = pd.Series([np.nan, ["New Zealand"]],index=["Institutions_man", "Countries_man"])
df.loc[35, ["Institutions_man", "Countries_man"]] = pd.Series([["Royal North Brisbane Hospital"], ["Australia"]],index=["Institutions_man", "Countries_man"])
df.loc[36, ["Institutions_man", "Countries_man"]] = pd.Series([["Azienda Ospedaliero Universitaria S Maria della Misericordia"], ["Italy"]],index=["Institutions_man", "Countries_man"])
df.loc[37, ["Institutions_man", "Countries_man"]] = pd.Series([["Universitá degli Studi di Palermo"], ["Italy"]],index=["Institutions_man", "Countries_man"])
df.loc[38, ["Institutions_man", "Countries_man"]] = pd.Series([["University Medical Center Hamburg-Eppendorf"], ["Germany"]],index=["Institutions_man", "Countries_man"])
df.loc[39, ["Institutions_man", "Countries_man"]] = [np.nan, np.nan]
df.loc[40, ["Institutions_man", "Countries_man"]] = pd.Series([["Institute of Medical Microbiology", "Charles University"], ["Czechia", "Czechia"]],index=["Institutions_man", "Countries_man"])
df.loc[41, ["Institutions_man", "Countries_man"]] = pd.Series([["Queensland Institute of Medical Research"], ["Australia"]],index=["Institutions_man", "Countries_man"])
df.loc[42, ["Institutions_man", "Countries_man"]] = pd.Series([["University of Porto"], ["Portugal"]],index=["Institutions_man", "Countries_man"])
df.loc[43, ["Institutions_man", "Countries_man"]] = pd.Series([["University of Liverpool", "Linda McCartney Centre", "Royal Liverpool University Hospital"], ["United Kingdom", "United Kingdom", "United Kingdom"]],index=["Institutions_man", "Countries_man"])
df.loc[44, ["Institutions_man", "Countries_man"]] = pd.Series([["University of Leipzig Medical Center", "University Medical Center Hamburg-Eppendorf", "Institute for Medical Biostatistics, Epidemiology and Informatics", "University of Mainz Medical Center", "University Hospital of Essen", "Children's Hospital"], ["Germany", "Germany", "Germany", "Germany", "Germany", "Germany"]],index=["Institutions_man", "Countries_man"])
df.loc[45, ["Institutions_man", "Countries_man"]] = pd.Series([["Northwestern Memorial Hospital", "Robert H. Lurie Comprehensive Cancer Center", "Northwestern University"], ["United States", "United States", "United States"]],index=["Institutions_man", "Countries_man"])
df.loc[46, ["Institutions_man", "Countries_man"]] = pd.Series([["First Affiliated Hospital", "Nanchang University"], ["China", "China"]],index=["Institutions_man", "Countries_man"])
df.loc[47, ["Institutions_man", "Countries_man"]] = pd.Series([["Suzhou Municipal Hospital", "Affiliated Suzhou Hospital", "Nanjing Medical University", "Shaoxing People's Hospital", "Shaoxing Hospital", "Zhejiang University"], ["China", "China", "China", "China", "China", "China"]],index=["Institutions_man", "Countries_man"])
df.loc[48, ["Institutions_man", "Countries_man"]] = [np.nan, np.nan]
df.loc[49, ["Institutions_man", "Countries_man"]] = [np.nan, np.nan]
df.loc[50, ["Institutions_man", "Countries_man"]] = pd.Series([["Institute of Biomedical and Genetic Engineering (IBGE)", "International Islamic University"], ["Pakistan", "Pakistan"]],index=["Institutions_man", "Countries_man"])
df.loc[51, ["Institutions_man", "Countries_man"]] = pd.Series([["Istanbul University", "Institute of Experimental Medicine", "Yedikule Chest Disease and Thoracic Surgery Training and Research Hospital"], ["Türkiye", "Türkiye", "Türkiye"]],index=["Institutions_man", "Countries_man"])
df.loc[52, ["Institutions_man", "Countries_man"]] = [np.nan, np.nan]
df.loc[53, ["Institutions_man", "Countries_man"]] = [np.nan, np.nan]
df.loc[54, ["Institutions_man", "Countries_man"]] = pd.Series([["Cincinnati Children's Hospital Medical Center", "University of Cincinnati", "Cancer and Blood Disease Institute", "Boston Children's Hospital", "Harvard"], ["United States", "United States", "United States", "United States", "United States"]],index=["Institutions_man", "Countries_man"])
df.loc[55, ["Institutions_man", "Countries_man"]] = pd.Series([["Erasmus MC", "Utrecht University", "Erasmus MC Cancer Institute"], ["The Netherlands", "The Netherlands", "The Netherlands"]],index=["Institutions_man", "Countries_man"])
df.loc[56, ["Institutions_man", "Countries_man"]] = [np.nan, np.nan]
df.loc[57, ["Institutions_man", "Countries_man"]] = [np.nan, np.nan]
df.loc[58, ["Institutions_man", "Countries_man"]] = pd.Series([["Queen Elizabeth Hospital", "Royal Victoria Infirmary", "Medical Research Council Clinical Trials Unit", "University College London"], ["United Kingdom", "United Kingdom", "United Kingdom", "United Kingdom"]],index=["Institutions_man", "Countries_man"])
df.loc[59, ["Institutions_man", "Countries_man"]] = pd.Series([["Centro Nacional de Investigaciones Oncológicas (CNIO)", "Center for Molecular Biology of Heidelberg University (ZMBH)", "Centro de Investigación en Red de Enfermedades Neurodegenerativas (CIBERNED)", "University of Cantabria", "IDIVAL", "Center for Biomedicine and Medical Technology Mannheim (CBTM)", "Heidelberg University", "German Cancer Research Center (DKFZ)", "Hope Center for Neurological Diseases", "Washington University"], ["Spain", "Germany", "Spain", "Spain", "Spain", "Germany", "Germany", "United States", "United States"]],index=["Institutions_man", "Countries_man"])
df.loc[60, ["Institutions_man", "Countries_man"]] = pd.Series([["King's College London", "Comprehensive Biomedical Research Centre", "Guy's and St Thomas NHS Foundation Trust", "Uppsala University", "Medical Products Agency", "Karolinska Insituet"], ["United Kingdom", "United Kingdom", "United Kingdom", "Sweden", "Sweden", "Sweden"]],index=["Institutions_man", "Countries_man"])
df.loc[61, ["Institutions_man", "Countries_man"]] = pd.Series([["August Pi i Sunyer Biomedical Research Institute", "Hospital Clínic", "Sant Joan de Deu Childrens Hospital", "University of Barcelona", "Nihon University School of Medicine", "University of Lausanne", "University of Pennsylvania", "Catalan Institution for Research and Advanced Studies"], ["Spain", "Spain", "Spain", "Spain", "Japan", "Switzerland", "United States", "Spain"]],index=["Institutions_man", "Countries_man"])
df.loc[62, ["Institutions_man", "Countries_man"]] = pd.Series([["Delhi State Cancer Institute"], ["India"]],index=["Institutions_man", "Countries_man"])
df.loc[63, ["Institutions_man", "Countries_man"]] = pd.Series([["Kushiro Rosai Hospital", "Kanagawa Cancer Center", "Keio University", "Sapporo Medical University", "Hijirigaoka Hospital", "National Hospital Organization", "Osaka National Hospital", "Hiroshima University", "University of Tokyo", "Tokai Central Hospital", "Translational Research and Clinical Trial Center", "Hokkaido University Hospital", "Japanese Foundation for Multidisciplinary Treatment of Cancer"], ["Japan", "Japan", "Japan", "Japan", "Japan", "Japan", "Japan", "Japan", "Japan", "Japan", "Japan", "Japan", "Japan"]],index=["Institutions_man", "Countries_man"])
df.loc[64, ["Institutions_man", "Countries_man"]] = pd.Series([["Life Raft Group"], ["United States"]],index=["Institutions_man", "Countries_man"])
df.loc[65, ["Institutions_man", "Countries_man"]] = pd.Series([["Washington State University"], ["United States"]],index=["Institutions_man", "Countries_man"])
df.loc[66, ["Institutions_man", "Countries_man"]] = pd.Series([["Addis Ababa University", "Karolinska Institutet", "Karolinska University Hospital", "Center for Innovative Drug Development and Therapeutic Trials", "Armauer Hansen Research Institute"], ["Ethiopia", "Sweden", "Sweden", "Ethiopia", "Ethiopia"]],index=["Institutions_man", "Countries_man"])
df.loc[67, ["Institutions_man", "Countries_man"]] = pd.Series([[np.nan], ["Italy"]],index=["Institutions_man", "Countries_man"])
df.loc[68, ["Institutions_man", "Countries_man"]] = pd.Series([["Tulane University", "Louisiana State University Health Sciences Center"], ["United States", "United States"]],index=["Institutions_man", "Countries_man"])
df.loc[69, ["Institutions_man", "Countries_man"]] = pd.Series([["Hebei Medical University", "Bethune International Peace Hospital", "Hebei University of Chinese Medicine"], ["China", "China", "China"]],index=["Institutions_man", "Countries_man"])
df.loc[70, ["Institutions_man", "Countries_man"]] = pd.Series([["Henan Provincial People's Hospital", "Zhengzhou University People's Hospital", "Henan University People's Hospital", "Institute of Hematology"], ["China", "China", "China", "China"]],index=["Institutions_man", "Countries_man"])
df.loc[71, ["Institutions_man", "Countries_man"]] = pd.Series([["Huazhong University of Science and Technology Union Shenzhen Hospital (Nanshan Hospital)", "Shenzhen Second People's Hospital", "First Affiliated Hospital", "Shenzhen University"], ["China", "China", "China", "China"]],index=["Institutions_man", "Countries_man"])
df.loc[72, ["Institutions_man", "Countries_man"]] = pd.Series([["Medical University of Innsbruck"], ["Austria"]],index=["Institutions_man", "Countries_man"])
df.loc[73, ["Institutions_man", "Countries_man"]] = pd.Series([["Stanton L. Young Biomedical Research Center", "University of Oklahoma Health Science Center"], ["United States", "United States"]],index=["Institutions_man", "Countries_man"])
df.loc[74, ["Institutions_man", "Countries_man"]] = pd.Series([["Center for Bioengineering and Tissue Regeneration", "University of California", "Gladstone Institutes", "Eli and Edythe Broad Center of Regeneration Medicine and Stem Cell Research", "Helen Diller Family Comprehensive Cancer Center"], ["United States", "United States", "United States", "United States", "United States"]],index=["Institutions_man", "Countries_man"])
df.loc[75, ["Institutions_man", "Countries_man"]] = pd.Series([["Northwestern University", "Robert H. Lurie Comprehensive Cancer Center"], ["United States", "United States"]],index=["Institutions_man", "Countries_man"])
df.loc[76, ["Institutions_man", "Countries_man"]] = pd.Series([["Qilu Hospital", "Shandong University", "Central Hospital", "Zaozhuang Coal Mining Group", "Jinan integrative medicine hospital"], ["China", "China", "China", "China", "China"]],index=["Institutions_man", "Countries_man"])
df.loc[77, ["Institutions_man", "Countries_man"]] = pd.Series([["St. Jude Children's Research Hospital", "Cornell", "University of Chicago", "Howard Hughes Medical Institute"], ["United States", "United States", "United States", "United States"]],index=["Institutions_man", "Countries_man"])
df.loc[78, ["Institutions_man", "Countries_man"]] = pd.Series([["Baylor College of Medicine"], ["United States"]],index=["Institutions_man", "Countries_man"])
df.loc[79, ["Institutions_man", "Countries_man"]] = pd.Series([["University of California"], ["United States"]],index=["Institutions_man", "Countries_man"])
df.loc[80, ["Institutions_man", "Countries_man"]] = [np.nan, np.nan]
df.loc[81, ["Institutions_man", "Countries_man"]] = [np.nan, np.nan]
df.loc[82, ["Institutions_man", "Countries_man"]] = pd.Series([["Second Affiliated Hospital", "Fujian Medical University", "Nanjing Medical University"], ["China", "China", "China"]],index=["Institutions_man", "Countries_man"])
df.loc[83, ["Institutions_man", "Countries_man"]] = pd.Series([["Universidade de São Paulo", "Universidade do Oeste Paulista UNOESTE", "Center of Translational Research in Oncology (LIM24)", "Instituto do Cancer do Estado de Sao Paulo (ICESP)"], ["Brazil", "Brazil", "Brazil", "Brazil"]],index=["Institutions_man", "Countries_man"])
df.loc[84, ["Institutions_man", "Countries_man"]] = pd.Series([["Hepatic Surgery Center", "Tongji Hospital", "Huazhong University of Science and Technology", "Shanxi Bethune Hospital", "Shanxi Academy of Medical Sciences", "Shanxi Medical University", "Shanxi Tongji Hospital"], ["China", "China", "China", "China", "China", "China", "China"]],index=["Institutions_man", "Countries_man"])
df.loc[85, ["Institutions_man", "Countries_man"]] = pd.Series([["Centre de Recherche des Cordeliers", "INSERM", "Sorbonne Université", "Université Paris Cité", "Institut universitaire de France", "Institut Gustave Roussy", "Centre de Recherche des Cordeliers", "Klinikum Rechts der Isar", "Technical University of Munich", "Institute of Biophysics", "Czech Academy of Sciences", "CNRS", "Institut Polytechnique de Paris", "Université Paris-Saclay", "Université Sorbonne Paris Nord", "Institut du Cancer Paris CARPEM", "Hôpital Européen Georges Pompidou"], ["France", "France", "France", "France", "France", "France", "France", "Germany", "Germany", "Czechia", "Czechia", "France", "France", "France", "France", "France", "France"]],index=["Institutions_man", "Countries_man"])
df.loc[86, ["Institutions_man", "Countries_man"]] = pd.Series([["Norwegian University of Science and Technology", "St. Olavs Hospital", "Center for Oral Health Services and Research Mid-Norway (TkMidt)", "Clinic of Medicine", "K.G. Jebsen Centre for Genetic Epidemiology"], ["Norway", "Norway", "Norway", "Norway", "Norway"]],index=["Institutions_man", "Countries_man"])
df.loc[87, ["Institutions_man", "Countries_man"]] = pd.Series([["Mayo Clinic"], ["United States"]],index=["Institutions_man", "Countries_man"])
df.loc[88, ["Institutions_man", "Countries_man"]] = pd.Series([["University of Agricultural Sciences and Veterinary Medicine of Cluj-Napoca", "Biotechnology Research Center", "Life Sciences Institute King Michael I of Romania", "Babeș-Bolyai University"], ["Romania", "Romania", "Romania", "Romania"]],index=["Institutions_man", "Countries_man"])
df.loc[89, ["Institutions_man", "Countries_man"]] = pd.Series([["Graduate Institute of Biomedical Science", "China Medical University", "Taichung Tzu Chi Hospital", "Buddhist Tzu Chi Medical Foundation", "China Medical University Hospital", "Asia University", "Institute of New Drug Development"], ["Taiwan", "Taiwan", "Taiwan", "Taiwan", "Taiwan", "Taiwan", "Taiwan"]],index=["Institutions_man", "Countries_man"])
df.loc[90, ["Institutions_man", "Countries_man"]] = pd.Series([["Chongqing University Three Gorges Hospital", "Center for Medicine Research and Translation", "Chengdu Fifth People's Hospital"], ["China", "China", "China"]],index=["Institutions_man", "Countries_man"])



#df.loc[, ["Institutions_man", "Countries_man"]] = pd.Series([[], []],index=["Institutions_man", "Countries_man"])

# %%
df.head()
# Out:
#        PMID                                            Authors  \
# 0   6083417  [{'Name': 'R L Momparler', 'Affiliation': []},...
# 1   6083438  [{'Name': 'Y Tanaka', 'Affiliation': []}, {'Na...
# 2  20301318  [{'Name': 'Rita Barbosa-Matos', 'Affiliation':...
# 3  20301357  [{'Name': 'Sharat Chandra', 'Affiliation': ["A...
# 4  39290086  [{'Name': 'Amy M Cohn', 'Affiliation': ['Depar...
#
#                                             NER_BERT        Country  \
# 0                                                 []            NaN
# 1                                                 []            NaN
# 2  [{'entity_group': 'INS', 'score': np.float32(0...       Portugal
# 3  [{'entity_group': 'INS', 'score': np.float32(0...          China
# 4  [{'entity_group': 'INS', 'score': np.float32(0...  United States
#
#                                     Institutions_man  \
# 0                                                NaN
# 1                                                NaN
# ...
