# %% [markdown]
# ## Fixing country assignments - Regex_institution
#
# It was found that, for some articles, the "Country" field, extracted from NER, was wrongly assigned when done by the method of "Regex_institution" ("Country_source" field). This notebook corrects each found mistake, assign the correct "Country" value and replace the "Country_source" value from "Regex_institution" to "Manual_correction"

# %%
import pandas as pd
import os
import country_converter as coco

## A function used to update Country names cleanly is imported from another file in this project
from aux_fix_country_utils import fix_country_from_text

# %%
DF_input = input().strip()
# Out:
#  C:\Users\svalb\OneDrive\Escritorio\Data_40_years_cancer_studies\parsedXMLs\

# %%
list_csvs = []

for file in os.listdir(DF_input):
    if file[-4:] == ".csv":
        list_csvs.append(file)

list_csvs
# Out:
# ['parsedX_100000.csv',
#  'parsedX_1000000.csv',
#  'parsedX_1100000.csv',
#  'parsedX_1200000.csv',
#  'parsedX_1300000.csv',
#  'parsedX_1400000.csv',
#  'parsedX_1500000.csv',
#  'parsedX_1600000.csv',
#  'parsedX_1700000.csv',
#  'parsedX_1800000.csv',
#  'parsedX_1900000.csv',
#  'parsedX_200000.csv',
#  'parsedX_2000000.csv',
#  'parsedX_2100000.csv',
#  'parsedX_2200000.csv',
#  'parsedX_2300000.csv',
#  'parsedX_2400000.csv',
#  'parsedX_2500000.csv',
#  'parsedX_2600000.csv',
#  'parsedX_2700000.csv',
#  'parsedX_2800000.csv',
#  'parsedX_2900000.csv',
#  'parsedX_300000.csv',
#  'parsedX_3000000.csv',
#  'parsedX_3100000.csv',
#  'parsedX_3200000.csv',
#  'parsedX_3300000.csv',
#  'parsedX_3400000.csv',
#  'parsedX_3500000.csv',
#  'parsedX_3600000.csv',
#  'parsedX_3700000.csv',
#  'parsedX_3800000.csv',
#  'parsedX_3900000.csv',
#  'parsedX_400000.csv',
#  'parsedX_4000000.csv',
#  'parsedX_4100000.csv',
#  'parsedX_4200000.csv',
#  'parsedX_4300000.csv',
# ...

# %% [markdown]
# ## In order to ensure quality renaming, use country_converter
# cc = coco.CountryConverter()

# %% [markdown]
# ### Correcting *parsedX_100000.csv*

# %%
# Read csv
df_parsedX_100000 = pd.read_csv(DF_input + "parsedX_100000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1279244, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1282908, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1283991, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1291757, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1291761, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1296783, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1296785, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1313408, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1313780, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1314917, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1315401, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1316340, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1317214, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1317572, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1319613, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1320139, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1321494, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1325432, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1330836, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1331573, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1335095, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1336492, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1336496, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1336497, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1340409, ["Country", "Country_source"]] = fix_country_from_text("Belarus")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1341320, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1344425, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1345519, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1350949, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1359172, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1359174, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1363324, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1376855, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1377842, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1387127, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1388196, ["Country", "Country_source"]] = fix_country_from_text("Gambia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1392886, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1395431, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1395873, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1399802, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1404961, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1411622, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1415280, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1421756, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1422359, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1429207, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1429209, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1429211, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1434027, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1435440, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1439020, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1439024, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1440177, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1452454, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1460118, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1464946, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1467544, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1469798, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1471221, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1473256, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1473952, ["Country", "Country_source"]] = fix_country_from_text("Ireland")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1479966, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1483427, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1483946, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1483949, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1488294, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1489379, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1494774, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1506274, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1506936, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1507495, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1508648, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1510633, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1511194, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1518137, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1518162, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1518164, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1518184, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1520168, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1522473, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1524849, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1526347, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1529127, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1530474, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1532492, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1544832, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1544844, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1544866, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1544877, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1555547, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1555994, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1555999, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1558779, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1561546, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1564719, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1568843, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1573788, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1573789, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1573791, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1574121, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1575692, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1579470, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1582887, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1582893, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1583573, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1586992, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1591059, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1606794, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1611340, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1612955, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1618700, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1619642, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1619780, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1625606, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1626610, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1627384, ["Country", "Country_source"]] = fix_country_from_text("Netherlands")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1630350, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1630894, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1635491, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1638698, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1640883, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1648129, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1648431, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1648633, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1648635, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1649794, ["Country", "Country_source"]] = fix_country_from_text("Thailand")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1649812, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1649814, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1650329, ["Country", "Country_source"]] = fix_country_from_text("Thailand")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1650574, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1651392, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1657552, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1657847, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1657848, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1658415, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1658416, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1658731, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1664877, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1664879, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1664881, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1664883, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1664886, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1665132, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1669524, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1675471, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1679056, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1684826, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1685881, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1694838, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1696094, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1697065, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1702370, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1702412, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1702415, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1708246, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1710446, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1711304, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1715338, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1715778, ["Country", "Country_source"]] = fix_country_from_text("Pakistan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1716622, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1721614, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1721615, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1721656, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1725688, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1734220, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1737628, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1744744, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1751280, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1752788, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1753417, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1753418, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1778757, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1778765, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1778775, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1785146, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1791253, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1793394, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1797655, ["Country", "Country_source"]] = fix_country_from_text("India")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1805050, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1827277, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1834359, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1834923, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1849184, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1849187, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1849189, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1851059, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1851610, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1851904, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1853503, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1863949, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1864137, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1872236, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1889579, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1889619, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1893082, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1893083, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1893515, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1894221, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1897075, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1900266, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1900734, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1900817, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1901116, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1902452, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1903663, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1904414, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1904418, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1906847, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1906848, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1908844, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1911349, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1912056, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1913642, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1914965, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1917597, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1919029, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1919387, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1924441, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1925010, ["Country", "Country_source"]] = fix_country_from_text("Norway")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1926038, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1929496, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1932332, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1936782, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1937362, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1938596, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1942549, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1942550, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1942552, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1942555, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1942560, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1953014, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1960180, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1960491, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1963245, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1966278, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1966519, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1970554, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1973161, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1975502, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1978564, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1979421, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1979976, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1983859, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1989642, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")

# %%
df_parsedX_100000.to_csv(DF_input + "parsedX_100000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_1000000.csv*

# %%
# Read csv
df_parsedX_1000000 = pd.read_csv(DF_input + "parsedX_1000000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11270620, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11289192, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11307302, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11315257, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11317526, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11317533, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11317539, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11317540, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11317547, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11320721, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11375234, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11383206, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11383447, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11383456, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11383460, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11389995, ["Country", "Country_source"]] = fix_country_from_text("Austria")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11396509, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11400696, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11402299, ["Country", "Country_source"]] = fix_country_from_text("Austria")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11422476, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11424371, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11424392, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11424412, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11424415, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11424419, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11424434, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11424435, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11424443, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11424444, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11452695, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11452701, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11464491, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11476352, ["Country", "Country_source"]] = fix_country_from_text("Israel")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11477111, ["Country", "Country_source"]] = fix_country_from_text("Belgium")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11479950, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11485960, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11488146, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11494004, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11494510, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11512313, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11521795, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11523571, ["Country", "Country_source"]] = fix_country_from_text("Israel")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11529666, ["Country", "Country_source"]] = fix_country_from_text("Austria")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11544827, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11544828, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11544829, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11544830, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11544831, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11544837, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11544839, ["Country", "Country_source"]] = fix_country_from_text("Armenia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11547588, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11547595, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11554051, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11593712, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11665947, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11676863, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11688624, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11705873, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11710281, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11710283, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11710284, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11710292, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11710293, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11712345, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11714441, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11744176, ["Country", "Country_source"]] = fix_country_from_text("Austria")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11751431, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11758333, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11761925, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11761931, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11761936, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11761944, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11761953, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11761958, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11761962, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11762028, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11766351, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11774267, ["Country", "Country_source"]] = fix_country_from_text("Austria")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11785097, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11785099, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11785104, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11785106, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11785109, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11789424, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11795767, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11808130, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11808346, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11825488, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11826490, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11829853, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11831067, ["Country", "Country_source"]] = fix_country_from_text("Switzerland")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11847882, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11851111, ["Country", "Country_source"]] = fix_country_from_text("Israel")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11865331, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11904439, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11904959, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11904960, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11904980, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11936580, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11968735, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11974424, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12011056, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12032698, ["Country", "Country_source"]] = fix_country_from_text("Austria")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12036442, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12036445, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12036454, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12048932, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12050096, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12054331, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12054336, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12055736, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12061341, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12063644, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12071446, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12079507, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12079509, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12079519, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12094715, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12098786, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101562, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101563, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101568, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101569, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101575, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101639, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101647, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101648, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101678, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101687, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101695, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101704, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101709, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101718, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101719, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101756, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101760, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101767, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101774, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101779, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12105432, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12105438, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12105441, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12105443, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12105507, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12105605, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12105607, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12105613, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12105615, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12105616, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12105617, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12105622, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12105623, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12105627, ["Country", "Country_source"]] = fix_country_from_text("Australia")

# %%
df_parsedX_1000000.to_csv(DF_input + "parsedX_1000000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_1100000.csv*

# %%
# Read csv
df_parsedX_1100000 = pd.read_csv(DF_input + "parsedX_1100000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12136428, ["Country", "Country_source"]] = fix_country_from_text("Austria")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12136764, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12141619, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12145990, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12146002, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12146010, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12146016, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12168482, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12212424, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12227067, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12227069, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12227072, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12227076, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12227077, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12227080, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12325330, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12355944, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12358597, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12365118, ["Country", "Country_source"]] = fix_country_from_text("South Africa")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12377961, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12405939, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12414660, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12415343, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12431965, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12452064, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12452070, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12455359, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12455360, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12455365, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12455366, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12469028, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12479098, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12500407, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12508641, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12518616, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12526345, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12527882, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12530258, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12530260, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12530262, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12530267, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12530268, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12530271, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12530275, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12530277, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12530278, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12548848, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12549040, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12553672, ["Country", "Country_source"]] = fix_country_from_text("Pakistan")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12572219, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12577360, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12595939, ["Country", "Country_source"]] = fix_country_from_text("Belgium")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12597470, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12599550, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12599579, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12607315, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12608385, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12609052, ["Country", "Country_source"]] = fix_country_from_text("Austria")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12619345, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12622041, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12645302, ["Country", "Country_source"]] = fix_country_from_text("France")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12653690, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12675960, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12692961, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12701641, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12708476, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12708491, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12708494, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12715371, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12715372, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12715375, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12715380, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12715381, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12716288, ["Country", "Country_source"]] = fix_country_from_text("India")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12717910, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12717918, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12717921, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12717922, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12717930, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12718029, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12721740, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12727849, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12728494, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12776509, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12785194, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12785199, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12785204, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12785205, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12788350, ["Country", "Country_source"]] = fix_country_from_text("Serbia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12795087, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12795093, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12806939, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12806957, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12808438, ["Country", "Country_source"]] = fix_country_from_text("Austria")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12813777, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12814632, ["Country", "Country_source"]] = fix_country_from_text("Austria")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12816081, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12824756, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12833828, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12852340, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12886499, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12899127, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12901809, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12926212, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12926213, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12926214, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12926218, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12926221, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12935986, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12937679, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 12966937, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 13677286, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 14501087, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_1100000.loc[df_parsedX_1100000["PMID"] == 14508115, ["Country", "Country_source"]] = fix_country_from_text("United States")

# %%
df_parsedX_1100000.to_csv(DF_input + "parsedX_1100000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_1200000.csv*

# %%
# Read csv
df_parsedX_1200000 = pd.read_csv(DF_input + "parsedX_1200000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14515721, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14515729, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14515733, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14516118, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14518671, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14569932, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14569935, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14569937, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14569938, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14569943, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14569944, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14569946, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14569947, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14574868, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14574911, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14574915, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14574916, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14574927, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14574951, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14574958, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14577941, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14578785, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14593772, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14594021, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14598682, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14611672, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14615835, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14626891, ["Country", "Country_source"]] = fix_country_from_text("South Africa")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14628576, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14628612, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14643316, ["Country", "Country_source"]] = fix_country_from_text("Austria")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14662028, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14680836, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14682126, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14682127, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14682128, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14682129, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14682130, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14682131, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14682132, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14682133, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14682134, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14682138, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14682139, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14682140, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14682143, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14696819, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14696940, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14705287, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14714084, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14746022, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14746039, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14762695, ["Country", "Country_source"]] = fix_country_from_text("Austria")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14770336, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14974271, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14976915, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14976917, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14976919, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14976920, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14976922, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14976923, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14981991, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14993212, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 14994511, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15014065, ["Country", "Country_source"]] = fix_country_from_text("Finland")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15021995, ["Country", "Country_source"]] = fix_country_from_text("Finland")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15025352, ["Country", "Country_source"]] = fix_country_from_text("India")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15041908, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15088521, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15088524, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15088527, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15114701, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15115771, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15120609, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15125279, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15129634, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15130183, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15168998, ["Country", "Country_source"]] = fix_country_from_text("India")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15176217, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15176218, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15176220, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15176223, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15176225, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15176226, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15176227, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15188530, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15244513, ["Country", "Country_source"]] = fix_country_from_text("India")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15283154, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15293736, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15301724, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15302543, ["Country", "Country_source"]] = fix_country_from_text("Spain")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15302683, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15332541, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15346983, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15387268, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15446553, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15446560, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15446574, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15455096, ["Country", "Country_source"]] = fix_country_from_text("Armenia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15455126, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15455128, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15468570, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15468978, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15485121, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15500082, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15532591, ["Country", "Country_source"]] = fix_country_from_text("Israel")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15535203, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15535302, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15535321, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1200000.loc[df_parsedX_1200000["PMID"] == 15536290, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")

# %%
df_parsedX_1200000.to_csv(DF_input + "parsedX_1200000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_1300000.csv*

# %%
# Read csv
df_parsedX_1300000 = pd.read_csv(DF_input + "parsedX_1300000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 15565963, ["Country", "Country_source"]] = fix_country_from_text("Denmark")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 15566009, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 15577137, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 15587186, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 15588186, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 15628428, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 15651770, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 15662466, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 15682855, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 15708305, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 15714978, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 15714979, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 15717329, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 15747150, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 15757047, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 15783098, ["Country", "Country_source"]] = fix_country_from_text("Türkiye")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 15883842, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 15915748, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 15937217, ["Country", "Country_source"]] = fix_country_from_text("Spain")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 15941162, ["Country", "Country_source"]] = fix_country_from_text("Malaysia")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 15941165, ["Country", "Country_source"]] = fix_country_from_text("Malaysia")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 15969504, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 15969977, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 15977506, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 15981624, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 15991778, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 16027833, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 16119498, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 16134821, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 16160719, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 16161481, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 16166593, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 16181469, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 16193058, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 16201593, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 16201594, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 16252725, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 16281672, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 16304871, ["Country", "Country_source"]] = fix_country_from_text("Pakistan")
df_parsedX_1300000.loc[df_parsedX_1300000["PMID"] == 16314121, ["Country", "Country_source"]] = fix_country_from_text("Germany")

# %%
df_parsedX_1300000.to_csv(DF_input + "parsedX_1300000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_1400000.csv*

# %%
# Read csv
df_parsedX_1400000 = pd.read_csv(DF_input + "parsedX_1400000.csv")
# Out:
# C:\Users\svalb\AppData\Local\Temp\ipykernel_4388\1721106359.py:2: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_parsedX_1400000 = pd.read_csv(DF_input + "parsedX_1400000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16352928, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16352946, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16363501, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16380734, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16392666, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16411349, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16416802, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16416833, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16424979, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16440711, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16454187, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16457216, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16457246, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16457296, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16457307, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16457317, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16457319, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16457327, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16458489, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16462891, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16467915, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16480002, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16491880, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16505263, ["Country", "Country_source"]] = fix_country_from_text("Netherlands")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16529031, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16529032, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16529040, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16531709, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16531710, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16533551, ["Country", "Country_source"]] = fix_country_from_text("France")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16551964, ["Country", "Country_source"]] = fix_country_from_text("Spain")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16582880, ["Country", "Country_source"]] = fix_country_from_text("Spain")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16598496, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16612152, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16629457, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16669461, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16703961, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16733503, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16750592, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16767903, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16767933, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16780103, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16800823, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16821669, ["Country", "Country_source"]] = fix_country_from_text("India")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16827805, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16828752, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16835473, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16835475, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16835477, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16835482, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16875116, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16878363, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16905385, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16917631, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16956160, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16972690, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16983991, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 16983992, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 17033223, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 17033226, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 17033250, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 17034384, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 17038737, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 17063873, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 17065961, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 17066111, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 17069891, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 17085910, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 17108724, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 17137071, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 17180074, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1400000.loc[df_parsedX_1400000["PMID"] == 17184607, ["Country", "Country_source"]] = fix_country_from_text("Spain")

# %%
df_parsedX_1400000.to_csv(DF_input + "parsedX_1400000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_1500000.csv*

# %%
# Read csv
df_parsedX_1500000 = pd.read_csv(DF_input + "parsedX_1500000.csv")
# Out:
# C:\Users\svalb\AppData\Local\Temp\ipykernel_4388\2796711726.py:2: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_parsedX_1500000 = pd.read_csv(DF_input + "parsedX_1500000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17195311, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17211092, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17220608, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17233408, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17233423, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17234118, ["Country", "Country_source"]] = fix_country_from_text("Kuwait")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17240427, ["Country", "Country_source"]] = fix_country_from_text("Morocco")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17240832, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17243646, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17283410, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17291758, ["Country", "Country_source"]] = fix_country_from_text("Austria")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17301523, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17301543, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17301548, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17301553, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17319501, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17331256, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17337515, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17369913, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17387247, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17390009, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17390013, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17395640, ["Country", "Country_source"]] = fix_country_from_text("Austria")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17414442, ["Country", "Country_source"]] = fix_country_from_text("Türkiye")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17415466, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17424930, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17437394, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17474393, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17491442, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17513603, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17554959, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17594471, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17619400, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17637534, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17637538, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17638335, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17656481, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17658151, ["Country", "Country_source"]] = fix_country_from_text("Spain")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17676038, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17682148, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17682177, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17682204, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17682211, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17684689, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17684691, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17684692, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17687221, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17695583, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17703446, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17710265, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17824921, ["Country", "Country_source"]] = fix_country_from_text("Saudi Arabia")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17851642, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17869009, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17878229, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17940079, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17940390, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17952223, ["Country", "Country_source"]] = fix_country_from_text("South Africa")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17952224, ["Country", "Country_source"]] = fix_country_from_text("South Africa")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17953025, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17953034, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 17989099, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 18057016, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 18061583, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 18074549, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 18076855, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1500000.loc[df_parsedX_1500000["PMID"] == 18080603, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")

# %%
df_parsedX_1500000.to_csv(DF_input + "parsedX_1500000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_1600000.csv*

# %%
# Read csv
df_parsedX_1600000 = pd.read_csv(DF_input + "parsedX_1600000.csv")
# Out:
# C:\Users\svalb\AppData\Local\Temp\ipykernel_4388\728907519.py:2: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_parsedX_1600000 = pd.read_csv(DF_input + "parsedX_1600000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18090128, ["Country", "Country_source"]] = fix_country_from_text("Israel")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18161163, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18163149, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18179862, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18214311, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18281754, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18304111, ["Country", "Country_source"]] = fix_country_from_text("Finland")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18320950, ["Country", "Country_source"]] = fix_country_from_text("Netherlands")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18324639, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18332993, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18349863, ["Country", "Country_source"]] = fix_country_from_text("Ireland")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18372992, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18372993, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18416195, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18444339, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18451597, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18470726, ["Country", "Country_source"]] = fix_country_from_text("Austria")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18474220, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18528681, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18536320, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18539490, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18549406, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18557345, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18559589, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18598253, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18603845, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18626666, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18628473, ["Country", "Country_source"]] = fix_country_from_text("Austria")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18633260, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18634843, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18647119, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18647124, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18664291, ["Country", "Country_source"]] = fix_country_from_text("Kuwait")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18686842, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18706098, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18772538, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18782404, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18789218, ["Country", "Country_source"]] = fix_country_from_text("Switzerland")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18799025, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18803448, ["Country", "Country_source"]] = fix_country_from_text("Greece")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18838752, ["Country", "Country_source"]] = fix_country_from_text("Indonesia")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18843491, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 18929375, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 19017732, ["Country", "Country_source"]] = fix_country_from_text("Sweden")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 19020730, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 19023969, ["Country", "Country_source"]] = fix_country_from_text("Armenia")
df_parsedX_1600000.loc[df_parsedX_1600000["PMID"] == 19031678, ["Country", "Country_source"]] = fix_country_from_text("Mexico")

# %%
df_parsedX_1600000.to_csv(DF_input + "parsedX_1600000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_1700000.csv*

# %%
# Read csv
df_parsedX_1700000 = pd.read_csv(DF_input + "parsedX_1700000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19048763, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19053940, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19062468, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19077459, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19102482, ["Country", "Country_source"]] = fix_country_from_text("Türkiye")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19117758, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19126391, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19140350, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19169344, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19177752, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19183436, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19223659, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19227439, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19234428, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19262705, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19273378, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19284797, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19295261, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19322053, ["Country", "Country_source"]] = fix_country_from_text("United Arab Emirates")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19358411, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19372039, ["Country", "Country_source"]] = fix_country_from_text("Netherlands")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19374192, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19374936, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19375338, ["Country", "Country_source"]] = fix_country_from_text("Netherlands")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19407097, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19409458, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19412903, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19433156, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19462554, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19486885, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19491750, ["Country", "Country_source"]] = fix_country_from_text("Greece")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19507518, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19507519, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19604245, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19635199, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19668929, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19682430, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19685436, ["Country", "Country_source"]] = fix_country_from_text("Netherlands")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19734698, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19735488, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19764668, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_1700000.loc[df_parsedX_1700000["PMID"] == 19807526, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")

# %%
df_parsedX_1700000.to_csv(DF_input + "parsedX_1700000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_1800000.csv*

# %%
# Read csv
df_parsedX_1800000 = pd.read_csv(DF_input + "parsedX_1800000.csv")
# Out:
# C:\Users\svalb\AppData\Local\Temp\ipykernel_4388\4156831956.py:2: DtypeWarning: Columns (13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_parsedX_1800000 = pd.read_csv(DF_input + "parsedX_1800000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 19846480, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 19848060, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 19853187, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 19860197, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 19893290, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 19920381, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 19967271, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 19967273, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 19967276, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 19967279, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 19967285, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 19967292, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 20003337, ["Country", "Country_source"]] = fix_country_from_text("Sweden")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 20073291, ["Country", "Country_source"]] = fix_country_from_text("South Africa")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 20084721, ["Country", "Country_source"]] = fix_country_from_text("Kuwait")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 20100773, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 20109071, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 20118592, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 20120646, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 20127005, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 20127025, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 20131669, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 20140864, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 20154484, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 20158104, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 20204306, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 20209690, ["Country", "Country_source"]] = fix_country_from_text("Pakistan")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 20376798, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 20380607, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 20444847, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 20464211, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 20464218, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 20464222, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 20523083, ["Country", "Country_source"]] = fix_country_from_text("Greece")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 20535964, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 20570927, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 20571589, ["Country", "Country_source"]] = fix_country_from_text("Egypt")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 20605933, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 20653429, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 20662210, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 20688012, ["Country", "Country_source"]] = fix_country_from_text("Pakistan")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 20716873, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1800000.loc[df_parsedX_1800000["PMID"] == 20719510, ["Country", "Country_source"]] = fix_country_from_text("China")

# %%
df_parsedX_1800000.to_csv(DF_input + "parsedX_1800000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_1900000.csv*

# %%
# Read csv
df_parsedX_1900000 = pd.read_csv(DF_input + "parsedX_1900000.csv")
# Out:
# C:\Users\svalb\AppData\Local\Temp\ipykernel_4388\405891281.py:2: DtypeWarning: Columns (13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_parsedX_1900000 = pd.read_csv(DF_input + "parsedX_1900000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 20727279, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 20805676, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 20827398, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 20836325, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 20847481, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 20857789, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 20857797, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 20885097, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 20927799, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 20970405, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 20976921, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 20976923, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 20976929, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 21031253, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 21047472, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 21071893, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 21106054, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 21133607, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 21163286, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 21163808, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 21179664, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 21196455, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 21209985, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 21226308, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 21229690, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 21229699, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 21229702, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 21243205, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 21265905, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 21269251, ["Country", "Country_source"]] = fix_country_from_text("South Africa")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 21271013, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 21275377, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 21289906, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 21316708, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 21348258, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 21378204, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 21384636, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 21398627, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 21416321, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 21432441, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 21442312, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 21473201, ["Country", "Country_source"]] = fix_country_from_text("Bangladesh")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 21479347, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 21488160, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 21535505, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 21542452, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 21562631, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 21566428, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 21566442, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1900000.loc[df_parsedX_1900000["PMID"] == 21569518, ["Country", "Country_source"]] = fix_country_from_text("Mexico")

# %%
df_parsedX_1900000.to_csv(DF_input + "parsedX_1900000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_200000.csv*

# %%
# Read csv
df_parsedX_200000 = pd.read_csv(DF_input + "parsedX_200000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 1995326, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 1995697, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 1999160, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2025219, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2027146, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2029835, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2030147, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2032076, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2034151, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2039721, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2040483, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2041504, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2051600, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2063516, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2064956, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2066984, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2067122, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2067124, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2067126, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2067127, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2067942, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2070839, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2072017, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2073203, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2077661, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2088471, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2090083, ["Country", "Country_source"]] = fix_country_from_text("Türkiye")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2095738, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2097236, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2108155, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2109702, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2110134, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2111663, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2112863, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2116390, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2116395, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2116396, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2116401, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2116583, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2117680, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2117908, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2118172, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2118896, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2119359, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2123951, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2125037, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2125989, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2127611, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2129846, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2139232, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2139575, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2141478, ["Country", "Country_source"]] = fix_country_from_text("Ireland")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2142152, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2143172, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2143180, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2146287, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2155314, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2157693, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2159091, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2161814, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2162402, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2162407, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2162656, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2166173, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2167650, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2167718, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2168864, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2168867, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2169471, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2169552, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2169836, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2170950, ["Country", "Country_source"]] = fix_country_from_text("Ukraine")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2172195, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2172198, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2172847, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2174995, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2174998, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2176200, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2177459, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2177460, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2178196, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2178198, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2179467, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2179962, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2179963, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2181938, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2181940, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2183875, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2184274, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2187775, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2188616, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2189067, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2192120, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2192177, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2192182, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2192188, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2195185, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2196388, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2197196, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2197476, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2200851, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2201038, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2201403, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2201827, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2202471, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2206863, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2207001, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2207551, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2217458, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2221768, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2230560, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2230578, ["Country", "Country_source"]] = fix_country_from_text("Uzbekistan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2232218, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2233447, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2233523, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2238391, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2244404, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2245808, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2246843, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2251743, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2253461, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2253792, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2255072, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2255078, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2255087, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2255101, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2255109, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2255895, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2262733, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2268401, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2269016, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2270038, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2277217, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2281156, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2283720, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2283725, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2284296, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2287813, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2290483, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2291751, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2293812, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2295217, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2296232, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2296233, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2300011, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2300026, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2315681, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2317076, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2319390, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2321980, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2323471, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2325063, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2325289, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2327414, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2332170, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2334176, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2343167, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2344192, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2344194, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2344196, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2345404, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2346447, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2346589, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2347333, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2353095, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2355403, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2355639, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2356842, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2357993, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2362791, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2364368, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2369286, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2370130, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2370690, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2370695, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2370696, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2370917, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2374440, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2378367, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2380014, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2390452, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2391699, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2395207, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2395208, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2400359, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2401351, ["Country", "Country_source"]] = fix_country_from_text("Georgia")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2402953, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2446915, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2453894, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2456124, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2460538, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2465316, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2466473, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2466821, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2470448, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2471460, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2471845, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2473055, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2474073, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2477964, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2478464, ["Country", "Country_source"]] = fix_country_from_text("Georgia")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2478739, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2478884, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2479834, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2482283, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2493529, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2498258, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2498260, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2501245, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2503148, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2504270, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2506827, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2506836, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2507485, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2511179, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2513298, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2514173, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2516840, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2516841, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2516843, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2516847, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2524459, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2525002, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2525905, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2527216, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2537127, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2537654, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2537863, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2537907, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2537908, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2538803, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2538982, ["Country", "Country_source"]] = fix_country_from_text("Sweden")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2539304, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2539781, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2539785, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2542205, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2543307, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2543331, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2549262, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2549878, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2550322, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2551686, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2554027, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2555320, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2563396, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2565103, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2572238, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2572271, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2575263, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2575608, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2593064, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2593903, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2593939, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2598115, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2603121, ["Country", "Country_source"]] = fix_country_from_text("South Africa")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2605081, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2606570, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2607638, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2607639, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2607642, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2607644, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2611135, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2611631, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2615470, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2619684, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2626668, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2632266, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2641696, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2641698, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2641705, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2641706, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2642235, ["Country", "Country_source"]] = fix_country_from_text("Poland")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2649706, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2650627, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2653222, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2654003, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2654446, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2659845, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2659846, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2659905, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2662918, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2665383, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2665480, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2666662, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2667632, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2674980, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2680955, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2683091, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2684257, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_200000.loc[df_parsedX_200000["PMID"] == 2685391, ["Country", "Country_source"]] = fix_country_from_text("Japan")

# %%
df_parsedX_200000.to_csv(DF_input + "parsedX_200000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_2000000.csv*

# %%
# Read csv
df_parsedX_2000000 = pd.read_csv(DF_input + "parsedX_2000000.csv")
# Out:
# C:\Users\svalb\AppData\Local\Temp\ipykernel_4388\1244244419.py:2: DtypeWarning: Columns (13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_parsedX_2000000 = pd.read_csv(DF_input + "parsedX_2000000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 21637307, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 21646757, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 21661649, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 21698003, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 21707846, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 21710867, ["Country", "Country_source"]] = fix_country_from_text("Malaysia")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 21717719, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 21755191, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 21766638, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 21768422, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 21819350, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 21830607, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 21830611, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 21863751, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 21877079, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 21877087, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 21891991, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 21892304, ["Country", "Country_source"]] = fix_country_from_text("Kuwait")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 21913537, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 21917309, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 21952582, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 21965475, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 21970213, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 21971142, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 22026176, ["Country", "Country_source"]] = fix_country_from_text("Switzerland")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 22035094, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 22073590, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 22096801, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 22096961, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 22130377, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 22131108, ["Country", "Country_source"]] = fix_country_from_text("Sweden")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 22189222, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 22208001, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 22208029, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 22209971, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 22213947, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 22213967, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 22213969, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 22213972, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 22213982, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 22213999, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 22214003, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 22214008, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 22214011, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 22214014, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 22214015, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 22214019, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 22218792, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 22241153, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 22241357, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 22242313, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 22242316, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 22266037, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 22288311, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 22302300, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 22337534, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 22341977, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 22352228, ["Country", "Country_source"]] = fix_country_from_text("Bangladesh")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 22368984, ["Country", "Country_source"]] = fix_country_from_text("Türkiye")
df_parsedX_2000000.loc[df_parsedX_2000000["PMID"] == 22369928, ["Country", "Country_source"]] = fix_country_from_text("China")

# %%
df_parsedX_2000000.to_csv(DF_input + "parsedX_2000000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_2100000.csv*

# %%
# Read csv
df_parsedX_2100000 = pd.read_csv(DF_input + "parsedX_2100000.csv")
# Out:
# C:\Users\svalb\AppData\Local\Temp\ipykernel_4388\253848843.py:2: DtypeWarning: Columns (13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_parsedX_2100000 = pd.read_csv(DF_input + "parsedX_2100000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22409695, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22413242, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22416370, ["Country", "Country_source"]] = fix_country_from_text("Uzbekistan")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22468379, ["Country", "Country_source"]] = fix_country_from_text("Sweden")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22470993, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22471045, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22471046, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22471047, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22471054, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22487742, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22491944, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22548295, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22553865, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22553866, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22553873, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22553876, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22553879, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22584329, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22592608, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22614916, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22619997, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22634998, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22642576, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22649628, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22678804, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22689161, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22689171, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22705300, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22740930, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22759733, ["Country", "Country_source"]] = fix_country_from_text("Singapore")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22768029, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22771919, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22811855, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22824846, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22825043, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22844368, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22859015, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22871163, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22908522, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22922424, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22923266, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22940266, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22966400, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22972805, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22993103, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 22995316, ["Country", "Country_source"]] = fix_country_from_text("South Korea")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 23041545, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 23044371, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 23052271, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 23055778, ["Country", "Country_source"]] = fix_country_from_text("Cuba")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 23081722, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 23124567, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 23131552, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 23133931, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 23134008, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 23134010, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 23146855, ["Country", "Country_source"]] = fix_country_from_text("Pakistan")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 23148667, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 23156213, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 23156226, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 23156243, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 23156318, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2100000.loc[df_parsedX_2100000["PMID"] == 23156501, ["Country", "Country_source"]] = fix_country_from_text("Japan")

# %%
df_parsedX_2100000.to_csv(DF_input + "parsedX_2100000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_2200000.csv*

# %%
# Read csv
df_parsedX_2200000 = pd.read_csv(DF_input + "parsedX_2200000.csv")
# Out:
# C:\Users\svalb\AppData\Local\Temp\ipykernel_4388\949312354.py:2: DtypeWarning: Columns (13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_parsedX_2200000 = pd.read_csv(DF_input + "parsedX_2200000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23175880, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23198545, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23198549, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23198551, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23198562, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23198568, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23205425, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23227577, ["Country", "Country_source"]] = fix_country_from_text("Switzerland")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23247845, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23259386, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23273264, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23288428, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23311199, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23311234, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23313659, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23350429, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23350466, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23359689, ["Country", "Country_source"]] = fix_country_from_text("Belgium")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23359754, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23359758, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23383564, ["Country", "Country_source"]] = fix_country_from_text("Switzerland")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23400243, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23431890, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23438037, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23439742, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23442399, ["Country", "Country_source"]] = fix_country_from_text("Sri Lanka")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23442998, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23447575, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23452341, ["Country", "Country_source"]] = fix_country_from_text("Sweden")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23465981, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23469566, ["Country", "Country_source"]] = fix_country_from_text("India")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23471455, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23483136, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23495705, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23513873, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23513885, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23531701, ["Country", "Country_source"]] = fix_country_from_text("Sweden")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23555321, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23557719, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23565595, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23568320, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23579364, ["Country", "Country_source"]] = fix_country_from_text("Greece")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23589750, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23603639, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23604900, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23611775, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23613288, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23628413, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23646820, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23679956, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23680751, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23682303, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23698137, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23702649, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23703800, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23724766, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23741443, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23759369, ["Country", "Country_source"]] = fix_country_from_text("Switzerland")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23760103, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23788920, ["Country", "Country_source"]] = fix_country_from_text("Türkiye")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23795545, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23804155, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23835497, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23851286, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23857592, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23860541, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23863732, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23867816, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23870553, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2200000.loc[df_parsedX_2200000["PMID"] == 23899839, ["Country", "Country_source"]] = fix_country_from_text("Japan")

# %%
df_parsedX_2200000.to_csv(DF_input + "parsedX_2200000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_2300000.csv*

# %%
# Read csv
df_parsedX_2300000 = pd.read_csv(DF_input + "parsedX_2300000.csv")
# Out:
# C:\Users\svalb\AppData\Local\Temp\ipykernel_4388\398227895.py:2: DtypeWarning: Columns (13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_parsedX_2300000 = pd.read_csv(DF_input + "parsedX_2300000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 23919270, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 23935856, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 23956811, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 23962981, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 23967867, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 23990115, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 23999638, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24002667, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24009066, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24020115, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24054020, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24078568, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24097144, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24105050, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24113756, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24127976, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24141978, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24157377, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24171151, ["Country", "Country_source"]] = fix_country_from_text("India")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24231695, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24235937, ["Country", "Country_source"]] = fix_country_from_text("Türkiye")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24239898, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24247422, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24277854, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24297085, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24335360, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24335368, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24345206, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24356570, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24357177, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24360211, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24366561, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24370014, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24393676, ["Country", "Country_source"]] = fix_country_from_text("Malaysia")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24397180, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24399074, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24406079, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24440656, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24474492, ["Country", "Country_source"]] = fix_country_from_text("India")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24483948, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24492135, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24492298, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24498562, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24500315, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24517622, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24520176, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24565101, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24579501, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24583786, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24583857, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24587621, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24593055, ["Country", "Country_source"]] = fix_country_from_text("UnitedKingdom")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24597341, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24597345, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24597367, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24598089, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24601103, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24606770, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24615258, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24626701, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24628363, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24642629, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2300000.loc[df_parsedX_2300000["PMID"] == 24649231, ["Country", "Country_source"]] = fix_country_from_text("China")

# %%
df_parsedX_2300000.to_csv(DF_input + "parsedX_2300000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_2400000.csv*

# %%
# Read csv
df_parsedX_2400000 = pd.read_csv(DF_input + "parsedX_2400000.csv")
# Out:
# C:\Users\svalb\AppData\Local\Temp\ipykernel_4388\3311821076.py:2: DtypeWarning: Columns (13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_parsedX_2400000 = pd.read_csv(DF_input + "parsedX_2400000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 24678763, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 24689482, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 24696746, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 24743193, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 24746300, ["Country", "Country_source"]] = fix_country_from_text("Saudi Arabia")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 24750454, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 24753816, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 24755544, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 24761907, ["Country", "Country_source"]] = fix_country_from_text("Türkiye")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 24780708, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 24815512, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 24820099, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 24829467, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 24830725, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 24830726, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 24839236, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 24840071, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 24843663, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 24854113, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 24858118, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 24888573, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 24901850, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 24913506, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 24915871, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 24919837, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 24921975, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 24932259, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 24935257, ["Country", "Country_source"]] = fix_country_from_text("Switzerland")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 24942945, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 24944618, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 24969260, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 24970308, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 24971413, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 24972470, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 24990468, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25006263, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25016951, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25026290, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25059680, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25061863, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25066760, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25075027, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25089604, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25097183, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25109605, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25124107, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25124603, ["Country", "Country_source"]] = fix_country_from_text("Türkiye")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25126288, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25130677, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25131192, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25132023, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25145381, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25160192, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25174748, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25176216, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25192414, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25196427, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25217154, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25234748, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25248886, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25248892, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25248897, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25249380, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25274741, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25275863, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25277197, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25279210, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25311507, ["Country", "Country_source"]] = fix_country_from_text("Switzerland")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25323946, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25326418, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25329252, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25332420, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25332421, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25347610, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25350463, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2400000.loc[df_parsedX_2400000["PMID"] == 25361001, ["Country", "Country_source"]] = fix_country_from_text("China")

# %%
df_parsedX_2400000.to_csv(DF_input + "parsedX_2400000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_2500000.csv*

# %%
# Read csv
df_parsedX_2500000 = pd.read_csv(DF_input + "parsedX_2500000.csv")
# Out:
# C:\Users\svalb\AppData\Local\Temp\ipykernel_4388\125890340.py:2: DtypeWarning: Columns (13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_parsedX_2500000 = pd.read_csv(DF_input + "parsedX_2500000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25376416, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25385820, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25392276, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25394667, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25398581, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25415070, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25422324, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25434433, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25461186, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25462224, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25465280, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25470554, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25473956, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25476853, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25483709, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25484045, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25488086, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25491985, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25502594, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25542041, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25561897, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25577590, ["Country", "Country_source"]] = fix_country_from_text("Kuwait")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25587131, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25596673, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25604281, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25604287, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25604294, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25604296, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25604297, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25604298, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25604301, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25605020, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25615804, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25622161, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25625609, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25625930, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25629306, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25638269, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25640374, ["Country", "Country_source"]] = fix_country_from_text("Türkiye")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25645204, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25670762, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25670763, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25673153, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25681388, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25702681, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25710485, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25735382, ["Country", "Country_source"]] = fix_country_from_text("Saint Lucia")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25743132, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25743141, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25744364, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25765981, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25794010, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25797780, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25812499, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25816720, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25834499, ["Country", "Country_source"]] = fix_country_from_text("Türkiye")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25850768, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25858894, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25868368, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25869615, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25875140, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25897338, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25901726, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25907051, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25908915, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25909171, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25921476, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25934025, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25973438, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25977170, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25982297, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25985329, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25987018, ["Country", "Country_source"]] = fix_country_from_text("Malaysia")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 25990510, ["Country", "Country_source"]] = fix_country_from_text("Antigua and Barbuda")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 26021434, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2500000.loc[df_parsedX_2500000["PMID"] == 26031946, ["Country", "Country_source"]] = fix_country_from_text("Russia")

# %%
df_parsedX_2500000.to_csv(DF_input + "parsedX_2500000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_2600000.csv*

# %%
# Read csv
df_parsedX_2600000 = pd.read_csv(DF_input + "parsedX_2600000.csv")
# Out:
# C:\Users\svalb\AppData\Local\Temp\ipykernel_4388\3281321585.py:2: DtypeWarning: Columns (13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_parsedX_2600000 = pd.read_csv(DF_input + "parsedX_2600000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26040477, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26045106, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26062012, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26075074, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26106000, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26120755, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26131061, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26153557, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26155313, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26189409, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26197742, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26199235, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26199239, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26204471, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26217940, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26232449, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26237064, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26240016, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26250636, ["Country", "Country_source"]] = fix_country_from_text("Marshall Islands")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26259855, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26260073, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26268885, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26278877, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26301700, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26307250, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26308229, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26336963, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26338776, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26339402, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26343440, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26345565, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26358820, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26359135, ["Country", "Country_source"]] = fix_country_from_text("Denmark")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26363177, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26370523, ["Country", "Country_source"]] = fix_country_from_text("Kazakhstan")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26374531, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26386124, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26397740, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26410890, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26411953, ["Country", "Country_source"]] = fix_country_from_text("India")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26432074, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26438540, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26440682, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26449252, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26450700, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26458440, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26462506, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26462763, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26469354, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26485776, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26485781, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26485783, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26486570, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26488693, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26489541, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26503995, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26510188, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26521120, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26525327, ["Country", "Country_source"]] = fix_country_from_text("Armenia")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26537163, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26545657, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26563484, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26591546, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26594976, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26598879, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26600177, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26602394, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26607263, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26622680, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26628199, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26659608, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26664661, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26674784, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26675240, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26685318, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26685321, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26694554, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26699303, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26700783, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26707089, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26707131, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2600000.loc[df_parsedX_2600000["PMID"] == 26709641, ["Country", "Country_source"]] = fix_country_from_text("United States")

# %%
df_parsedX_2600000.to_csv(DF_input + "parsedX_2600000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_2700000.csv*

# %%
# Read csv
df_parsedX_2700000 = pd.read_csv(DF_input + "parsedX_2700000.csv")
# Out:
# C:\Users\svalb\AppData\Local\Temp\ipykernel_4388\3473263253.py:2: DtypeWarning: Columns (13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_parsedX_2700000 = pd.read_csv(DF_input + "parsedX_2700000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 26776828, ["Country", "Country_source"]] = fix_country_from_text("Singapore")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 26795401, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 26797750, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 26800896, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 26801633, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 26809528, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 26809530, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 26821251, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 26823700, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 26825869, ["Country", "Country_source"]] = fix_country_from_text("Sweden")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 26838258, ["Country", "Country_source"]] = fix_country_from_text("Togo")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 26849815, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 26853532, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 26853980, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 26856920, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 26862641, ["Country", "Country_source"]] = fix_country_from_text("Kenya")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 26864113, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 26870275, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 26880429, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 26906132, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 26917721, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 26925640, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 26936374, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 26937671, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 26941840, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 26956035, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 26967053, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 26971878, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 26978472, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 26985849, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 26993776, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 27002946, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 27027335, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 27032703, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 27067681, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 27067842, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 27069431, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 27070165, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 27070875, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 27072426, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 27096274, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 27133967, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 27148412, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 27149525, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 27158413, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 27161304, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 27167343, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 27179445, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 27209087, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 27210082, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 27210101, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 27220800, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 27227932, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 27246977, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 27254880, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 27255383, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 27257421, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 27285759, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 27306822, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 27318391, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 27334855, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 27372883, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 27373783, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 27380806, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 27382221, ["Country", "Country_source"]] = fix_country_from_text("India")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 27383100, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 27398318, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2700000.loc[df_parsedX_2700000["PMID"] == 27416805, ["Country", "Country_source"]] = fix_country_from_text("China")

# %%
df_parsedX_2700000.to_csv(DF_input + "parsedX_2700000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_2800000.csv*

# %%
# Read csv
df_parsedX_2800000 = pd.read_csv(DF_input + "parsedX_2800000.csv")
# Out:
# C:\Users\svalb\AppData\Local\Temp\ipykernel_4388\885282449.py:2: DtypeWarning: Columns (13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_parsedX_2800000 = pd.read_csv(DF_input + "parsedX_2800000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27433557, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27460496, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27484217, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27498865, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27542766, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27547644, ["Country", "Country_source"]] = fix_country_from_text("Poland")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27557497, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27577439, ["Country", "Country_source"]] = fix_country_from_text("Ireland")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27581780, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27584619, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27599422, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27600778, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27628550, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27655907, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27659325, ["Country", "Country_source"]] = fix_country_from_text("India")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27666593, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27678311, ["Country", "Country_source"]] = fix_country_from_text("Uruguay")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27699931, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27702837, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27725583, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27736623, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27745554, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27760933, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27765756, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27780612, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27784781, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27811191, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27816200, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27826198, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27829598, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27840896, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27856337, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27877240, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27880930, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27882192, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27886951, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27893210, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27899772, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27909713, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27913500, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27919796, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27935768, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27941289, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27959429, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27974698, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27980082, ["Country", "Country_source"]] = fix_country_from_text("Singapore")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27991985, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 27999612, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 28008897, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 28025583, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 28035349, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 28050152, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 28076328, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 28100683, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 28112375, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 28121454, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 28125872, ["Country", "Country_source"]] = fix_country_from_text("Türkiye")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 28169022, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 28174378, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 28174490, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2800000.loc[df_parsedX_2800000["PMID"] == 28204832, ["Country", "Country_source"]] = fix_country_from_text("China")

# %%
df_parsedX_2800000.to_csv(DF_input + "parsedX_2800000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_2900000.csv*

# %%
# Read csv
df_parsedX_2900000 = pd.read_csv(DF_input + "parsedX_2900000.csv")
# Out:
# C:\Users\svalb\AppData\Local\Temp\ipykernel_4388\4036662242.py:2: DtypeWarning: Columns (13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_parsedX_2900000 = pd.read_csv(DF_input + "parsedX_2900000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28216519, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28228693, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28231055, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28235803, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28250921, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28260708, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28270296, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28270720, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28277626, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28277627, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28292114, ["Country", "Country_source"]] = fix_country_from_text("Uganda")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28292993, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28292999, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28296727, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28303874, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28315542, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28315766, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28338065, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28339081, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28340734, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28342951, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28345504, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28346885, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28358374, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28359013, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28361159, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28373752, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28382174, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28386361, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28389722, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28396577, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28398582, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28400542, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28400543, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28400545, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28408288, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28411630, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28419328, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28423538, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28430350, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28430988, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28431392, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28432593, ["Country", "Country_source"]] = fix_country_from_text("Sweden")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28432899, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28441715, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28445933, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28454414, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28458284, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28470874, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28484168, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28486390, ["Country", "Country_source"]] = fix_country_from_text("Greece")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28490384, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28506287, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28521363, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28529265, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28529642, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28533367, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28535659, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28536329, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28553110, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28560063, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28560416, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28564636, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28569906, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28579592, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28591817, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28591818, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28592763, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28600128, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28601388, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28602395, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28612597, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28620565, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28635239, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28635976, ["Country", "Country_source"]] = fix_country_from_text("Kuwait")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28638777, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28656000, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28661554, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28664586, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28666315, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28670507, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28676609, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28676623, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28682833, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28694351, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28698434, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28698435, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28708234, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28710916, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28716524, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28724667, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28725161, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28725243, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28739762, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28739768, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28741732, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28771052, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28781265, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28790255, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28792815, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28802022, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28802175, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28805780, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28818096, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28818111, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28829821, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28836864, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28838206, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28839461, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28845017, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28857613, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28860428, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28860472, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_2900000.loc[df_parsedX_2900000["PMID"] == 28860822, ["Country", "Country_source"]] = fix_country_from_text("China")

# %%
df_parsedX_2900000.to_csv(DF_input + "parsedX_2900000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_300000.csv*

# %%
# Read csv
df_parsedX_300000 = pd.read_csv(DF_input + "parsedX_300000.csv")
# Out:
# C:\Users\svalb\AppData\Local\Temp\ipykernel_4388\2581632480.py:2: DtypeWarning: Columns (13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_parsedX_300000 = pd.read_csv(DF_input + "parsedX_300000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2691731, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2691733, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2693732, ["Country", "Country_source"]] = fix_country_from_text("Georgia")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2698617, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2701089, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2704119, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2704122, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2704334, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2709162, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2713239, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2716918, ["Country", "Country_source"]] = fix_country_from_text("Georgia")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2724549, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2729068, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2730010, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2730015, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2730025, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2730026, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2730029, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2730051, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2730069, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2730125, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2733166, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2733167, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2733171, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2738748, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2751016, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2751316, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2751647, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2757750, ["Country", "Country_source"]] = fix_country_from_text("Ireland")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2758566, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2761294, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2763307, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2769228, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2777677, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2784353, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2787007, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2788492, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2797101, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2803467, ["Country", "Country_source"]] = fix_country_from_text("Ireland")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2804347, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2810824, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2811726, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2813767, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2816139, ["Country", "Country_source"]] = fix_country_from_text("Latvia")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2819616, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2821179, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2822295, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2822639, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2823722, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2824028, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2824028, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2826545, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2826848, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2828292, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2832635, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2833322, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2836347, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2837984, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2837991, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2839114, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2839268, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2842523, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2843076, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2843111, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2845167, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2845981, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2848045, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2849692, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2850125, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2852926, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2890401, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2892820, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2892821, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2895197, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2898464, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2900827, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2902832, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2904243, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2912937, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2921815, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2924577, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2926980, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2929620, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2930203, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2930698, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2961953, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 2966880, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3045278, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3045373, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3053368, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3056751, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3061548, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3063084, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3077607, ["Country", "Country_source"]] = fix_country_from_text("Hungary")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3115923, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3115934, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3117083, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3117753, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3119539, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3121555, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3121614, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3123435, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3123440, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3124221, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3125971, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3128501, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3129071, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3130346, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3130357, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3130359, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3132755, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3132855, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3133332, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3133334, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3134934, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3136114, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3137192, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3137193, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3137715, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3139593, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3142832, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3143696, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3143697, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3148595, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3152965, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3153218, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3153306, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3154010, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3154011, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3163243, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3163932, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3166209, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3167415, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3167848, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3171722, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3172494, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3174980, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3174981, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3176073, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3178267, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3180148, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3181836, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3182311, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3190250, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3191367, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3196041, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3204685, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3209130, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3211930, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3222465, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3224607, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3256301, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3260091, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3260255, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3269054, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3269737, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3273416, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3278084, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3278121, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3281824, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3282566, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3282650, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3284798, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3287843, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3290821, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3294389, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3310905, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3326376, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3339851, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3345785, ["Country", "Country_source"]] = fix_country_from_text("Georgia")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3354578, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3358989, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3359452, ["Country", "Country_source"]] = fix_country_from_text("Ireland")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3366488, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3369339, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3373350, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3374170, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3379782, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3381784, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3381837, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3382203, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3382212, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3382226, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3382231, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3382232, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3385920, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3386561, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3386578, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3393551, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3395586, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3396259, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3396274, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3396292, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3400078, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3409164, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_300000.loc[df_parsedX_300000["PMID"] == 3410704, ["Country", "Country_source"]] = fix_country_from_text("United States")

# %%
df_parsedX_300000.to_csv(DF_input + "parsedX_300000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_3000000.csv*

# %%
# Read csv
df_parsedX_3000000 = pd.read_csv(DF_input + "parsedX_3000000.csv")
# Out:
# C:\Users\svalb\AppData\Local\Temp\ipykernel_4388\3891522716.py:2: DtypeWarning: Columns (13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_parsedX_3000000 = pd.read_csv(DF_input + "parsedX_3000000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 28882179, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 28883270, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 28883282, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 28912395, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 28912397, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 28915640, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 28918038, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 28918670, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 28944929, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 28945850, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 28953447, ["Country", "Country_source"]] = fix_country_from_text("France")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 28961842, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 28967066, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 28978845, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 28978856, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 28981729, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 28981730, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 28988062, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 28990489, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29020068, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29020511, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29034885, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29036613, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29037218, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29040555, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29045685, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29057772, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29058129, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29059382, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29066671, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29070080, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29070416, ["Country", "Country_source"]] = fix_country_from_text("Switzerland")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29080431, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29083976, ["Country", "Country_source"]] = fix_country_from_text("Belgium")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29109146, ["Country", "Country_source"]] = fix_country_from_text("Belgium")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29113215, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29136177, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29136453, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29138368, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29138375, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29138572, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29142184, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29162344, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29163697, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29173759, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29177209, ["Country", "Country_source"]] = fix_country_from_text("Bangladesh")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29196102, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29199237, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29204169, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29206595, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29217398, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29225308, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29232802, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29238222, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29242759, ["Country", "Country_source"]] = fix_country_from_text("Republic of Palau")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29245119, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29251666, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29262567, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29262878, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29267651, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29270023, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29278911, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29323599, ["Country", "Country_source"]] = fix_country_from_text("Switzerland")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29329114, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29331416, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29351631, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29360661, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29362296, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29382381, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29393411, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29397340, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29399411, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29402755, ["Country", "Country_source"]] = fix_country_from_text("Singapore")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29405054, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29416840, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29423058, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29431541, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29435015, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29437271, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29442710, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29445583, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29452124, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29453281, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29474549, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29483499, ["Country", "Country_source"]] = fix_country_from_text("Belarus")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29486176, ["Country", "Country_source"]] = fix_country_from_text("Laos")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29490794, ["Country", "Country_source"]] = fix_country_from_text("Switzerland")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29507627, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29511447, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29516981, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29541212, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3000000.loc[df_parsedX_3000000["PMID"] == 29545717, ["Country", "Country_source"]] = fix_country_from_text("China")

# %%
df_parsedX_3000000.to_csv(DF_input + "parsedX_3000000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_3100000.csv*

# %%
# Read csv
df_parsedX_3100000 = pd.read_csv(DF_input + "parsedX_3100000.csv")
# Out:
# C:\Users\svalb\AppData\Local\Temp\ipykernel_4388\464466689.py:2: DtypeWarning: Columns (13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_parsedX_3100000 = pd.read_csv(DF_input + "parsedX_3100000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29565466, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29593407, ["Country", "Country_source"]] = fix_country_from_text("India")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29607823, ["Country", "Country_source"]] = fix_country_from_text("United Arab Emirates")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29607939, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29625409, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29649076, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29650894, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29650898, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29650901, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29656187, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29658607, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29659425, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29667385, ["Country", "Country_source"]] = fix_country_from_text("Poland")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29674733, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29675182, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29675235, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29684149, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29687772, ["Country", "Country_source"]] = fix_country_from_text("Serbia")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29689653, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29691486, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29693134, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29707993, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29732153, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29739712, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29753008, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29764514, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29767247, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29787516, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29788168, ["Country", "Country_source"]] = fix_country_from_text("France")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29803104, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29843792, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29849811, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29861611, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29861639, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29868161, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29872807, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29877246, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29885177, ["Country", "Country_source"]] = fix_country_from_text("India")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29887585, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29903923, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29906308, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29907572, ["Country", "Country_source"]] = fix_country_from_text("Taiwan")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29917193, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29923189, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29930434, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29951453, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29958123, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29959897, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29970165, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29977542, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29978648, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29978870, ["Country", "Country_source"]] = fix_country_from_text("Netherlands")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29985345, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29985366, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29986113, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 29989649, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 30004218, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 30006164, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 30008598, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 30012846, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 30026408, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 30026422, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 30026428, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 30026442, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 30026825, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 30042272, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 30046670, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 30061088, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 30075827, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 30076181, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 30077214, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 30088188, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 30104348, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 30108422, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 30114878, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 30147001, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 30149376, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 30152006, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 30154244, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 30155143, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 30158409, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 30165187, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 30165555, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 30171052, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 30174831, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 30185712, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 30202955, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 30237359, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 30237364, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 30237375, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3100000.loc[df_parsedX_3100000["PMID"] == 30247463, ["Country", "Country_source"]] = fix_country_from_text("United States")

# %%
df_parsedX_3100000.to_csv(DF_input + "parsedX_3100000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_3200000.csv*

# %%
# Read csv
df_parsedX_3200000 = pd.read_csv(DF_input + "parsedX_3200000.csv")
# Out:
# C:\Users\svalb\AppData\Local\Temp\ipykernel_4388\1690115169.py:2: DtypeWarning: Columns (13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_parsedX_3200000 = pd.read_csv(DF_input + "parsedX_3200000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30263847, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30272643, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30275772, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30293547, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30305516, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30305518, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30305539, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30305565, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30305567, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30364362, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30369427, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30371720, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30376625, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30380023, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30381714, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30382031, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30382033, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30390573, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30408543, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30420181, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30430016, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30447909, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30449839, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30453160, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30453865, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30473645, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30487219, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30499751, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30501701, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30502627, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30508942, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30510363, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30510367, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30510851, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30520956, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30521071, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30529304, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30531102, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30531143, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30538546, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30544294, ["Country", "Country_source"]] = fix_country_from_text("Switzerland")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30558010, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30570865, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30587725, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30589990, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30606259, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30623908, ["Country", "Country_source"]] = fix_country_from_text("Pakistan")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30626853, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30651289, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30664052, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30668892, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30675274, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30689702, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30694915, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30699267, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30699269, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30699277, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30700931, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30712649, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30737779, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30745258, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30745548, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30763716, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30765635, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30790289, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30793198, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30799850, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30799955, ["Country", "Country_source"]] = fix_country_from_text("Sweden")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30814910, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30828047, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30839356, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30854141, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30864715, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30875484, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_3200000.loc[df_parsedX_3200000["PMID"] == 30891558, ["Country", "Country_source"]] = fix_country_from_text("United States")

# %%
df_parsedX_3200000.to_csv(DF_input + "parsedX_3200000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_3300000.csv*

# %%
# Read csv
df_parsedX_3300000 = pd.read_csv(DF_input + "parsedX_3300000.csv")
# Out:
# C:\Users\svalb\AppData\Local\Temp\ipykernel_4388\556119615.py:2: DtypeWarning: Columns (13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_parsedX_3300000 = pd.read_csv(DF_input + "parsedX_3300000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 30914578, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 30927622, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 30940189, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 30940199, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 30942201, ["Country", "Country_source"]] = fix_country_from_text("Netherlands")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 30946966, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 30958961, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31007741, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31033799, ["Country", "Country_source"]] = fix_country_from_text("Türkiye")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31040152, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31042686, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31043829, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31060406, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31093047, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31105995, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31127989, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31151062, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31164495, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31171907, ["Country", "Country_source"]] = fix_country_from_text("Malaysia")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31184976, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31185150, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31185151, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31186680, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31186682, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31189800, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31189809, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31196254, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31215209, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31229873, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31253728, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31261446, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31271488, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31273162, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31273167, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31276336, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31276338, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31277094, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31277111, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31281144, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31282590, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31289523, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31289547, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31296833, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31315906, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31322846, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31332011, ["Country", "Country_source"]] = fix_country_from_text("Austria")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31334982, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31335687, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31346366, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31370083, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31377667, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31391375, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31398615, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31400325, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31413752, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31413834, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31415235, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31431216, ["Country", "Country_source"]] = fix_country_from_text("Switzerland")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31434853, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31440046, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31443740, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31445803, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31454542, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31471384, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31479603, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31501366, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31516591, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31516713, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31530778, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31535847, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31539127, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31544511, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3300000.loc[df_parsedX_3300000["PMID"] == 31544918, ["Country", "Country_source"]] = fix_country_from_text("China")

# %%
df_parsedX_3300000.to_csv(DF_input + "parsedX_3300000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_3400000.csv*

# %%
# Read csv
df_parsedX_3400000 = pd.read_csv(DF_input + "parsedX_3400000.csv")
# Out:
# C:\Users\svalb\AppData\Local\Temp\ipykernel_4388\2580815593.py:2: DtypeWarning: Columns (13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_parsedX_3400000 = pd.read_csv(DF_input + "parsedX_3400000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31552119, ["Country", "Country_source"]] = fix_country_from_text("Uganda")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31553165, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31563418, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31584185, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31588056, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31601265, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31602263, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31602900, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31611957, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31612019, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31631124, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31631132, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31631133, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31642614, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31662326, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31665670, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31725893, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31735752, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31743457, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31746400, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31748473, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31748479, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31756778, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31772161, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31780392, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31785819, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31800546, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31808637, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31808917, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31812872, ["Country", "Country_source"]] = fix_country_from_text("Belgium")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31821060, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31823663, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31826531, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31827988, ["Country", "Country_source"]] = fix_country_from_text("Türkiye")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31843683, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31876953, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31899205, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31902811, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31903125, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31911077, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31926788, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31929504, ["Country", "Country_source"]] = fix_country_from_text("Switzerland")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31932192, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31933987, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31935398, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31938151, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31938270, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31944405, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31949210, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31972012, ["Country", "Country_source"]] = fix_country_from_text("Belgium")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31987158, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31990457, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 31994495, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 32011399, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 32011400, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 32011550, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 32031005, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 32065128, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 32065882, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 32077901, ["Country", "Country_source"]] = fix_country_from_text("Singapore")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 32087309, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 32104581, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 32104588, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 32115643, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 32127800, ["Country", "Country_source"]] = fix_country_from_text("Botswana")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 32135639, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3400000.loc[df_parsedX_3400000["PMID"] == 32150272, ["Country", "Country_source"]] = fix_country_from_text("Mexico")

# %%
df_parsedX_3400000.to_csv(DF_input + "parsedX_3400000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_3500000.csv*

# %%
# Read csv
df_parsedX_3500000 = pd.read_csv(DF_input + "parsedX_3500000.csv")
# Out:
# C:\Users\svalb\AppData\Local\Temp\ipykernel_4388\3586501621.py:2: DtypeWarning: Columns (13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_parsedX_3500000 = pd.read_csv(DF_input + "parsedX_3500000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32180433, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32186405, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32194790, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32195840, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32196002, ["Country", "Country_source"]] = fix_country_from_text("Malawi")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32208668, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32215053, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32227728, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32233751, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32236948, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32237333, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32238680, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32250351, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32256791, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32261095, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32262541, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32272148, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32297743, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32323844, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32324265, ["Country", "Country_source"]] = fix_country_from_text("Saudi Arabia")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32337324, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32355577, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32359212, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32375473, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32377704, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32378637, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32378664, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32381907, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32382348, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32389956, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32392590, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32401292, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32408319, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32432738, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32434692, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32436611, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32443117, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32453195, ["Country", "Country_source"]] = fix_country_from_text("South Africa")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32459781, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32467316, ["Country", "Country_source"]] = fix_country_from_text("Austria")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32468036, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32480224, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32482215, ["Country", "Country_source"]] = fix_country_from_text("Switzerland")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32512997, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32513428, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32527549, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32541171, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32546257, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32552926, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32566013, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32568693, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32569041, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32571289, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32624167, ["Country", "Country_source"]] = fix_country_from_text("Morocco")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32626522, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32629674, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32651542, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32654950, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32655115, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32662817, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32665167, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32667645, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32668851, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32670413, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32694236, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32707136, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32719865, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32725692, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32732540, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32736229, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32750245, ["Country", "Country_source"]] = fix_country_from_text("Hungary")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32756099, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32759558, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32779487, ["Country", "Country_source"]] = fix_country_from_text("Austria")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32782573, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32788939, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32789038, ["Country", "Country_source"]] = fix_country_from_text("Pakistan")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32794591, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32795280, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32802440, ["Country", "Country_source"]] = fix_country_from_text("Taiwan")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32804282, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_3500000.loc[df_parsedX_3500000["PMID"] == 32810031, ["Country", "Country_source"]] = fix_country_from_text("China")

# %%
df_parsedX_3500000.to_csv(DF_input + "parsedX_3500000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_3600000.csv*

# %%
# Read csv
df_parsedX_3600000 = pd.read_csv(DF_input + "parsedX_3600000.csv")
# Out:
# C:\Users\svalb\AppData\Local\Temp\ipykernel_4388\2731050640.py:2: DtypeWarning: Columns (13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_parsedX_3600000 = pd.read_csv(DF_input + "parsedX_3600000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 32820651, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 32826390, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 32832641, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 32836201, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 32838753, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 32843638, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 32845581, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 32846759, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 32852469, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 32867821, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 32886754, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 32898320, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 32898795, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 32901853, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 32908053, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 32913471, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 32915978, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 32920340, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 32944452, ["Country", "Country_source"]] = fix_country_from_text("Pakistan")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 32957402, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 32982583, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 32985499, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 32999254, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33000263, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33009697, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33011800, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33014156, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33014912, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33022039, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33029072, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33048119, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33060391, ["Country", "Country_source"]] = fix_country_from_text("Türkiye")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33080727, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33085843, ["Country", "Country_source"]] = fix_country_from_text("Singapore")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33125211, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33127094, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33130692, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33131541, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33155136, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33162493, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33165271, ["Country", "Country_source"]] = fix_country_from_text("South Africa")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33173969, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33193890, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33193891, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33194073, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33209857, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33223238, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33229902, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33230509, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33230973, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33252825, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33264481, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33268729, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33268739, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33314747, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33315692, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33323378, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33340437, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33342942, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33342975, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33342984, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33370682, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33383500, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33384111, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33395025, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33417086, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33425353, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33427756, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33429799, ["Country", "Country_source"]] = fix_country_from_text("Türkiye")
df_parsedX_3600000.loc[df_parsedX_3600000["PMID"] == 33443863, ["Country", "Country_source"]] = fix_country_from_text("Japan")

# %%
df_parsedX_3600000.to_csv(DF_input + "parsedX_3600000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_3700000.csv*

# %%
# Read csv
df_parsedX_3700000 = pd.read_csv(DF_input + "parsedX_3700000.csv")
# Out:
# C:\Users\svalb\AppData\Local\Temp\ipykernel_4388\3819988390.py:2: DtypeWarning: Columns (13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_parsedX_3700000 = pd.read_csv(DF_input + "parsedX_3700000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33461720, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33468665, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33468715, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33468716, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33468724, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33472322, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33473189, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33475487, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33476486, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33491616, ["Country", "Country_source"]] = fix_country_from_text("United Arab Emirates")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33501779, ["Country", "Country_source"]] = fix_country_from_text("Peru")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33512952, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33533212, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33551423, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33551426, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33558426, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33560312, ["Country", "Country_source"]] = fix_country_from_text("Singapore")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33567168, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33570246, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33574925, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33574947, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33595372, ["Country", "Country_source"]] = fix_country_from_text("Singapore")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33597359, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33617721, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33650320, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33662780, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33663097, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33690219, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33727227, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33732415, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33744050, ["Country", "Country_source"]] = fix_country_from_text("Singapore")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33747529, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33763698, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33778757, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33780630, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33790153, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33790156, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33793113, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33798550, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33835975, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33853831, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33882542, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33900375, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33949412, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33959428, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33965974, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33973887, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33976028, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 33976029, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 34002778, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 34006702, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 34007336, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 34012527, ["Country", "Country_source"]] = fix_country_from_text("Indonesia")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 34019391, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 34026227, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 34028925, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 34046601, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 34077156, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 34084224, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 34092557, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 34092563, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 34097307, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3700000.loc[df_parsedX_3700000["PMID"] == 34098593, ["Country", "Country_source"]] = fix_country_from_text("Mexico")

# %%
df_parsedX_3700000.to_csv(DF_input + "parsedX_3700000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_3800000.csv*

# %%
# Read csv
df_parsedX_3800000 = pd.read_csv(DF_input + "parsedX_3800000.csv")
# Out:
# C:\Users\svalb\AppData\Local\Temp\ipykernel_4388\2647766763.py:2: DtypeWarning: Columns (13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_parsedX_3800000 = pd.read_csv(DF_input + "parsedX_3800000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34108321, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34126137, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34139611, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34139716, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34139727, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34144278, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34145257, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34146456, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34155147, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34177097, ["Country", "Country_source"]] = fix_country_from_text("Malaysia")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34180219, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34183205, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34195379, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34216153, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34218242, ["Country", "Country_source"]] = fix_country_from_text("Ukraine")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34219088, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34228983, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34242966, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34251160, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34258114, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34269356, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34278498, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34279092, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34290914, ["Country", "Country_source"]] = fix_country_from_text("Pakistan")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34297660, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34298834, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34305060, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34316378, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34330299, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34340593, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34343344, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34347390, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34364224, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34369132, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34371506, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34394250, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34394252, ["Country", "Country_source"]] = fix_country_from_text("Türkiye")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34399040, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34404764, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34411393, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34412920, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34415858, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34415882, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34422466, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34450664, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34469907, ["Country", "Country_source"]] = fix_country_from_text("Ukraine")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34472219, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34474280, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34475252, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34497198, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34497239, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34512155, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34521011, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34525964, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34532049, ["Country", "Country_source"]] = fix_country_from_text("Ukraine")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34537516, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34543875, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34551640, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34567566, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34569224, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34587434, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34602188, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34617446, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34619905, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34623385, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34623797, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34628756, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34636753, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34641822, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34643369, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34648220, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34653697, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34655924, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34657046, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34657061, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34657951, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34665942, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34668694, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34671219, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34690245, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34704726, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34709717, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34714278, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34721687, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34736664, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3800000.loc[df_parsedX_3800000["PMID"] == 34753106, ["Country", "Country_source"]] = fix_country_from_text("China")

# %%
df_parsedX_3800000.to_csv(DF_input + "parsedX_3800000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_3900000.csv*

# %%
# Read csv
df_parsedX_3900000 = pd.read_csv(DF_input + "parsedX_3900000.csv")
# Out:
# C:\Users\svalb\AppData\Local\Temp\ipykernel_4388\2707836882.py:2: DtypeWarning: Columns (13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_parsedX_3900000 = pd.read_csv(DF_input + "parsedX_3900000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 34759262, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 34794576, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 34794884, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 34800099, ["Country", "Country_source"]] = fix_country_from_text("Türkiye")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 34815753, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 34839647, ["Country", "Country_source"]] = fix_country_from_text("Morocco")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 34873461, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 34882211, ["Country", "Country_source"]] = fix_country_from_text("Belgium")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 34887372, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 34894107, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 34897183, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 34911877, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 34911905, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 34911910, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 34911913, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 34915428, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 34924476, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 34925852, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 34949310, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 34987143, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 34987928, ["Country", "Country_source"]] = fix_country_from_text("Morocco")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 34991919, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35005121, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35014411, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35014626, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35017181, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35018835, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35024252, ["Country", "Country_source"]] = fix_country_from_text("Greece")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35043660, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35044111, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35046214, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35046359, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35057760, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35067517, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35077067, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35092156, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35099678, ["Country", "Country_source"]] = fix_country_from_text("Sweden")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35103624, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35112749, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35133364, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35150127, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35169083, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35171857, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35188381, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35191194, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35191403, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35195958, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35198316, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35198747, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35224157, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35251351, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35252797, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35253473, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35283319, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35293596, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35296600, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35299179, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35299180, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35313274, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35325345, ["Country", "Country_source"]] = fix_country_from_text("Sweden")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35362384, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35362692, ["Country", "Country_source"]] = fix_country_from_text("Türkiye")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35382161, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_3900000.loc[df_parsedX_3900000["PMID"] == 35386167, ["Country", "Country_source"]] = fix_country_from_text("Japan")

# %%
df_parsedX_3900000.to_csv(DF_input + "parsedX_3900000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_400000.csv*

# %%
# Read csv
df_parsedX_400000 = pd.read_csv(DF_input + "parsedX_400000.csv")
# Out:
# C:\Users\svalb\AppData\Local\Temp\ipykernel_4388\26203809.py:2: DtypeWarning: Columns (13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_parsedX_400000 = pd.read_csv(DF_input + "parsedX_400000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_400000.loc[df_parsedX_400000["PMID"] == 3411785, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_400000.loc[df_parsedX_400000["PMID"] == 3411789, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_400000.loc[df_parsedX_400000["PMID"] == 3412898, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_400000.loc[df_parsedX_400000["PMID"] == 3412899, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_400000.loc[df_parsedX_400000["PMID"] == 3424272, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_400000.loc[df_parsedX_400000["PMID"] == 3425525, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_400000.loc[df_parsedX_400000["PMID"] == 3425601, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_400000.loc[df_parsedX_400000["PMID"] == 3428671, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_400000.loc[df_parsedX_400000["PMID"] == 3440256, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_400000.loc[df_parsedX_400000["PMID"] == 3442946, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_400000.loc[df_parsedX_400000["PMID"] == 3445643, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_400000.loc[df_parsedX_400000["PMID"] == 3447894, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_400000.loc[df_parsedX_400000["PMID"] == 3478074, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_400000.loc[df_parsedX_400000["PMID"] == 3478088, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_400000.loc[df_parsedX_400000["PMID"] == 3479948, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_400000.loc[df_parsedX_400000["PMID"] == 3499584, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_400000.loc[df_parsedX_400000["PMID"] == 3508181, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_400000.loc[df_parsedX_400000["PMID"] == 3657225, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_400000.loc[df_parsedX_400000["PMID"] == 3657931, ["Country", "Country_source"]] = fix_country_from_text("Estonia")
df_parsedX_400000.loc[df_parsedX_400000["PMID"] == 3658046, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_400000.loc[df_parsedX_400000["PMID"] == 3666675, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_400000.loc[df_parsedX_400000["PMID"] == 3669763, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_400000.loc[df_parsedX_400000["PMID"] == 3673339, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_400000.loc[df_parsedX_400000["PMID"] == 3674895, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_400000.loc[df_parsedX_400000["PMID"] == 3676681, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_400000.loc[df_parsedX_400000["PMID"] == 3681511, ["Country", "Country_source"]] = fix_country_from_text("France")
df_parsedX_400000.loc[df_parsedX_400000["PMID"] == 3682867, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_400000.loc[df_parsedX_400000["PMID"] == 3682868, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_400000.loc[df_parsedX_400000["PMID"] == 3687952, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_400000.loc[df_parsedX_400000["PMID"] == 3690970, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_400000.loc[df_parsedX_400000["PMID"] == 3691330, ["Country", "Country_source"]] = fix_country_from_text("Germany")

# %%
df_parsedX_400000.to_csv(DF_input + "parsedX_400000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_4000000.csv*

# %%
# Read csv
df_parsedX_4000000 = pd.read_csv(DF_input + "parsedX_4000000.csv")
# Out:
# C:\Users\svalb\AppData\Local\Temp\ipykernel_4388\3123405976.py:2: DtypeWarning: Columns (13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_parsedX_4000000 = pd.read_csv(DF_input + "parsedX_4000000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35411632, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35438905, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35449176, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35526510, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35527932, ["Country", "Country_source"]] = fix_country_from_text("Switzerland")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35540074, ["Country", "Country_source"]] = fix_country_from_text("Switzerland")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35540326, ["Country", "Country_source"]] = fix_country_from_text("India")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35550912, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35559784, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35559944, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35570408, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35577159, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35578854, ["Country", "Country_source"]] = fix_country_from_text("Malaysia")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35578934, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35583119, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35589662, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35606169, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35613346, ["Country", "Country_source"]] = fix_country_from_text("Belarus")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35618211, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35620214, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35623786, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35633271, ["Country", "Country_source"]] = fix_country_from_text("Republic of Maldives")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35637799, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35640117, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35657137, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35661985, ["Country", "Country_source"]] = fix_country_from_text("Slovakia")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35662168, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35663144, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35667572, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35695661, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35698679, ["Country", "Country_source"]] = fix_country_from_text("Türkiye")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35702054, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35702640, ["Country", "Country_source"]] = fix_country_from_text("India")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35702752, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35706368, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35709897, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35718452, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35726827, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35729682, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35731019, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35733494, ["Country", "Country_source"]] = fix_country_from_text("Morocco")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35748232, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35756163, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35759755, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35788277, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35788325, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35793148, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35811121, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35811500, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35815797, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35819392, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35820297, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35831964, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35831967, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35842389, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35848447, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35850506, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35851339, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35858784, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35880856, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35887149, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35899681, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35900786, ["Country", "Country_source"]] = fix_country_from_text("Belgium")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35908902, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35909002, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35932642, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35939825, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35940360, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35943859, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35943962, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35950297, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35952476, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35952578, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35961071, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35963698, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35975322, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35993846, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35996814, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 35999213, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 36037385, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 36043698, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 36047666, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 36058855, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 36058859, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 36059354, ["Country", "Country_source"]] = fix_country_from_text("Saudi Arabia")
df_parsedX_4000000.loc[df_parsedX_4000000["PMID"] == 36059382, ["Country", "Country_source"]] = fix_country_from_text("Brazil")

# %%
df_parsedX_4000000.to_csv(DF_input + "parsedX_4000000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_4100000.csv*

# %%
# Read csv
df_parsedX_4100000 = pd.read_csv(DF_input + "parsedX_4100000.csv")
# Out:
# C:\Users\svalb\AppData\Local\Temp\ipykernel_4388\121223794.py:2: DtypeWarning: Columns (13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_parsedX_4100000 = pd.read_csv(DF_input + "parsedX_4100000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36070661, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36091685, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36096693, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36106295, ["Country", "Country_source"]] = fix_country_from_text("Morocco")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36121279, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36125400, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36183205, ["Country", "Country_source"]] = fix_country_from_text("Spain ")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36188121, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36198530, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36200417, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36206141, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36210795, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36214815, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36217664, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36217885, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36226500, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36246416, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36250677, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36265321, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36268179, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36281589, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36281592, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36281593, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36281596, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36310059, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36368902, ["Country", "Country_source"]] = fix_country_from_text("Sweden")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36376175, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36377590, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36412020, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36413416, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36414993, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36436924, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36436937, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36448054, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36461237, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36464293, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36466039, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36480783, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36484099, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36494187, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36495506, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36534728, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36565460, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36574975, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36576108, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36610262, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36624003, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36628321, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36631115, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36632627, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36634853, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36653138, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36653530, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36670112, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36682813, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36687347, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36698118, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36707770, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4100000.loc[df_parsedX_4100000["PMID"] == 36720232, ["Country", "Country_source"]] = fix_country_from_text("Germany")

# %%
df_parsedX_4100000.to_csv(DF_input + "parsedX_4100000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_4200000.csv*

# %%
# Read csv
df_parsedX_4200000 = pd.read_csv(DF_input + "parsedX_4200000.csv")
# Out:
# C:\Users\svalb\AppData\Local\Temp\ipykernel_4388\982750643.py:2: DtypeWarning: Columns (13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_parsedX_4200000 = pd.read_csv(DF_input + "parsedX_4200000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 36744219, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 36750071, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 36751242, ["Country", "Country_source"]] = fix_country_from_text("India")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 36751251, ["Country", "Country_source"]] = fix_country_from_text("Saudi Arabia")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 36759980, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 36801760, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 36807158, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 36819187, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 36822668, ["Country", "Country_source"]] = fix_country_from_text("Switzerland")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 36843108, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 36843626, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 36878605, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 36905771, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 36911291, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 36923530, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 36927812, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 36927896, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 36927897, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 36928390, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 36948630, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 36951150, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 36960780, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 36960874, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 36972145, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 36974713, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37012998, ["Country", "Country_source"]] = fix_country_from_text("Switzerland")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37025355, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37032108, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37038094, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37065787, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37066457, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37082450, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37098695, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37113367, ["Country", "Country_source"]] = fix_country_from_text("Egypt")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37121712, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37142086, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37150608, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37152224, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37153059, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37168563, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37169984, ["Country", "Country_source"]] = fix_country_from_text("Netherlands")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37184997, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37200663, ["Country", "Country_source"]] = fix_country_from_text("Morocco")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37212792, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37216157, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37235182, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37246348, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37249048, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37256771, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37258187, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37260331, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37261200, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37261854, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37303421, ["Country", "Country_source"]] = fix_country_from_text("Netherlands")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37310183, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37317597, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37324190, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37327699, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37331794, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37337926, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37341301, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37347499, ["Country", "Country_source"]] = fix_country_from_text("Austria")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37350398, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37365153, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37379365, ["Country", "Country_source"]] = fix_country_from_text("Netherlands")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37394457, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4200000.loc[df_parsedX_4200000["PMID"] == 37398927, ["Country", "Country_source"]] = fix_country_from_text("China")

# %%
df_parsedX_4200000.to_csv(DF_input + "parsedX_4200000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_4300000.csv*

# %%
# Read csv
df_parsedX_4300000 = pd.read_csv(DF_input + "parsedX_4300000.csv")
# Out:
# C:\Users\svalb\AppData\Local\Temp\ipykernel_4388\98432334.py:2: DtypeWarning: Columns (13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_parsedX_4300000 = pd.read_csv(DF_input + "parsedX_4300000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37407475, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37428195, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37428749, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37440245, ["Country", "Country_source"]] = fix_country_from_text("Singapore")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37451504, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37460296, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37486003, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37496217, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37496223, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37499869, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37517364, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37544725, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37545939, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37546129, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37558411, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37558430, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37559588, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37580282, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37608404, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37608407, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37608408, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37611485, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37640994, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37640995, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37640996, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37654145, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37654509, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37667512, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37671301, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37678279, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37696254, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37696627, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37705585, ["Country", "Country_source"]] = fix_country_from_text("Republic of Guyana")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37711956, ["Country", "Country_source"]] = fix_country_from_text("Saudi Arabia")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37738887, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37743327, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37771017, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37772555, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37779508, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37793870, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37793872, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37800290, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37806829, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37807729, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37822427, ["Country", "Country_source"]] = fix_country_from_text("India")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37830863, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37846760, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37872020, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37872055, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37899187, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37899197, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37905623, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37906683, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37907253, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37908917, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37913653, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37928868, ["Country", "Country_source"]] = fix_country_from_text("Burundi")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37942844, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37978881, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 37981322, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 38010143, ["Country", "Country_source"]] = fix_country_from_text("United Arab Emirates")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 38023360, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 38024614, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 38027616, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 38035827, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 38035828, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 38035835, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4300000.loc[df_parsedX_4300000["PMID"] == 38045830, ["Country", "Country_source"]] = fix_country_from_text("China")

# %%
df_parsedX_4300000.to_csv(DF_input + "parsedX_4300000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_4400000.csv*

# %%
# Read csv
df_parsedX_4400000 = pd.read_csv(DF_input + "parsedX_4400000.csv")
# Out:
# C:\Users\svalb\AppData\Local\Temp\ipykernel_4388\67776341.py:2: DtypeWarning: Columns (13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_parsedX_4400000 = pd.read_csv(DF_input + "parsedX_4400000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38076144, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38085798, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38089085, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38089086, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38089449, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38089745, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38089749, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38089760, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38090055, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38090059, ["Country", "Country_source"]] = fix_country_from_text("Türkiye")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38090061, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38090369, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38090370, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38090382, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38090648, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38090650, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38100883, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38114312, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38128545, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38143640, ["Country", "Country_source"]] = fix_country_from_text("Saudi Arabia")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38145685, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38161126, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38171959, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38179374, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38183216, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38189447, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38191182, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38193384, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38194605, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38194883, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38200688, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38223595, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38251671, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38261351, ["Country", "Country_source"]] = fix_country_from_text("Eswatini")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38268998, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38274949, ["Country", "Country_source"]] = fix_country_from_text("United Arab Emirates")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38277843, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38281782, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38296500, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38303276, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38350081, ["Country", "Country_source"]] = fix_country_from_text("Spain")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38375519, ["Country", "Country_source"]] = fix_country_from_text("Antigua and Barbuda")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38394223, ["Country", "Country_source"]] = fix_country_from_text("Malaysia")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38406597, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38416810, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38423673, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38425585, ["Country", "Country_source"]] = fix_country_from_text("India")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38446523, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38449394, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38450305, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38452690, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38454812, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38462465, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38462466, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38462470, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38477105, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38483042, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38490023, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38494799, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38494800, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38494801, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38494803, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38494804, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38494805, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38500053, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38519263, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38531608, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38570395, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38581911, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38599073, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38613908, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38629689, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38629975, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38638751, ["Country", "Country_source"]] = fix_country_from_text("Saudi Arabia")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38640932, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38642885, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38644305, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38645666, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38652001, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38657050, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38659423, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38659557, ["Country", "Country_source"]] = fix_country_from_text("Saudi Arabia")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38666543, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38682088, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38692880, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4400000.loc[df_parsedX_4400000["PMID"] == 38723412, ["Country", "Country_source"]] = fix_country_from_text("China")

# %%
df_parsedX_4400000.to_csv(DF_input + "parsedX_4400000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_4454000.csv*

# %%
# Read csv
df_parsedX_4454000 = pd.read_csv(DF_input + "parsedX_4454000.csv")
# Out:
# C:\Users\svalb\AppData\Local\Temp\ipykernel_4388\3807851422.py:2: DtypeWarning: Columns (13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_parsedX_4454000 = pd.read_csv(DF_input + "parsedX_4454000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 38733544, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 38742358, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 38759317, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 38769544, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 38770016, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 38788718, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 38795813, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 38813272, ["Country", "Country_source"]] = fix_country_from_text("Türkiye")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 38817653, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 38825513, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 38845275, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 38854323, ["Country", "Country_source"]] = fix_country_from_text("Saudi Arabia")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 38881674, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 38883045, ["Country", "Country_source"]] = fix_country_from_text("Saudi Arabia")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 38887964, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 38896789, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 38902768, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 38924542, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 38935830, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 38948113, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 38948246, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 38948247, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 38948248, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 38955104, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 38960645, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 39005059, ["Country", "Country_source"]] = fix_country_from_text("Rwanda")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 39021914, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 39034120, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 39036229, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 39070381, ["Country", "Country_source"]] = fix_country_from_text("Morocco")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 39081450, ["Country", "Country_source"]] = fix_country_from_text("Pakistan")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 39085058, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 39231709, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 39355732, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 39358255, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 39358260, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 39358262, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 39358298, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 39391592, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 39421173, ["Country", "Country_source"]] = fix_country_from_text("India")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 39483155, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 39617447, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 39710413, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 39713210, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_4454000.loc[df_parsedX_4454000["PMID"] == 40212553, ["Country", "Country_source"]] = fix_country_from_text("South Korea")

# %%
df_parsedX_4454000.to_csv(DF_input + "parsedX_4454000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_500000.csv*

# %%
# Read csv
df_parsedX_500000 = pd.read_csv(DF_input + "parsedX_500000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7474374, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7474406, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7474615, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7476618, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7479552, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7490320, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7493911, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7493912, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7495629, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7504592, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7514058, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7514586, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7515022, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7515171, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7525524, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7525761, ["Country", "Country_source"]] = fix_country_from_text("Colombia")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7526016, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7529629, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7529885, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7531687, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7533489, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7534632, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7545032, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7547392, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7559089, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7562230, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7574801, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7577071, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7578537, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7578542, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7585659, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7591953, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7591963, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7591965, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7596048, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7615264, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7616902, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7622414, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7622421, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7625059, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7655647, ["Country", "Country_source"]] = fix_country_from_text("Belarus")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7655751, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7662467, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7670905, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7677689, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7679590, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7683736, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7685837, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7699911, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7715075, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7730149, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7730494, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7734589, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7734602, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7736591, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7737095, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7737901, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7737902, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7737903, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7737904, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7737906, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7737912, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7745822, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7745824, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7749054, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7755386, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7756067, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7756362, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7765938, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7772006, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7772530, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7797197, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7809123, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7811212, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7822532, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7826107, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7826125, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7827553, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7829393, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7829401, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7842350, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7845389, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7847804, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7849464, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7852184, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7852187, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7860384, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7860390, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7863062, ["Country", "Country_source"]] = fix_country_from_text("Oman")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7877257, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7877258, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7877260, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7880057, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7880103, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7880108, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7884825, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7895213, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7897851, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7902882, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7904987, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7912926, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7913312, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7913313, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7913600, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7915263, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7915508, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7916182, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7925858, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7939795, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7944272, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7944537, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7947268, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7956693, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7961105, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7961107, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7961108, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7961109, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7961118, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7967099, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7967102, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7967108, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7977396, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7979412, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7980172, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 7982315, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 8007422, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 8007467, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 8013153, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 8014101, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 8014110, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 8019362, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 8019715, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 8028535, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 8037750, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 8038032, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 8044760, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 8045292, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 8055881, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 8068195, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 8070028, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 8070382, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 8071107, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 8071114, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 8074387, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 8081551, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 8085630, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 8088287, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 8090512, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 8093263, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 8097504, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 8099903, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 8105677, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 8117023, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 8121700, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 8122387, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 8124551, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 8126917, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 8126920, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 8126922, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_500000.loc[df_parsedX_500000["PMID"] == 8133638, ["Country", "Country_source"]] = fix_country_from_text("Pakistan")

# %%
df_parsedX_500000.to_csv(DF_input + "parsedX_500000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_600000.csv*

# %%
# Read csv
df_parsedX_600000 = pd.read_csv(DF_input + "parsedX_600000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8137352, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8144391, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8147393, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8149158, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8156485, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8158861, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8158862, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8161900, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8164372, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8168403, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8169517, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8178718, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8179556, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8179557, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8186595, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8188525, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8195931, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8200853, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8202890, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8204718, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8206210, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8206228, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8206237, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8210738, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8210739, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8212070, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8218087, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8226149, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8230752, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8230755, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8230759, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8232328, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8244145, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8244352, ["Country", "Country_source"]] = fix_country_from_text("South Africa")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8246607, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8254964, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8255744, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8260346, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8262850, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8270460, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8276650, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8276720, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8283791, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8286259, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8291647, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8291896, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8301825, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8309901, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8311498, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8313353, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8316334, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8316667, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8318133, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8320167, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8320175, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8334647, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8340259, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8350487, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8350491, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8350493, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8357520, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8361800, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8370655, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8370656, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8372259, ["Country", "Country_source"]] = fix_country_from_text("Spain")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8373304, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8383649, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8384672, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8387266, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8390584, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8394471, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8394596, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8398308, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8399701, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8407550, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8411738, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8425245, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8426337, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8426543, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8432890, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8433679, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8433680, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8440492, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8449824, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8452388, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8459599, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8459601, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8459638, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8459639, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8459641, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8463128, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8466248, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8470022, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8471669, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8484985, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8485046, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8488069, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8492515, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8494774, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8498943, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8498946, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8504420, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8512915, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8513076, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8515576, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8518033, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8523819, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8523822, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8523823, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8523824, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8538521, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8542403, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8551664, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8551665, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8551668, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8551669, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8561933, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8562837, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8567395, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8567401, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8567405, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8568004, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8577483, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8584808, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8611443, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8613430, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8635999, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8636010, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8636011, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8636012, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8645679, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8650833, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8652391, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8655711, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8664042, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8665509, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8672203, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8686247, ["Country", "Country_source"]] = fix_country_from_text("Armenia")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8688128, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8691599, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8691602, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8691619, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8691629, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8693352, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8698613, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8698614, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8707073, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8713191, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8717576, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8731274, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8741469, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8741680, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8752475, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8757757, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8758251, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8763341, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8790160, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8790830, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8793651, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8797883, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8797891, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8797895, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8799086, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8799088, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_600000.loc[df_parsedX_600000["PMID"] == 8799412, ["Country", "Country_source"]] = fix_country_from_text("Japan")

# %%
df_parsedX_600000.to_csv(DF_input + "parsedX_600000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_700000.csv*

# %%
# Read csv
df_parsedX_700000 = pd.read_csv(DF_input + "parsedX_700000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 8838099, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 8853496, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 8854386, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 8857455, ["Country", "Country_source"]] = fix_country_from_text("Türkiye")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 8861494, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 8895674, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 8895676, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 8895681, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 8908761, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 8908768, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 8914393, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 8920649, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 8920672, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 8920674, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 8943818, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 8944568, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 8952323, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 8957955, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 8964326, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 8965345, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 8965352, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 8965361, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 8965366, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 8976871, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 8979775, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 8984531, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9001346, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9001350, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9001351, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9001353, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9001355, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9001357, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9001358, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9007130, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9014757, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9021817, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9025864, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9030234, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9033343, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9035664, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9036066, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9038400, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9038612, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9045890, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9045955, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9045961, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9050854, ["Country", "Country_source"]] = fix_country_from_text("Norway")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9063478, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9066545, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9081573, ["Country", "Country_source"]] = fix_country_from_text("Singapore")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9117967, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9119737, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9119746, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9135967, ["Country", "Country_source"]] = fix_country_from_text("United Kingdoms")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9140106, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9140112, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9140118, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9155115, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9161079, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9172498, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9190649, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9191325, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9194462, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9196566, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9197524, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9204620, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9209312, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9212213, ["Country", "Country_source"]] = fix_country_from_text("Hungary")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9247607, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9256141, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9256714, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9263527, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9263533, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9263535, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9263536, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9263537, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9283233, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9297211, ["Country", "Country_source"]] = fix_country_from_text("Spain")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9306851, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9308208, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9309150, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9310143, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9314261, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9317131, ["Country", "Country_source"]] = fix_country_from_text("Austria")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9337676, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9337688, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9348918, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9359499, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9369908, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9369909, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9369912, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9369916, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9369922, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9369936, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9380963, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9381248, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9381251, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9386550, ["Country", "Country_source"]] = fix_country_from_text("France")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9386734, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9414650, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9414651, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9414653, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9414664, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9418546, ["Country", "Country_source"]] = fix_country_from_text("Netherlands")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9423071, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9424727, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9424727, ["Country", "Country_source"]] = fix_country_from_text("Paraguay")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9427433, ["Country", "Country_source"]] = fix_country_from_text("Denmark")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9429722, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9439676, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9439677, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9450002, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9450003, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9450818, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9451388, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9455090, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9455091, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9464326, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9473726, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9473727, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9473734, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9474935, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9474937, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9474938, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9479354, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9479355, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9479357, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9479360, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9479366, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9479369, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9479371, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9479372, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9483923, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9488562, ["Country", "Country_source"]] = fix_country_from_text("Georgia")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9489184, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9489192, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9493432, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9503995, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9505360, ["Country", "Country_source"]] = fix_country_from_text("Ukraine")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9509131, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9510467, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9510481, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9512467, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9523128, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9533756, ["Country", "Country_source"]] = fix_country_from_text("Norway")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9538927, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9539898, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_700000.loc[df_parsedX_700000["PMID"] == 9548448, ["Country", "Country_source"]] = fix_country_from_text("Japan")

# %%
df_parsedX_700000.to_csv(DF_input + "parsedX_700000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_800000.csv*

# %%
# Read csv
df_parsedX_800000 = pd.read_csv(DF_input + "parsedX_800000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9559016, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9567657, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9578722, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9578726, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9578727, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9578728, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9578729, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9578730, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9578731, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9578732, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9578734, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9578735, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9578736, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9578737, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9578740, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9578741, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9578743, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9578744, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9580732, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9584772, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9597967, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9600116, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9600122, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9601238, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9615815, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9615817, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9615818, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9615820, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9615821, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9615822, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9615823, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9615824, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9615825, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9615826, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9615827, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9615829, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9615830, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9615831, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9615832, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9615834, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9615837, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9617352, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9627490, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9629814, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9629816, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9629821, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9633843, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9638017, ["Country", "Country_source"]] = fix_country_from_text("Ireland")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9645177, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9653494, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9654713, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9658816, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9658843, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9664198, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9664698, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9685848, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9685850, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9685860, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9695678, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9695696, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9695778, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9695779, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9695780, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9695781, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9695783, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9695785, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9703359, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9722291, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9744180, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9744202, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9745414, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9757195, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9757210, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9760427, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9763901, ["Country", "Country_source"]] = fix_country_from_text("Türkiye")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9765613, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9765618, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9765619, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9765620, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9765731, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9765747, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9765748, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9771100, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9771102, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9771103, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9778736, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9779724, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9785387, ["Country", "Country_source"]] = fix_country_from_text("Norway")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9785977, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9807204, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9807206, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9816021, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9816254, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9817284, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9818032, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9819471, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9832713, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9849579, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9849581, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9849582, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9851230, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9851357, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9861912, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9873556, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9884707, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9914779, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9914787, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9927538, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9932638, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9951534, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 9987520, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10025122, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10074220, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10074425, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10076559, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10076573, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10076575, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10081498, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10087826, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10087963, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10087964, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10087967, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10087976, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10097760, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10098340, ["Country", "Country_source"]] = fix_country_from_text("Ireland")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10104646, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10189882, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10200459, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10211121, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10212587, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10221481, ["Country", "Country_source"]] = fix_country_from_text("Norway")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10225684, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10234289, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10321867, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10323059, ["Country", "Country_source"]] = fix_country_from_text("Pakistan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10329856, ["Country", "Country_source"]] = fix_country_from_text("Costa Rica")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10330761, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10330923, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10337839, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10340956, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10347464, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10359039, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10359044, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10363576, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10378652, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10383140, ["Country", "Country_source"]] = fix_country_from_text("Norway")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10388167, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10388168, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10398086, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10398113, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10410151, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10411280, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10412245, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10414100, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10443222, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10443223, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10443224, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10443225, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10443227, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10443228, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10443229, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10443230, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10443232, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10443233, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10443234, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10443235, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10443239, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10443240, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10448183, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10456996, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10460588, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10460860, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10462863, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10491546, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10491906, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10504858, ["Country", "Country_source"]] = fix_country_from_text("Norway")
df_parsedX_800000.loc[df_parsedX_800000["PMID"] == 10520416, ["Country", "Country_source"]] = fix_country_from_text("Italy")

# %%
df_parsedX_800000.to_csv(DF_input + "parsedX_800000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_900000.csv*

# %%
# Read csv
df_parsedX_900000 = pd.read_csv(DF_input + "parsedX_900000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10526514, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10532101, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10532102, ["Country", "Country_source"]] = fix_country_from_text("Belarus")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10532103, ["Country", "Country_source"]] = fix_country_from_text("Belarus")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10532104, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10532106, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10532107, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10532109, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10533479, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10538758, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10543144, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10544074, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10551200, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10551330, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10553415, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10565225, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10572232, ["Country", "Country_source"]] = fix_country_from_text("France")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10579170, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10579171, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10590218, ["Country", "Country_source"]] = fix_country_from_text("Netherlands")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10590688, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10593238, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10614106, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10622536, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10622679, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10624139, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10629708, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10629710, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10629711, ["Country", "Country_source"]] = fix_country_from_text("Armenia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10629714, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10629719, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10650109, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10660731, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10665646, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10682908, ["Country", "Country_source"]] = fix_country_from_text("Austria")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10683318, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10684221, ["Country", "Country_source"]] = fix_country_from_text("Denmark")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10703509, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10703511, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10703512, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10703515, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10703521, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10703523, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10703524, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10714224, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10714226, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10717877, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10729345, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10735020, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10738575, ["Country", "Country_source"]] = fix_country_from_text("Austria")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10740634, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10741151, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10743065, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10743395, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10743397, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10744038, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10751526, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10766294, ["Country", "Country_source"]] = fix_country_from_text("Austria")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10778214, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10789224, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10789230, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10789232, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10791011, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10795526, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10804817, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10824553, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10824566, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10853411, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10853413, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10853414, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10853416, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10853418, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10853419, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10853427, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10853428, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10853429, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10895201, ["Country", "Country_source"]] = fix_country_from_text("Indonesia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10896173, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10918244, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10920754, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10921307, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10925698, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10941361, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10941362, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10941363, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10941364, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10941365, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10941367, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10941368, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10941369, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10941370, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10941371, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10941372, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10941373, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10941374, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10941375, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10941376, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10941377, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10941378, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10941379, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10945006, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10945009, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10945014, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10945028, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10945030, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10949675, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10969605, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10976272, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10976273, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10976276, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10976277, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10976278, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10976281, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 10993655, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11002415, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11004217, ["Country", "Country_source"]] = fix_country_from_text("Spain")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11006657, ["Country", "Country_source"]] = fix_country_from_text("India")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11011478, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11013406, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11014475, ["Country", "Country_source"]] = fix_country_from_text("Saudi Arabia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11016010, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11022721, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11022728, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11022733, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11025821, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11025975, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11026001, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11026003, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11026006, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11026008, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11026016, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11026026, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11031929, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11034669, ["Country", "Country_source"]] = fix_country_from_text("Denmark")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11043166, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11045224, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11048499, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11059341, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11064596, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11065007, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11070351, ["Country", "Country_source"]] = fix_country_from_text("Austria")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11070755, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11075570, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11082687, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11082691, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11086128, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11140589, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11143541, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11147416, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11147419, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11176866, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11185890, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11190312, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11190324, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11194906, ["Country", "Country_source"]] = fix_country_from_text("Türkiye")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11197853, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11198572, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11202185, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11202187, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11202192, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11202195, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11202196, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11211759, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11211813, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11212496, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11215004, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11215193, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11218412, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11219937, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11219939, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11219940, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11219941, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11219942, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11219945, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11219946, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11219947, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11219948, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11219949, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11219950, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11219951, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11236940, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11241570, ["Country", "Country_source"]] = fix_country_from_text("Singapore")
df_parsedX_900000.loc[df_parsedX_900000["PMID"] == 11251968, ["Country", "Country_source"]] = fix_country_from_text("Austria")

# %%
df_parsedX_900000.to_csv(DF_input + "parsedX_900000.csv", index = False)

# %% [markdown]
# # Fixing first update PMIDs

# %%
DF_input_first_update = input().strip()
# Out:
#  C:\Users\svalb\OneDrive\Escritorio\Data_40_years_cancer_studies\parsedXMLs_first_update\

# %%
list_csvs_first_update = []

for file in os.listdir(DF_input_first_update):
    if file[-4:] == ".csv":
        list_csvs_first_update.append(file)

list_csvs_first_update
# Out:
# ['parsedXMLs_first_upd_100000.csv',
#  'parsedXMLs_first_upd_200000.csv',
#  'parsedXMLs_first_upd_300000.csv',
#  'parsedXMLs_first_upd_340800.csv']

# %% [markdown]
# ### Correcting *parsedX_100000.csv* (first update)

# %%
# Read csv
df_parsedX_first_update_100000 = pd.read_csv(DF_input_first_update + "parsedXMLs_first_upd_100000.csv")
# Out:
# C:\Users\svalb\AppData\Local\Temp\ipykernel_25280\2602507938.py:2: DtypeWarning: Columns (2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_parsedX_first_update_100000 = pd.read_csv(DF_input_first_update + "parsedXMLs_first_upd_100000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 31334982, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 36974732, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 37872055, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 37981322, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38191179, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38191182, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38194605, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38251671, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38394223, ["Country", "Country_source"]] = fix_country_from_text("Malaysia")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38483042, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38490023, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38519263, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38531608, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38553775, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38599073, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38629689, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38629975, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38642885, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38644195, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38659423, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38666543, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38682088, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38723412, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38754178, ["Country", "Country_source"]] = fix_country_from_text("Türkiye")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38754196, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38759317, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38788718, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38795813, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38817653, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38841789, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38845275, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38852520, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38881674, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38887964, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38896789, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38902768, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38924542, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38935830, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38936410, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38948113, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38948246, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38948247, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38948248, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38955104, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38962426, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38972723, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38972811, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38992586, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 38997298, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39016057, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39018589, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39021914, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39036229, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39037718, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39041699, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39044367, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39060968, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39070381, ["Country", "Country_source"]] = fix_country_from_text("Morocco")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39081450, ["Country", "Country_source"]] = fix_country_from_text("Pakistan")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39081932, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39082979, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39095325, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39105366, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39119870, ["Country", "Country_source"]] = fix_country_from_text("Malaysia")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39146048, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39161480, ["Country", "Country_source"]] = fix_country_from_text("Saudi Arabia")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39183033, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39183034, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39188475, ["Country", "Country_source"]] = fix_country_from_text("Saudi Arabia")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39190965, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39191488, ["Country", "Country_source"]] = fix_country_from_text("Switzerland")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39191683, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39191705, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39191706, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39219283, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39224497, ["Country", "Country_source"]] = fix_country_from_text("Antigua & Barbuda")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39226595, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39229651, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39235834, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39239714, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39241496, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39244346, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39245580, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39251969, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39264581, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39276854, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39277091, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39286636, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_100000.loc[df_parsedX_first_update_100000["PMID"] == 39181163, ["Country", "Country_source"]] = fix_country_from_text("Germany")

# %%
df_parsedX_first_update_100000.to_csv(DF_input_first_update + "parsedXMLs_first_upd_100000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_200000.csv* (first update)

# %%
# Read csv
df_parsedX_first_update_200000 = pd.read_csv(DF_input_first_update + "parsedXMLs_first_upd_200000.csv")
# Out:
# C:\Users\svalb\AppData\Local\Temp\ipykernel_25280\3459491506.py:2: DtypeWarning: Columns (13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_parsedX_first_update_200000 = pd.read_csv(DF_input_first_update + "parsedXMLs_first_upd_200000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39297872, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39301201, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39318916, ["Country", "Country_source"]] = fix_country_from_text("Saudi Arabia")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39319557, ["Country", "Country_source"]] = fix_country_from_text("Cote d'Ivoire")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39320099, ["Country", "Country_source"]] = fix_country_from_text("Malaysia")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39321503, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39355732, ["Country", "Country_source"]] = fix_country_from_text("Ireland")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39364488, ["Country", "Country_source"]] = fix_country_from_text("Kenya")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39386335, ["Country", "Country_source"]] = fix_country_from_text("United Arab Emirates")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39391592, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39395887, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39396314, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39418821, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39421173, ["Country", "Country_source"]] = fix_country_from_text("India")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39444059, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39445531, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39446605, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39454478, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39462541, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39480206, ["Country", "Country_source"]] = fix_country_from_text("Sierra Leone")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39483155, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39493131, ["Country", "Country_source"]] = fix_country_from_text("Pakistan")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39512498, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39512500, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39525954, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39529955, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39550887, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39559423, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39574987, ["Country", "Country_source"]] = fix_country_from_text("United Arab Emirates")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39580679, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39600350, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39609369, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39624746, ["Country", "Country_source"]] = fix_country_from_text("France")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39626854, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39627663, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39650621, ["Country", "Country_source"]] = fix_country_from_text("Vietnam")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39696292, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39700848, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39703305, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39704849, ["Country", "Country_source"]] = fix_country_from_text("Kuwait")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39707719, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39713210, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39723280, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39723635, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39737702, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39749708, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39754336, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39773427, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39821325, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39823567, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39826271, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39832965, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39846241, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39856436, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39868745, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39897218, ["Country", "Country_source"]] = fix_country_from_text("Kenya")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39898982, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39930787, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39948975, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39951991, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39955233, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39957215, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39963174, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39963614, ["Country", "Country_source"]] = fix_country_from_text("India")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39968433, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39977086, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39977214, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39474711, ["Country", "Country_source"]] = fix_country_from_text("France")
df_parsedX_first_update_200000.loc[df_parsedX_first_update_200000["PMID"] == 39815403, ["Country", "Country_source"]] = fix_country_from_text("Denmark")

# %%
df_parsedX_first_update_200000.to_csv(DF_input_first_update + "parsedXMLs_first_upd_200000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_300000.csv* (first update)

# %%
# Read csv
df_parsedX_first_update_300000 = pd.read_csv(DF_input_first_update + "parsedXMLs_first_upd_300000.csv")
# Out:
# C:\Users\svalb\AppData\Local\Temp\ipykernel_25280\1914561263.py:2: DtypeWarning: Columns (13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_parsedX_first_update_300000 = pd.read_csv(DF_input_first_update + "parsedXMLs_first_upd_300000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 39981497, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 39991386, ["Country", "Country_source"]] = fix_country_from_text("Qatar")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 39993980, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40013319, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40022054, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40023122, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40026960, ["Country", "Country_source"]] = fix_country_from_text("India")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40026980, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40029804, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40035174, ["Country", "Country_source"]] = fix_country_from_text("Singapore")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40044148, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40048246, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40052724, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40077834, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40084249, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40085921, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40099067, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40103743, ["Country", "Country_source"]] = fix_country_from_text("Malaysia")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40115906, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40189754, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40189756, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40190529, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40196744, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40196745, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40199901, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40207650, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40212553, ["Country", "Country_source"]] = fix_country_from_text("South Korea")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40225499, ["Country", "Country_source"]] = fix_country_from_text("Pakistan")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40230612, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40248551, ["Country", "Country_source"]] = fix_country_from_text("Morocco")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40250245, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40251674, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40254442, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40255060, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40256896, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40264494, ["Country", "Country_source"]] = fix_country_from_text("Taiwan")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40264581, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40264585, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40279769, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40293964, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40296668, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40298941, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40307990, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40334840, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40350274, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40351891, ["Country", "Country_source"]] = fix_country_from_text("Nigeria")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40351999, ["Country", "Country_source"]] = fix_country_from_text("Pakistan")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40354099, ["Country", "Country_source"]] = fix_country_from_text("United Arab Emirates")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40354336, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40355213, ["Country", "Country_source"]] = fix_country_from_text("India")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40360402, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40360403, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40360969, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40361146, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40368772, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40380167, ["Country", "Country_source"]] = fix_country_from_text("United Arab Emirates")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40383631, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40385769, ["Country", "Country_source"]] = fix_country_from_text("India")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40391200, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40402532, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40414555, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40432877, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40433504, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40433907, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40442776, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40443719, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40456672, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40463261, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40463490, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40475254, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40487561, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40503912, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40522871, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40525667, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40538941, ["Country", "Country_source"]] = fix_country_from_text("Ukraine")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40539233, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40542961, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40545764, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40597875, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40619225, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40620515, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40623507, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40636438, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_300000.loc[df_parsedX_first_update_300000["PMID"] == 40404564, ["Country", "Country_source"]] = fix_country_from_text("Germany")

# %%
df_parsedX_first_update_300000.to_csv(DF_input_first_update + "parsedXMLs_first_upd_300000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_340800.csv* (first update)

# %%
# Read csv
df_parsedX_first_update_340800 = pd.read_csv(DF_input_first_update + "parsedXMLs_first_upd_340800.csv")

# %%
## Replace found errors by true Country values

df_parsedX_first_update_340800.loc[df_parsedX_first_update_340800["PMID"] == 40655317, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_340800.loc[df_parsedX_first_update_340800["PMID"] == 40656431, ["Country", "Country_source"]] = fix_country_from_text("Pakistan")
df_parsedX_first_update_340800.loc[df_parsedX_first_update_340800["PMID"] == 40668150, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_340800.loc[df_parsedX_first_update_340800["PMID"] == 40683576, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_340800.loc[df_parsedX_first_update_340800["PMID"] == 40685780, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_340800.loc[df_parsedX_first_update_340800["PMID"] == 40691066, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_340800.loc[df_parsedX_first_update_340800["PMID"] == 40692411, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_340800.loc[df_parsedX_first_update_340800["PMID"] == 40699023, ["Country", "Country_source"]] = fix_country_from_text("Taiwan")
df_parsedX_first_update_340800.loc[df_parsedX_first_update_340800["PMID"] == 40701722, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_340800.loc[df_parsedX_first_update_340800["PMID"] == 40711424, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_340800.loc[df_parsedX_first_update_340800["PMID"] == 40769921, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_340800.loc[df_parsedX_first_update_340800["PMID"] == 40769927, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_340800.loc[df_parsedX_first_update_340800["PMID"] == 40775882, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_340800.loc[df_parsedX_first_update_340800["PMID"] == 40776309, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_340800.loc[df_parsedX_first_update_340800["PMID"] == 40785062, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_340800.loc[df_parsedX_first_update_340800["PMID"] == 40790805, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_340800.loc[df_parsedX_first_update_340800["PMID"] == 40790806, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_340800.loc[df_parsedX_first_update_340800["PMID"] == 40791176, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_340800.loc[df_parsedX_first_update_340800["PMID"] == 40802992, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_first_update_340800.loc[df_parsedX_first_update_340800["PMID"] == 40814369, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_340800.loc[df_parsedX_first_update_340800["PMID"] == 40819548, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_340800.loc[df_parsedX_first_update_340800["PMID"] == 40820270, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_340800.loc[df_parsedX_first_update_340800["PMID"] == 40828650, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_340800.loc[df_parsedX_first_update_340800["PMID"] == 40831848, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_340800.loc[df_parsedX_first_update_340800["PMID"] == 40832384, ["Country", "Country_source"]] = fix_country_from_text("Brazil")
df_parsedX_first_update_340800.loc[df_parsedX_first_update_340800["PMID"] == 40866222, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_340800.loc[df_parsedX_first_update_340800["PMID"] == 40907168, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_340800.loc[df_parsedX_first_update_340800["PMID"] == 40917729, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_340800.loc[df_parsedX_first_update_340800["PMID"] == 40917780, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_340800.loc[df_parsedX_first_update_340800["PMID"] == 40932929, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_first_update_340800.loc[df_parsedX_first_update_340800["PMID"] == 40932956, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_first_update_340800.loc[df_parsedX_first_update_340800["PMID"] == 40986913, ["Country", "Country_source"]] = fix_country_from_text("Eswatini")

# %%
df_parsedX_first_update_340800.to_csv(DF_input_first_update + "parsedXMLs_first_upd_340800.csv", index = False)

# %% [markdown]
# # Fixing first predate PMIDs (Jan-July 1984)

# %%
DF_input_first_predate = input().strip()
# Out:
#  C:\Users\svalb\OneDrive\Escritorio\Data_40_years_cancer_studies\parsedXMLs_first_predate\

# %%
list_csvs_first_predate = []

for file in os.listdir(DF_input_first_predate):
    if file[-4:] == ".csv":
        list_csvs_first_predate.append(file)

list_csvs_first_predate
# Out:
# ['parsedXMLs_first_pred_26400.csv']

# %%
# Read csv
df_parsedX_first_predate_26400 = pd.read_csv(DF_input_first_predate + "parsedXMLs_first_pred_26400.csv")

# %% [markdown]
# # Fixing first PMIDs update Sept 2025

# %%
DF_input_sept_2025 = input().strip()
# Out:
#  C:\Users\svalb\OneDrive\Escritorio\Data_40_years_cancer_studies\parsedXMLs_update_2025-09\

# %%
list_csvs_sept_2025 = []

for file in os.listdir(DF_input_sept_2025):
    if file[-4:] == ".csv":
        list_csvs_sept_2025.append(file)

list_csvs_sept_2025
# Out:
# ['parsedXMLs_update_2025_09_33200.csv']

# %%
# Read csv
df_parsedX_update_sept_2025 = pd.read_csv(DF_input_sept_2025 + "parsedXMLs_update_2025_09_33200.csv")
# Out:
# C:\Users\svalb\AppData\Local\Temp\ipykernel_28816\3836960796.py:2: DtypeWarning: Columns (3,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_parsedX_update_sept_2025 = pd.read_csv(DF_input_sept_2025 + "parsedXMLs_update_2025__09_33200.csv")

# %%
df_parsedX_update_sept_2025.loc[df_parsedX_update_sept_2025["PMID"] == 40256896, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_update_sept_2025.loc[df_parsedX_update_sept_2025["PMID"] == 40414555, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_update_sept_2025.loc[df_parsedX_update_sept_2025["PMID"] == 40525667, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_update_sept_2025.loc[df_parsedX_update_sept_2025["PMID"] == 40623507, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_update_sept_2025.loc[df_parsedX_update_sept_2025["PMID"] == 40655317, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_update_sept_2025.loc[df_parsedX_update_sept_2025["PMID"] == 40683576, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_update_sept_2025.loc[df_parsedX_update_sept_2025["PMID"] == 40685780, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_update_sept_2025.loc[df_parsedX_update_sept_2025["PMID"] == 40692411, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_update_sept_2025.loc[df_parsedX_update_sept_2025["PMID"] == 40701722, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_update_sept_2025.loc[df_parsedX_update_sept_2025["PMID"] == 40819548, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_update_sept_2025.loc[df_parsedX_update_sept_2025["PMID"] == 40819548, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_update_sept_2025.loc[df_parsedX_update_sept_2025["PMID"] == 40913565, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_update_sept_2025.loc[df_parsedX_update_sept_2025["PMID"] == 40917780, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_update_sept_2025.loc[df_parsedX_update_sept_2025["PMID"] == 40928867, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_update_sept_2025.loc[df_parsedX_update_sept_2025["PMID"] == 40932929, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_update_sept_2025.loc[df_parsedX_update_sept_2025["PMID"] == 40939680, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_update_sept_2025.loc[df_parsedX_update_sept_2025["PMID"] == 40954942, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_update_sept_2025.loc[df_parsedX_update_sept_2025["PMID"] == 40966972, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_update_sept_2025.loc[df_parsedX_update_sept_2025["PMID"] == 41017572, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_update_sept_2025.loc[df_parsedX_update_sept_2025["PMID"] == 41022585, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_update_sept_2025.loc[df_parsedX_update_sept_2025["PMID"] == 41024932, ["Country", "Country_source"]] = fix_country_from_text("China")

# %%
df_parsedX_update_sept_2025.to_csv(DF_input_sept_2025 + "parsedXMLs_update_2025_09_33200.csv", index = False)
