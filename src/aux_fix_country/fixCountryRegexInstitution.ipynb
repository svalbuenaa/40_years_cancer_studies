# %% [markdown]
# ## Fixing country assignments - Regex_institution
#
# It was found that, for some articles, the "Country" field, extracted from NER, was wrongly assigned when done by the method of "Regex_institution" ("Country_source" field). This notebook corrects each found mistake, assign the correct "Country" value and replace the "Country_source" value from "Regex_institution" to "Manual_correction"

# %%
import pandas as pd
import os
import country_converter as coco
from ..

# %%
DF_input = input().strip()
# Out:
#  C:\Users\svalb\OneDrive\Escritorio\Data_40_years_cancer_studies\parsedXMLs\

# %%
list_csvs = []

for file in os.listdir(DF_input):
    if file[-4:] == ".csv":
        list_csvs.append(file)

list_csvs
# Out:
# ['parsedX_100000.csv',
#  'parsedX_1000000.csv',
#  'parsedX_1100000.csv',
#  'parsedX_1200000.csv',
#  'parsedX_1300000.csv',
#  'parsedX_1400000.csv',
#  'parsedX_1500000.csv',
#  'parsedX_1600000.csv',
#  'parsedX_1700000.csv',
#  'parsedX_1800000.csv',
#  'parsedX_1900000.csv',
#  'parsedX_200000.csv',
#  'parsedX_2000000.csv',
#  'parsedX_2100000.csv',
#  'parsedX_2200000.csv',
#  'parsedX_2300000.csv',
#  'parsedX_2400000.csv',
#  'parsedX_2500000.csv',
#  'parsedX_2600000.csv',
#  'parsedX_2700000.csv',
#  'parsedX_2800000.csv',
#  'parsedX_2900000.csv',
#  'parsedX_300000.csv',
#  'parsedX_3000000.csv',
#  'parsedX_3100000.csv',
#  'parsedX_3200000.csv',
#  'parsedX_3300000.csv',
#  'parsedX_3400000.csv',
#  'parsedX_3500000.csv',
#  'parsedX_3600000.csv',
#  'parsedX_3700000.csv',
#  'parsedX_3800000.csv',
#  'parsedX_3900000.csv',
#  'parsedX_400000.csv',
#  'parsedX_4000000.csv',
#  'parsedX_4100000.csv',
#  'parsedX_4200000.csv',
#  'parsedX_4300000.csv',
#  'parsedX_4400000.csv',
#  'parsedX_4454000.csv',
#  'parsedX_500000.csv',
#  'parsedX_600000.csv',
#  'parsedX_700000.csv',
#  'parsedX_800000.csv',
#  'parsedX_900000.csv']

# %%
## In order to ensure quality renaming, use country_converter
cc = coco.CountryConverter()

## Use a function to get the Country via coco and the Country_source manually
## Similar to the function *get_country_from_text()* from *extractCountryFromNER.ipynb*
## This one returns Country_source as well, and raises error if country not found
## because the idea now is to fix an error with a correct value. No need to have None values
def fix_country_from_text(text):
    """Fixing Country value names manually, error if coco doesn't find Country name"""
    # Attempt to extract country directly from text passed to the function (NER)
    result = cc.convert(names=text, to='name_short')
    if result != "not found":
        return result, "Manual_correction"
    else:
        raise ValueError("New Country not found")

# %% [markdown]
# ### Correcting *parsedX_100000.csv*

# %%
# Read csv
df_parsedX_100000 = pd.read_csv(DF_input + "parsedX_100000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1279244, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1282908, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1283991, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1291757, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1291761, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1296783, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1296785, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1313408, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1313780, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1314917, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1315401, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1316340, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1317214, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1317572, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1319613, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1320139, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1321494, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1325432, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1330836, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1331573, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1335095, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1336492, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1336496, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1336497, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1340409, ["Country", "Country_source"]] = fix_country_from_text("Belarus")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1341320, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1344425, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1345519, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1350949, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1359172, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1359174, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1363324, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1376855, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1377842, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1387127, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1388196, ["Country", "Country_source"]] = fix_country_from_text("Gambia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1392886, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1395431, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1395873, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1399802, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1404961, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1411622, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1415280, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1421756, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1422359, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1429207, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1429209, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1429211, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1434027, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1435440, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1439020, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1439024, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1440177, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1452454, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1460118, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1464946, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1467544, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1469798, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1471221, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1473256, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1473952, ["Country", "Country_source"]] = fix_country_from_text("Ireland")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1479966, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1483427, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1483946, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1483949, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1488294, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1489379, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1494774, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1506274, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1506936, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1507495, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1508648, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1510633, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1511194, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1518137, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1518162, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1518164, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1518184, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1520168, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1522473, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1524849, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1526347, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1529127, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1530474, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1532492, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1544832, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1544844, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1544866, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1544877, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1555547, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1555994, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1555999, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1558779, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1561546, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1564719, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1568843, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1573788, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1573789, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1573791, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1574121, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1575692, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1579470, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1582887, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1582893, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1583573, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1586992, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1591059, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1606794, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1611340, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1612955, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1618700, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1619642, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1619780, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1625606, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1626610, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1627384, ["Country", "Country_source"]] = fix_country_from_text("Netherlands")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1630350, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1630894, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1635491, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1638698, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1640883, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1648129, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1648431, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1648633, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1648635, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1649794, ["Country", "Country_source"]] = fix_country_from_text("Thailand")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1649812, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1649814, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1650329, ["Country", "Country_source"]] = fix_country_from_text("Thailand")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1650574, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1651392, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1657552, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1657847, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1657848, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1658415, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1658416, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1658731, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1664877, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1664879, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1664881, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1664883, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1664886, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1665132, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1669524, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1675471, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1679056, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1684826, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1685881, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1694838, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1696094, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1697065, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1702370, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1702412, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1702415, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1708246, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1710446, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1711304, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1715338, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1715778, ["Country", "Country_source"]] = fix_country_from_text("Pakistan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1716622, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1721614, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1721615, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1721656, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1725688, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1734220, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1737628, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1744744, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1751280, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1752788, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1753417, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1753418, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1778757, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1778765, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1778775, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1785146, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1791253, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1793394, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1797655, ["Country", "Country_source"]] = fix_country_from_text("India")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1805050, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1827277, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1834359, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1834923, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1849184, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1849187, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1849189, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1851059, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1851610, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1851904, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1853503, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1863949, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1864137, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1872236, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1889579, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1889619, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1893082, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1893083, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1893515, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1894221, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1897075, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1900266, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1900734, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1900817, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1901116, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1902452, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1903663, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1904414, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1904418, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1906847, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1906848, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1908844, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1911349, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1912056, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1913642, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1914965, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1917597, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1919029, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1919387, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1924441, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1925010, ["Country", "Country_source"]] = fix_country_from_text("Norway")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1926038, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1929496, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1932332, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1936782, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1937362, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1938596, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1942549, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1942550, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1942552, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1942555, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1942560, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1953014, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1960180, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1960491, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1963245, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1966278, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1966519, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1970554, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1973161, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1975502, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1978564, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1979421, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1979976, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1983859, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1989642, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")

# %%
df_parsedX_100000.to_csv(DF_input + "parsedX_100000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_1000000.csv*

# %%
# Read csv
df_parsedX_1000000 = pd.read_csv(DF_input + "parsedX_1000000.csv")

# %%
## Replace found errors by true Country values

df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11270620, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11289192, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11307302, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11315257, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11317526, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11317533, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11317539, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11317540, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11317547, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11320721, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11375234, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11383206, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11383447, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11383456, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11383460, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11389995, ["Country", "Country_source"]] = fix_country_from_text("Austria")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11396509, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11400696, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11402299, ["Country", "Country_source"]] = fix_country_from_text("Austria")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11422476, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11424371, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11424392, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11424412, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11424415, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11424419, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11424434, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11424435, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11424443, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11424444, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11452695, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11452701, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11464491, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11476352, ["Country", "Country_source"]] = fix_country_from_text("Israel")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11477111, ["Country", "Country_source"]] = fix_country_from_text("Belgium")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11479950, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11485960, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11488146, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11494004, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11494510, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11512313, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11521795, ["Country", "Country_source"]] = fix_country_from_text("Canada")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11523571, ["Country", "Country_source"]] = fix_country_from_text("Israel")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11529666, ["Country", "Country_source"]] = fix_country_from_text("Austria")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11544827, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11544828, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11544829, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11544830, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11544831, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11544837, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11544839, ["Country", "Country_source"]] = fix_country_from_text("Armenia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11547588, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11547595, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11554051, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11593712, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11665947, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11676863, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11688624, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11705873, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11710281, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11710283, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11710284, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11710292, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11710293, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11712345, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11714441, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11744176, ["Country", "Country_source"]] = fix_country_from_text("Austria")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11751431, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11758333, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11761925, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11761931, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11761936, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11761944, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11761953, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11761958, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11761962, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11762028, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11766351, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11774267, ["Country", "Country_source"]] = fix_country_from_text("Austria")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11785097, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11785099, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11785104, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11785106, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11785109, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11789424, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11795767, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11808130, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11808346, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11825488, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11826490, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11829853, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11831067, ["Country", "Country_source"]] = fix_country_from_text("Switzerland")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11847882, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11851111, ["Country", "Country_source"]] = fix_country_from_text("Israel")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11865331, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11904439, ["Country", "Country_source"]] = fix_country_from_text("United States")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11904959, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11904960, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11904980, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11936580, ["Country", "Country_source"]] = fix_country_from_text("Italy")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11968735, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 11974424, ["Country", "Country_source"]] = fix_country_from_text("United Kingdom")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12011056, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12032698, ["Country", "Country_source"]] = fix_country_from_text("Austria")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12036442, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12036445, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12036454, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12048932, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12050096, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12054331, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12054336, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12055736, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12061341, ["Country", "Country_source"]] = fix_country_from_text("Mexico")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12063644, ["Country", "Country_source"]] = fix_country_from_text("Germany")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12071446, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12079507, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12079509, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12079519, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12094715, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12098786, ["Country", "Country_source"]] = fix_country_from_text("China")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101562, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101563, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101568, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101569, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101575, ["Country", "Country_source"]] = fix_country_from_text("Russia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101639, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101647, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101648, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101678, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101687, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101695, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101704, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101709, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101718, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101719, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101756, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101760, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101767, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101774, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12101779, ["Country", "Country_source"]] = fix_country_from_text("Japan")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12105432, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12105438, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12105441, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12105443, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12105507, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12105605, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12105607, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12105613, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12105615, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12105616, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12105617, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12105622, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12105623, ["Country", "Country_source"]] = fix_country_from_text("Australia")
df_parsedX_1000000.loc[df_parsedX_1000000["PMID"] == 12105627, ["Country", "Country_source"]] = fix_country_from_text("Australia")

# %%
df_parsedX_1000000.to_csv(DF_input + "parsedX_1000000.csv", index = False)

# %% [markdown]
# ### Correcting *parsedX_1100000.csv*

# %%
# Read csv
df_parsedX_1100000 = pd.read_csv(DF_input + "parsedX_1100000.csv")

# %%
pd.set_option('max_colwidth', 400)
pd.set_option('display.max_rows', 5000)
df_parsedX_1100000.loc[df_parsedX_100000["Country_source"]=="Regex_institution", ["PMID", "NER_lastAuthor", "Country"]]
# Out:
#           PMID         Country     Country_source
# 1      1279108        Zimbabwe  Regex_institution
# 6      1279163   United States  Regex_institution
# 23     1279216   United States  Regex_institution
# 26     1279224   United States  Regex_institution
# 38     1279247           Japan  Regex_institution
# 42     1279261           Japan  Regex_institution
# 50     1279317   United States  Regex_institution
# 79     1279632   United States  Regex_institution
# 90     1279701   United States  Regex_institution
# 105    1279729   United States  Regex_institution
# 149    1279957   United States  Regex_institution
# 173    1280107   United States  Regex_institution
# 190    1280212   United States  Regex_institution
# 200    1280305           Japan  Regex_institution
# 201    1280306           Japan  Regex_institution
# 212    1280343           Japan  Regex_institution
# 273    1280635           Japan  Regex_institution
# 287    1280761   United States  Regex_institution
# 290    1280775           Japan  Regex_institution
# 291    1280777           Japan  Regex_institution
# 293    1280779           Japan  Regex_institution
# 319    1281001   United States  Regex_institution
# 328    1281040   United States  Regex_institution
# 382    1281320   United States  Regex_institution
# 392    1281376  United Kingdom  Regex_institution
# 414    1281535   United States  Regex_institution
# 418    1281545   United States  Regex_institution
# 421    1281552   United States  Regex_institution
# 428    1281588   United States  Regex_institution
# 438    1281622   United States  Regex_institution
# 470    1281758   United States  Regex_institution
# 471    1281759   United States  Regex_institution
# 488    1281892           Japan  Regex_institution
# 491    1281896           Japan  Regex_institution
# 502    1281940   United States  Regex_institution
# 531    1282074  United Kingdom  Regex_institution
# 542    1282115   United States  Regex_institution
# 613    1282775           Japan  Regex_institution
# 632    1282909           Japan  Regex_institution
# 634    1282911           Japan  Regex_institution
# 638    1282924           Japan  Regex_institution
# 760    1283487   United States  Regex_institution
# 774    1283520   United States  Regex_institution
# 789    1283618           Japan  Regex_institution
# 792    1283625           Japan  Regex_institution
# 853    1283993           Japan  Regex_institution
# 859    1284015   United States  Regex_institution
# 903    1284282   United States  Regex_institution
# 926    1284387           China  Regex_institution
# 957    1284591   United States  Regex_institution
# 996    1284834           Japan  Regex_institution
# 1009   1284911           Japan  Regex_institution
# 1011   1284914           Japan  Regex_institution
# 1024   1285070   United States  Regex_institution
# 1032   1285216   United States  Regex_institution
# 1069   1285355   United States  Regex_institution
# 1158   1286048    South Africa  Regex_institution
# 1276   1286989   United States  Regex_institution
# 1300   1287209   United States  Regex_institution
# 1302   1287220   United States  Regex_institution
# 1310   1287228   United States  Regex_institution
# 1315   1287255           Japan  Regex_institution
# 1396   1288238           Japan  Regex_institution
# 1400   1288273   United States  Regex_institution
# 1468   1289123   United States  Regex_institution
# 1477   1289194          Israel  Regex_institution
# 1496   1289408   United States  Regex_institution
# 1502   1289420   United States  Regex_institution
# 1565   1289950   United States  Regex_institution
# 1591   1290204   United States  Regex_institution
# 1596   1290214   United States  Regex_institution
# 1618   1290415           Japan  Regex_institution
# 1713   1291144       Sri Lanka  Regex_institution
# 1727   1291242   United States  Regex_institution
# 1730   1291273   United States  Regex_institution
# 1776   1291755           Japan  Regex_institution
# 1780   1291760           Japan  Regex_institution
# 1797   1291888   United States  Regex_institution
# 1873   1292637   United States  Regex_institution
# 1882   1292742           Japan  Regex_institution
# 1973   1293224           Japan  Regex_institution
# 2128   1294690           Egypt  Regex_institution
# 2157   1295028   United States  Regex_institution
# 2165   1295038   United States  Regex_institution
# 2203   1295318   United States  Regex_institution
# 2363   1296600   United States  Regex_institution
# 2447   1297406   United States  Regex_institution
# 2449   1297431   United States  Regex_institution
# 2492   1297827   United States  Regex_institution
# 2522   1298225   United States  Regex_institution
# 2529   1298312           China  Regex_institution
# 2532   1298410   United States  Regex_institution
# 2533   1298413   United States  Regex_institution
# 2540   1298501   United States  Regex_institution
# 2541   1298570         Nigeria  Regex_institution
# 2570   1298796   United States  Regex_institution
# 2571   1298806   United States  Regex_institution
# 2648   1299460   United States  Regex_institution
# 2674   1299657   United States  Regex_institution
# 2707   1300108           Japan  Regex_institution
# 2722   1300262           Japan  Regex_institution
# 2959   1301129   United States  Regex_institution
# 2977   1301324           Japan  Regex_institution
# 3140   1302463   United States  Regex_institution
# 3233   1303125   United States  Regex_institution
# 3237   1303129   United States  Regex_institution
# 3499   1305466   United States  Regex_institution
# 3533   1305681   United States  Regex_institution
# 3596   1306108   United States  Regex_institution
# 3616   1306207          Serbia  Regex_institution
# 3641   1306319   United States  Regex_institution
# 3658   1306346         Türkiye  Regex_institution
# 3659   1306347         Türkiye  Regex_institution
# 3665   1306413           China  Regex_institution
# 3679   1306563   United States  Regex_institution
# 3686   1306607           Japan  Regex_institution
# 3760   1307332           China  Regex_institution
# 3773   1307503           China  Regex_institution
# 3830   1308219   United States  Regex_institution
# 3832   1308237   United States  Regex_institution
# 3911   1309207    South Africa  Regex_institution
# 3917   1309214   United States  Regex_institution
# 3922   1309219   United States  Regex_institution
# 3924   1309221   United States  Regex_institution
# 3930   1309227   United States  Regex_institution
# 3966   1309365   United States  Regex_institution
# 3967   1309379   United States  Regex_institution
# 3980   1309412   United States  Regex_institution
# 4007   1309467   United States  Regex_institution
# 4021   1309539   United States  Regex_institution
# 4023   1309543   United States  Regex_institution
# 4032   1309579   United States  Regex_institution
# 4043   1309612   United States  Regex_institution
# 4072   1309716   United States  Regex_institution
# 4103   1309911         Germany  Regex_institution
# 4110   1309952   United States  Regex_institution
# 4122   1310010   United States  Regex_institution
# 4177   1310241   United States  Regex_institution
# 4208   1310377   United States  Regex_institution
# 4255   1310553   United States  Regex_institution
# 4268   1310627  United Kingdom  Regex_institution
# 4276   1310639   United States  Regex_institution
# 4362   1310950   United States  Regex_institution
# 4386   1311022   United States  Regex_institution
# 4395   1311047   United States  Regex_institution
# 4413   1311138   United States  Regex_institution
# 4415   1311141   United States  Regex_institution
# 4466   1311375  United Kingdom  Regex_institution
# 4550   1311742   United States  Regex_institution
# 4582   1311888   United States  Regex_institution
# 4583   1311889   United States  Regex_institution
# 4589   1311912           Japan  Regex_institution
# 4592   1311915           Japan  Regex_institution
# 4596   1311924   United States  Regex_institution
# 4604   1311965   United States  Regex_institution
# 4627   1312005   United States  Regex_institution
# 4644   1312062   United States  Regex_institution
# 4653   1312078   United States  Regex_institution
# 4655   1312080           Japan  Regex_institution
# 4663   1312110           Japan  Regex_institution
# 4664   1312111           Japan  Regex_institution
# 4705   1312293           Japan  Regex_institution
# 4736   1312463   United States  Regex_institution
# 4756   1312627   United States  Regex_institution
# 4787   1312733   United States  Regex_institution
# 4814   1312850   United States  Regex_institution
# 4815   1312856   United States  Regex_institution
# 4874   1313058   United States  Regex_institution
# 4877   1313072   United States  Regex_institution
# 4878   1313093   United States  Regex_institution
# 4911   1313248   United States  Regex_institution
# 4916   1313285   United States  Regex_institution
# 4955   1313426   United States  Regex_institution
# 4964   1313469   United States  Regex_institution
# 4966   1313485   United States  Regex_institution
# 4968   1313488   United States  Regex_institution
# 4969   1313489   United States  Regex_institution
# 5006   1313679   United States  Regex_institution
# 5041   1313796   United States  Regex_institution
# 5057   1313895   United States  Regex_institution
# 5062   1313907   United States  Regex_institution
# 5090   1314023   United States  Regex_institution
# 5121   1314124   United States  Regex_institution
# 5122   1314126   United States  Regex_institution
# 5179   1314278   United States  Regex_institution
# 5188   1314321   United States  Regex_institution
# 5190   1314343   United States  Regex_institution
# 5220   1314462   United States  Regex_institution
# 5236   1314534         Hungary  Regex_institution
# 5265   1314696   United States  Regex_institution
# 5276   1314730   United States  Regex_institution
# 5305   1314817   United States  Regex_institution
# 5340   1315042   United States  Regex_institution
# 5343   1315048   United States  Regex_institution
# 5363   1315130   United States  Regex_institution
# 5387   1315207   United States  Regex_institution
# 5392   1315212   United States  Regex_institution
# 5398   1315242   United States  Regex_institution
# 5418   1315365   United States  Regex_institution
# 5424   1315400           Japan  Regex_institution
# 5447   1315485   United States  Regex_institution
# 5450   1315505   United States  Regex_institution
# 5458   1315549   United States  Regex_institution
# 5493   1315720   United States  Regex_institution
# 5518   1315889           Japan  Regex_institution
# 5526   1315945   United States  Regex_institution
# 5527   1315950           Japan  Regex_institution
# 5528   1315951           Japan  Regex_institution
# 5529   1315952           Japan  Regex_institution
# 5544   1316031   United States  Regex_institution
# 5569   1316103   United States  Regex_institution
# 5663   1316501           Japan  Regex_institution
# 5667   1316543   United States  Regex_institution
# 5684   1316611   United States  Regex_institution
# 5689   1316634   United States  Regex_institution
# 5705   1316718   United States  Regex_institution
# 5777   1317057   United States  Regex_institution
# 5852   1317392   United States  Regex_institution
# 5858   1317483   United States  Regex_institution
# 5880   1317573   United States  Regex_institution
# 5914   1317695   United States  Regex_institution
# 5929   1317747   United States  Regex_institution
# 5939   1317783   United States  Regex_institution
# 5960   1317891   United States  Regex_institution
# 5967   1317945   United States  Regex_institution
# 6010   1318197   United States  Regex_institution
# 6018   1318254   United States  Regex_institution
# 6051   1318430           Japan  Regex_institution
# 6052   1318431           Japan  Regex_institution
# 6070   1318470   United States  Regex_institution
# 6113   1318636   United States  Regex_institution
# 6144   1318773   United States  Regex_institution
# 6186   1318915           Japan  Regex_institution
# 6200   1318973   United States  Regex_institution
# 6209   1319000   United States  Regex_institution
# 6229   1319093   United States  Regex_institution
# 6235   1319115   United States  Regex_institution
# 6243   1319143   United States  Regex_institution
# 6246   1319161   United States  Regex_institution
# 6269   1319282   United States  Regex_institution
# 6302   1319430   United States  Regex_institution
# 6303   1319432   United States  Regex_institution
# 6304   1319436   United States  Regex_institution
# 6328   1319566         Croatia  Regex_institution
# 6350   1319733    South Africa  Regex_institution
# 6361   1319774    South Africa  Regex_institution
# 6434   1319983           Japan  Regex_institution
# 6436   1319985           Japan  Regex_institution
# 6451   1320085           Japan  Regex_institution
# 6465   1320136           Japan  Regex_institution
# 6470   1320141           Japan  Regex_institution
# 6474   1320146           Japan  Regex_institution
# 6513   1320356   United States  Regex_institution
# 6553   1320567   United States  Regex_institution
# 6565   1320599   United States  Regex_institution
# 6573   1320639   United States  Regex_institution
# 6579   1320664   United States  Regex_institution
# 6596   1320711   United States  Regex_institution
# 6642   1320898  United Kingdom  Regex_institution
# 6703   1321146   United States  Regex_institution
# 6740   1321298   United States  Regex_institution
# 6753   1321351           Japan  Regex_institution
# 6767   1321410           Japan  Regex_institution
# 6773   1321438   United States  Regex_institution
# 6809   1321656   United States  Regex_institution
# 6853   1321843   United States  Regex_institution
# 6865   1321894   United States  Regex_institution
# 6880   1321980   United States  Regex_institution
# 6917   1322201   United States  Regex_institution
# 6971   1322386   United States  Regex_institution
# 6972   1322387   United States  Regex_institution
# 6973   1322388   United States  Regex_institution
# 6999   1322525           Japan  Regex_institution
# 7005   1322566   United States  Regex_institution
# 7019   1322643   United States  Regex_institution
# 7116   1323109   United States  Regex_institution
# 7122   1323117   United States  Regex_institution
# 7130   1323146   United States  Regex_institution
# 7132   1323162         Nigeria  Regex_institution
# 7179   1323335   United States  Regex_institution
# 7201   1323425   United States  Regex_institution
# 7237   1323643   United States  Regex_institution
# 7241   1323649   United States  Regex_institution
# 7254   1323723           Japan  Regex_institution
# 7264   1323810   United States  Regex_institution
# 7267   1323813   United States  Regex_institution
# 7278   1323840   United States  Regex_institution
# 7293   1323924   United States  Regex_institution
# 7325   1324026         Denmark  Regex_institution
# 7331   1324094   United States  Regex_institution
# 7335   1324151   United States  Regex_institution
# 7336   1324153   United States  Regex_institution
# 7340   1324184   United States  Regex_institution
# 7355   1324234           Japan  Regex_institution
# 7359   1324266   United States  Regex_institution
# 7361   1324283           Japan  Regex_institution
# 7369   1324326   United States  Regex_institution
# 7374   1324379           Japan  Regex_institution
# 7388   1324442           Japan  Regex_institution
# 7393   1324465           Japan  Regex_institution
# 7394   1324466           Japan  Regex_institution
# 7398   1324470           Japan  Regex_institution
# 7464   1324797   United States  Regex_institution
# 7483   1324877   United States  Regex_institution
# 7548   1325157  United Kingdom  Regex_institution
# 7568   1325213   United States  Regex_institution
# 7570   1325215   United States  Regex_institution
# 7590   1325280   United States  Regex_institution
# 7592   1325282   United States  Regex_institution
# 7600   1325290   United States  Regex_institution
# 7612   1325398   United States  Regex_institution
# 7622   1325427           Japan  Regex_institution
# 7623   1325428           Japan  Regex_institution
# 7626   1325431           Japan  Regex_institution
# 7641   1325525   United States  Regex_institution
# 7657   1325571           Japan  Regex_institution
# 7661   1325576   United States  Regex_institution
# 7664   1325579   United States  Regex_institution
# 7676   1325643   United States  Regex_institution
# 7693   1325739   United States  Regex_institution
# 7721   1325845   United States  Regex_institution
# 7785   1326226   United States  Regex_institution
# 7788   1326250   United States  Regex_institution
# 7867   1326612   United States  Regex_institution
# 7876   1326663   United States  Regex_institution
# 7892   1326756   United States  Regex_institution
# 7918   1326885   United States  Regex_institution
# 7930   1326909           Japan  Regex_institution
# 7937   1326916           Japan  Regex_institution
# 7940   1326919           Japan  Regex_institution
# 7942   1326921           Japan  Regex_institution
# 7943   1326922           Japan  Regex_institution
# 7944   1326923           Japan  Regex_institution
# 7946   1326925           Japan  Regex_institution
# 7951   1326940  United Kingdom  Regex_institution
# 7959   1327014   United States  Regex_institution
# 7975   1327035   United States  Regex_institution
# 8002   1327082   United States  Regex_institution
# 8022   1327203   United States  Regex_institution
# 8026   1327243   United States  Regex_institution
# 8049   1327313   United States  Regex_institution
# 8061   1327374  United Kingdom  Regex_institution
# 8067   1327435           China  Regex_institution
# 8077   1327481          Taiwan  Regex_institution
# 8081   1327487   United States  Regex_institution
# 8083   1327489   United States  Regex_institution
# 8085   1327491   United States  Regex_institution
# 8101   1327509   United States  Regex_institution
# 8123   1327543   United States  Regex_institution
# 8146   1327654  United Kingdom  Regex_institution
# 8212   1328004           Japan  Regex_institution
# 8215   1328011    South Africa  Regex_institution
# 8260   1328123           Japan  Regex_institution
# 8274   1328253          Israel  Regex_institution
# 8285   1328334   United States  Regex_institution
# 8341   1328611   United States  Regex_institution
# 8353   1328712           Japan  Regex_institution
# 8355   1328725           Japan  Regex_institution
# 8361   1328731           Japan  Regex_institution
# 8368   1328771   United States  Regex_institution
# 8373   1328802   United States  Regex_institution
# 8387   1328870   United States  Regex_institution
# 8423   1329046   United States  Regex_institution
# 8447   1329142   United States  Regex_institution
# 8568   1329747   United States  Regex_institution
# 8574   1329797   United States  Regex_institution
# 8592   1329904   United States  Regex_institution
# 8606   1329932           Japan  Regex_institution
# 8648   1330148  United Kingdom  Regex_institution
# 8651   1330152   United States  Regex_institution
# 8689   1330295   United States  Regex_institution
# 8792   1330911   United States  Regex_institution
# 8794   1330913         Denmark  Regex_institution
# 8795   1330914   United States  Regex_institution
# 8825   1331003           Japan  Regex_institution
# 8827   1331005           Japan  Regex_institution
# 8854   1331192   United States  Regex_institution
# 8874   1331240   United States  Regex_institution
# 8887   1331341   United States  Regex_institution
# 8917   1331501   United States  Regex_institution
# 8932   1331571           Japan  Regex_institution
# 8933   1331572           Japan  Regex_institution
# 8937   1331600           Japan  Regex_institution
# 8938   1331602           Japan  Regex_institution
# 8956   1331729   United States  Regex_institution
# 8963   1331774   United States  Regex_institution
# 8973   1331836   United States  Regex_institution
# 9008   1332035   United States  Regex_institution
# 9013   1332049   United States  Regex_institution
# 9024   1332114         Germany  Regex_institution
# 9056   1332253   United States  Regex_institution
# 9089   1332456   United States  Regex_institution
# 9158   1332741   United States  Regex_institution
# 9205   1333017           Japan  Regex_institution
# 9207   1333019           Japan  Regex_institution
# 9208   1333020           Japan  Regex_institution
# 9219   1333053   United States  Regex_institution
# 9221   1333064   United States  Regex_institution
# 9223   1333066   United States  Regex_institution
# 9224   1333069           Japan  Regex_institution
# 9243   1333146           Japan  Regex_institution
# 9244   1333165   United States  Regex_institution
# 9245   1333166   United States  Regex_institution
# 9246   1333167   United States  Regex_institution
# 9274   1333267   United States  Regex_institution
# 9345   1333517   United States  Regex_institution
# 9354   1333557   United States  Regex_institution
# 9367   1333609   United States  Regex_institution
# 9380   1333650           Japan  Regex_institution
# 9391   1333749   United States  Regex_institution
# 9467   1333983   United States  Regex_institution
# 9485   1334054   United States  Regex_institution
# 9505   1334112  United Kingdom  Regex_institution
# 9511   1334139  United Kingdom  Regex_institution
# 9519   1334154   United States  Regex_institution
# 9520   1334164           Japan  Regex_institution
# 9522   1334166           Japan  Regex_institution
# 9537   1334249   United States  Regex_institution
# 9544   1334280   United States  Regex_institution
# 9607   1334635   United States  Regex_institution
# 9614   1334692   United States  Regex_institution
# 9648   1334938   United States  Regex_institution
# 9666   1335042   United States  Regex_institution
# 9680   1335091   United States  Regex_institution
# 9712   1335188   United States  Regex_institution
# 9728   1335248   United States  Regex_institution
# 9746   1335372           China  Regex_institution
# 9769   1335475   United States  Regex_institution
# 9773   1335526           Japan  Regex_institution
# 9874   1336124   United States  Regex_institution
# 9889   1336209   United States  Regex_institution
# 9900   1336305           Japan  Regex_institution
# 9910   1336391   United States  Regex_institution
# 9912   1336393           Japan  Regex_institution
# 9931   1336490           Japan  Regex_institution
# 9934   1336493           Japan  Regex_institution
# 9981   1336708   United States  Regex_institution
# 10031  1336897   United States  Regex_institution
# 10065  1337030   United States  Regex_institution
# 10082  1337124           Japan  Regex_institution
# 10089  1337185   United States  Regex_institution
# 10117  1337324   United States  Regex_institution
# 10216  1337762           Japan  Regex_institution
# 10222  1337797   United States  Regex_institution
# 10237  1337829   United States  Regex_institution
# 10244  1337839   United States  Regex_institution
# 10252  1337866   United States  Regex_institution
# 10299  1338061   United States  Regex_institution
# 10327  1338232   United States  Regex_institution
# 10359  1338365   United States  Regex_institution
# 10497  1338998        Malaysia  Regex_institution
# 10520  1339094           Japan  Regex_institution
# 10552  1339191   United States  Regex_institution
# 10567  1339300   United States  Regex_institution
# 10619  1339816           Japan  Regex_institution
# 10688  1340210   United States  Regex_institution
# 10714  1340515   United States  Regex_institution
# 10719  1340569           Chile  Regex_institution
# 10758  1340903   United States  Regex_institution
# 10815  1341247   United States  Regex_institution
# 10844  1341276   United States  Regex_institution
# 10901  1341663   United States  Regex_institution
# 10940  1342048   United States  Regex_institution
# 10965  1342309   United States  Regex_institution
# 11022  1342956   United States  Regex_institution
# 11031  1342968   United States  Regex_institution
# 11033  1342970   United States  Regex_institution
# 11055  1343093  United Kingdom  Regex_institution
# 11117  1343570   United States  Regex_institution
# 11123  1343707   United States  Regex_institution
# 11125  1343751   United States  Regex_institution
# 11175  1344276         Nigeria  Regex_institution
# 11180  1344348           Japan  Regex_institution
# 11187  1344427           Japan  Regex_institution
# 11231  1344668   United States  Regex_institution
# 11251  1344815   United States  Regex_institution
# 11364  1345678   United States  Regex_institution
# 11365  1345679   United States  Regex_institution
# 11423  1346083           Japan  Regex_institution
# 11427  1346087           Japan  Regex_institution
# 11449  1346255   United States  Regex_institution
# 11473  1346493   United States  Regex_institution
# 11570  1347082   United States  Regex_institution
# 11639  1347557           Japan  Regex_institution
# 11652  1347663   United States  Regex_institution
# 11675  1347745   United States  Regex_institution
# 11678  1347754  United Kingdom  Regex_institution
# 11743  1348283   United States  Regex_institution
# 11814  1348778   United States  Regex_institution
# 11815  1348796   United States  Regex_institution
# 11850  1348973   United States  Regex_institution
# 11869  1349046           Japan  Regex_institution
# 11897  1349244   United States  Regex_institution
# 11934  1349513   United States  Regex_institution
# 11979  1349840   United States  Regex_institution
# 12089  1350646           Japan  Regex_institution
# 12125  1350939   United States  Regex_institution
# 12168  1351318   United States  Regex_institution
# 12183  1351513           Japan  Regex_institution
# 12184  1351514           Japan  Regex_institution
# 12191  1351534   United States  Regex_institution
# 12209  1351658   United States  Regex_institution
# 12238  1351861  United Kingdom  Regex_institution
# 12247  1351885   United States  Regex_institution
# 12315  1352321           Japan  Regex_institution
# 12358  1352687   United States  Regex_institution
# 12371  1352788   United States  Regex_institution
# 12409  1353118   United States  Regex_institution
# 12450  1353412   United States  Regex_institution
# 12503  1353753           Japan  Regex_institution
# 12504  1353754           Japan  Regex_institution
# 12506  1353756           Japan  Regex_institution
# 12570  1354355   United States  Regex_institution
# 12663  1355010   United States  Regex_institution
# 12718  1355366   United States  Regex_institution
# 12749  1355522   United States  Regex_institution
# 12754  1355571           Japan  Regex_institution
# 12785  1355757   United States  Regex_institution
# 12848  1356108   United States  Regex_institution
# 12869  1356339   United States  Regex_institution
# 12935  1356675   United States  Regex_institution
# 12963  1356959           Japan  Regex_institution
# 12998  1357216           Japan  Regex_institution
# 13089  1357973   United States  Regex_institution
# 13164  1358440  United Kingdom  Regex_institution
# 13192  1358743   United States  Regex_institution
# 13204  1358812   United States  Regex_institution
# 13232  1359144   United States  Regex_institution
# 13238  1359155   United States  Regex_institution
# 13393  1360266   United States  Regex_institution
# 13411  1360410   United States  Regex_institution
# 13430  1360549           Japan  Regex_institution
# 13431  1360550           Japan  Regex_institution
# 13443  1360710   United States  Regex_institution
# 13446  1360713   United States  Regex_institution
# 13455  1360785   United States  Regex_institution
# 13481  1360912   United States  Regex_institution
# 13484  1360981   United States  Regex_institution
# 13525  1361373   United States  Regex_institution
# 13545  1361520   United States  Regex_institution
# 13576  1361720   United States  Regex_institution
# 13607  1362127   United States  Regex_institution
# 13628  1362284   United States  Regex_institution
# 13669  1362429           Japan  Regex_institution
# 13671  1362439   United States  Regex_institution
# 13694  1362576   United States  Regex_institution
# 13785  1363258   United States  Regex_institution
# 13817  1363379   United States  Regex_institution
# 13880  1363885   United States  Regex_institution
# 13893  1363977   United States  Regex_institution
# 14002  1365035   United States  Regex_institution
# 14040  1365682   United States  Regex_institution
# 14052  1365747   United States  Regex_institution
# 14211  1369360   United States  Regex_institution
# 14224  1369471   United States  Regex_institution
# 14300  1370063   United States  Regex_institution
# 14305  1370074   United States  Regex_institution
# 14327  1370188   United States  Regex_institution
# 14351  1370263   United States  Regex_institution
# 14368  1370384   United States  Regex_institution
# 14412  1370633   United States  Regex_institution
# 14445  1370766   United States  Regex_institution
# 14446  1370768   United States  Regex_institution
# 14447  1370771   United States  Regex_institution
# 14464  1370849   United States  Regex_institution
# 14493  1370958   United States  Regex_institution
# 14514  1371081   United States  Regex_institution
# 14522  1371091   United States  Regex_institution
# 14538  1371176   United States  Regex_institution
# 14555  1371262   United States  Regex_institution
# 14560  1371295   United States  Regex_institution
# 14566  1371351   United States  Regex_institution
# 14577  1371413   United States  Regex_institution
# 14652  1371717   United States  Regex_institution
# 14656  1371722   United States  Regex_institution
# 14669  1371813   United States  Regex_institution
# 14676  1371870   United States  Regex_institution
# 14677  1371872   United States  Regex_institution
# 14680  1371877   United States  Regex_institution
# 14681  1371882   United States  Regex_institution
# 14697  1371926   United States  Regex_institution
# 14714  1371989           Japan  Regex_institution
# 14719  1372004   United States  Regex_institution
# 14724  1372033           Japan  Regex_institution
# 14752  1372126  United Kingdom  Regex_institution
# 14788  1372357   United States  Regex_institution
# 14814  1372464   United States  Regex_institution
# 14817  1372477   United States  Regex_institution
# 14837  1372636   United States  Regex_institution
# 14875  1372801   United States  Regex_institution
# 14886  1372840   United States  Regex_institution
# 14900  1372887           Japan  Regex_institution
# 14903  1372901   United States  Regex_institution
# 14924  1373003   United States  Regex_institution
# 14948  1373088   United States  Regex_institution
# 14955  1373112   United States  Regex_institution
# 15008  1373340   United States  Regex_institution
# 15009  1373341   United States  Regex_institution
# 15032  1373444   United States  Regex_institution
# 15033  1373451           Japan  Regex_institution
# 15035  1373453           Japan  Regex_institution
# 15049  1373500   United States  Regex_institution
# 15059  1373547   United States  Regex_institution
# 15137  1373880   United States  Regex_institution
# 15161  1373989   United States  Regex_institution
# 15190  1374135     South Korea  Regex_institution
# 15195  1374149   United States  Regex_institution
# 15200  1374171   United States  Regex_institution
# 15231  1374248  United Kingdom  Regex_institution
# 15267  1374455   United States  Regex_institution
# 15268  1374476   United States  Regex_institution
# 15276  1374505  United Kingdom  Regex_institution
# 15285  1374522   United States  Regex_institution
# 15326  1374683   United States  Regex_institution
# 15329  1374691   United States  Regex_institution
# 15337  1374736   United States  Regex_institution
# 15351  1374811   United States  Regex_institution
# 15363  1374897   United States  Regex_institution
# 15407  1375218   United States  Regex_institution
# 15419  1375281  United Kingdom  Regex_institution
# 15451  1375477       Australia  Regex_institution
# 15454  1375482  United Kingdom  Regex_institution
# 15465  1375521   United States  Regex_institution
# 15487  1375656   United States  Regex_institution
# 15488  1375657   United States  Regex_institution
# 15499  1375718   United States  Regex_institution
# 15517  1375808   United States  Regex_institution
# 15528  1375852   United States  Regex_institution
# 15557  1375978           Japan  Regex_institution
# 15558  1375982           Japan  Regex_institution
# 15559  1375983           Japan  Regex_institution
# 15566  1376020   United States  Regex_institution
# 15604  1376191   United States  Regex_institution
# 15617  1376204   United States  Regex_institution
# 15629  1376227   United States  Regex_institution
# 15645  1376354   United States  Regex_institution
# 15712  1376723   United States  Regex_institution
# 15727  1376860           Japan  Regex_institution
# 15730  1376868           Japan  Regex_institution
# 15757  1377007   United States  Regex_institution
# 15775  1377054   United States  Regex_institution
# 15776  1377055   United States  Regex_institution
# 15779  1377084   United States  Regex_institution
# 15802  1377186   United States  Regex_institution
# 15809  1377209   United States  Regex_institution
# 15810  1377210   United States  Regex_institution
# 15880  1377595   United States  Regex_institution
# 15896  1377668           Japan  Regex_institution
# 15897  1377669           Japan  Regex_institution
# 15908  1377758           Japan  Regex_institution
# 15917  1377793           Japan  Regex_institution
# 15919  1377800           Japan  Regex_institution
# 15928  1377838   United States  Regex_institution
# 15961  1377945   United States  Regex_institution
# 15963  1377976   United States  Regex_institution
# 16009  1378297   United States  Regex_institution
# 16014  1378311   United States  Regex_institution
# 16017  1378314   United States  Regex_institution
# 16018  1378315   United States  Regex_institution
# 16019  1378316   United States  Regex_institution
# 16047  1378531   United States  Regex_institution
# 16053  1378567           Japan  Regex_institution
# 16077  1378698   United States  Regex_institution
# 16080  1378713   United States  Regex_institution
# 16087  1378763   United States  Regex_institution
# 16112  1378905   United States  Regex_institution
# 16117  1378916   United States  Regex_institution
# 16130  1378983   United States  Regex_institution
# 16154  1379115   United States  Regex_institution
# 16195  1379363   United States  Regex_institution
# 16239  1379577           Japan  Regex_institution
# 16258  1379704   United States  Regex_institution
# 16261  1379731   United States  Regex_institution
# 16282  1379847   United States  Regex_institution
# 16283  1379848   United States  Regex_institution
# 16290  1379890           China  Regex_institution
# 16308  1379962   United States  Regex_institution
# 16330  1380077   United States  Regex_institution
# 16352  1380203   United States  Regex_institution
# 16370  1380279   United States  Regex_institution
# 16384  1380377  United Kingdom  Regex_institution
# 16406  1380571           Japan  Regex_institution
# 16452  1380886   United States  Regex_institution
# 16467  1380941   United States  Regex_institution
# 16490  1381057           Japan  Regex_institution
# 16491  1381058           Japan  Regex_institution
# 16492  1381061           Japan  Regex_institution
# 16512  1381160   United States  Regex_institution
# 16522  1381228       Australia  Regex_institution
# 16524  1381236   United States  Regex_institution
# 16532  1381270   United States  Regex_institution
# 16543  1381333   United States  Regex_institution
# 16544  1381334   United States  Regex_institution
# 16547  1381340           Japan  Regex_institution
# 16567  1381448           Japan  Regex_institution
# 16568  1381449           Japan  Regex_institution
# 16569  1381450           Japan  Regex_institution
# 16570  1381451           Japan  Regex_institution
# 16623  1381759        Pakistan  Regex_institution
# 16634  1381866           Japan  Regex_institution
# 16675  1382047   United States  Regex_institution
# 16703  1382383           Japan  Regex_institution
# 16705  1382395           Japan  Regex_institution
# 16751  1382561   United States  Regex_institution
# 16769  1382650   United States  Regex_institution
# 16847  1382897   United States  Regex_institution
# 16899  1383254   United States  Regex_institution
# 16905  1383293   United States  Regex_institution
# 16915  1383347   United States  Regex_institution
# 16931  1383433   United States  Regex_institution
# 16937  1383481   United States  Regex_institution
# 16977  1383764   United States  Regex_institution
# 16992  1383851           Japan  Regex_institution
# 16993  1383852           Japan  Regex_institution
# 16995  1383861           Japan  Regex_institution
# 17017  1384036   United States  Regex_institution
# 17037  1384142   United States  Regex_institution
# 17099  1384367   United States  Regex_institution
# 17105  1384373   United States  Regex_institution
# 17126  1384525   United States  Regex_institution
# 17172  1384682   United States  Regex_institution
# 17193  1384795   United States  Regex_institution
# 17197  1384801   United States  Regex_institution
# 17208  1384869   United States  Regex_institution
# 17243  1384968   United States  Regex_institution
# 17247  1384998   United States  Regex_institution
# 17260  1385097   United States  Regex_institution
# 17262  1385103   United States  Regex_institution
# 17298  1385305   United States  Regex_institution
# 17308  1385355   United States  Regex_institution
# 17312  1385392           Japan  Regex_institution
# 17334  1385513   United States  Regex_institution
# 17341  1385604   United States  Regex_institution
# 17346  1385638   United States  Regex_institution
# 17442  1386556   United States  Regex_institution
# 17461  1386679   United States  Regex_institution
# 17467  1386713   United States  Regex_institution
# 17468  1386715   United States  Regex_institution
# 17507  1387016   United States  Regex_institution
# 17520  1387147   United States  Regex_institution
# 17526  1387181           Japan  Regex_institution
# 17533  1387246   United States  Regex_institution
# 17578  1387653   United States  Regex_institution
# 17590  1387731   United States  Regex_institution
# 17628  1387980           Japan  Regex_institution
# 17629  1387999    South Africa  Regex_institution
# 17643  1388048    South Africa  Regex_institution
# 17655  1388146         Germany  Regex_institution
# 17668  1388301   United States  Regex_institution
# 17712  1388678   United States  Regex_institution
# 17713  1388681   United States  Regex_institution
# 17721  1388719  United Kingdom  Regex_institution
# 17810  1389511   United States  Regex_institution
# 17862  1389694   United States  Regex_institution
# 17878  1389902   United States  Regex_institution
# 17915  1390057   United States  Regex_institution
# 18026  1390539   United States  Regex_institution
# 18052  1390976   United States  Regex_institution
# 18086  1391307   United States  Regex_institution
# 18093  1391528   United States  Regex_institution
# 18096  1391531   United States  Regex_institution
# 18097  1391532   United States  Regex_institution
# 18144  1391940   United States  Regex_institution
# 18155  1391975   United States  Regex_institution
# 18216  1392253   United States  Regex_institution
# 18261  1392575   United States  Regex_institution
# 18265  1392579   United States  Regex_institution
# 18270  1392584   United States  Regex_institution
# 18366  1393694   United States  Regex_institution
# 18420  1394043   United States  Regex_institution
# 18423  1394046   United States  Regex_institution
# 18461  1394107  United Kingdom  Regex_institution
# 18483  1394129   United States  Regex_institution
# 18486  1394132   United States  Regex_institution
# 18500  1394146   United States  Regex_institution
# 18508  1394154   United States  Regex_institution
# 18519  1394165   United States  Regex_institution
# 18523  1394169   United States  Regex_institution
# 18551  1394197   United States  Regex_institution
# 18568  1394214   United States  Regex_institution
# 18575  1394221   United States  Regex_institution
# 18583  1394229   United States  Regex_institution
# 18714  1394851   United States  Regex_institution
# 18738  1395122   United States  Regex_institution
# 18739  1395128   United States  Regex_institution
# 18740  1395132   United States  Regex_institution
# 18755  1395324           Japan  Regex_institution
# 18763  1395364   United States  Regex_institution
# 18785  1395713   United States  Regex_institution
# 18842  1396022   United States  Regex_institution
# 18845  1396026   United States  Regex_institution
# 18851  1396032   United States  Regex_institution
# 18908  1396194         Nigeria  Regex_institution
# 18923  1396465   United States  Regex_institution
# 18925  1396493   United States  Regex_institution
# 19002  1397382           Japan  Regex_institution
# 19014  1397463           Japan  Regex_institution
# 19016  1397494   United States  Regex_institution
# 19041  1397909   United States  Regex_institution
# 19060  1398067   United States  Regex_institution
# 19072  1398227  United Kingdom  Regex_institution
# 19149  1398641   United States  Regex_institution
# 19215  1399139   United States  Regex_institution
# 19243  1399315   United States  Regex_institution
# 19246  1399323   United States  Regex_institution
# 19279  1399569   United States  Regex_institution
# 19284  1399576   United States  Regex_institution
# 19297  1399636   United States  Regex_institution
# 19314  1399725   United States  Regex_institution
# 19317  1399728   United States  Regex_institution
# 19320  1399731   United States  Regex_institution
# 19324  1399735   United States  Regex_institution
# 19344  1399816           Japan  Regex_institution
# 19346  1399818           Japan  Regex_institution
# 19347  1399819           Japan  Regex_institution
# 19348  1399820           Japan  Regex_institution
# 19349  1399821           Japan  Regex_institution
# 19350  1399822           Japan  Regex_institution
# 19351  1399823           Japan  Regex_institution
# 19352  1399824           Japan  Regex_institution
# 19355  1399827           Japan  Regex_institution
# 19356  1399828   United States  Regex_institution
# 19375  1400401   United States  Regex_institution
# 19382  1400545   United States  Regex_institution
# 19413  1400884   United States  Regex_institution
# 19436  1401166   United States  Regex_institution
# 19456  1401274   United States  Regex_institution
# 19458  1401279   United States  Regex_institution
# 19461  1401284   United States  Regex_institution
# 19468  1401305   United States  Regex_institution
# 19475  1401342   United States  Regex_institution
# 19483  1401422          Canada  Regex_institution
# 19528  1401905   United States  Regex_institution
# 19548  1402058           Japan  Regex_institution
# 19550  1402094           Japan  Regex_institution
# 19567  1402141   United States  Regex_institution
# 19591  1402224           Japan  Regex_institution
# 19644  1402648   United States  Regex_institution
# 19646  1402653   United States  Regex_institution
# 19662  1402732   United States  Regex_institution
# 19680  1403037   United States  Regex_institution
# 19683  1403040   United States  Regex_institution
# 19684  1403041   United States  Regex_institution
# 19705  1403062   United States  Regex_institution
# 19725  1403127   United States  Regex_institution
# 19750  1403316           Japan  Regex_institution
# 19753  1403330           Japan  Regex_institution
# 19801  1403809  United Kingdom  Regex_institution
# 19812  1403988   United States  Regex_institution
# 19839  1404452   United States  Regex_institution
# 19857  1404586   United States  Regex_institution
# 19858  1404588   United States  Regex_institution
# 19885  1404715   United States  Regex_institution
# 19887  1404740   United States  Regex_institution
# 19899  1404836        Pakistan  Regex_institution
# 19907  1404863           Japan  Regex_institution
# 19914  1404963           Japan  Regex_institution
# 19925  1404996           Japan  Regex_institution
# 19940  1405161           Japan  Regex_institution
# 19941  1405162           Japan  Regex_institution
# 19942  1405165           Japan  Regex_institution
# 19944  1405170           Japan  Regex_institution
# 19960  1405608   United States  Regex_institution
# 19989  1405719   United States  Regex_institution
# 19992  1405722   United States  Regex_institution
# 19998  1405756   United States  Regex_institution
# 20037  1406088   United States  Regex_institution
# 20039  1406194   United States  Regex_institution
# 20074  1406656   United States  Regex_institution
# 20098  1406793   United States  Regex_institution
# 20123  1407023   United States  Regex_institution
# 20160  1407340           Japan  Regex_institution
# 20166  1407349           Japan  Regex_institution
# 20169  1407363           Japan  Regex_institution
# 20191  1407462   United States  Regex_institution
# 20215  1407568   United States  Regex_institution
# 20225  1407609   United States  Regex_institution
# 20259  1407974   United States  Regex_institution
# 20300  1408150   United States  Regex_institution
# 20313  1408224   United States  Regex_institution
# 20352  1408684           Japan  Regex_institution
# 20353  1408687           Japan  Regex_institution
# 20377  1408943   United States  Regex_institution
# 20390  1408968   United States  Regex_institution
# 20468  1409404   United States  Regex_institution
# 20472  1409415   United States  Regex_institution
# 20483  1409427   United States  Regex_institution
# 20513  1409589   United States  Regex_institution
# 20543  1410057   United States  Regex_institution
# 20544  1410058   United States  Regex_institution
# 20550  1410064   United States  Regex_institution
# 20551  1410065   United States  Regex_institution
# 20552  1410066   United States  Regex_institution
# 20570  1410337   United States  Regex_institution
# 20574  1410347   United States  Regex_institution
# 20577  1410352   United States  Regex_institution
# 20579  1410362   United States  Regex_institution
# 20587  1410445   United States  Regex_institution
# 20616  1410578   United States  Regex_institution
# 20639  1410658   United States  Regex_institution
# 20697  1411138   United States  Regex_institution
# 20761  1411535   United States  Regex_institution
# 20773  1411617     Netherlands  Regex_institution
# 20775  1411619   United States  Regex_institution
# 20803  1411647   United States  Regex_institution
# 20812  1411656   United States  Regex_institution
# 20820  1411716   United States  Regex_institution
# 20938  1413118   United States  Regex_institution
# 20996  1413536           Japan  Regex_institution
# 21003  1413743   United States  Regex_institution
# 21073  1414160   United States  Regex_institution
# 21121  1414668  United Kingdom  Regex_institution
# 21133  1414740           Japan  Regex_institution
# 21144  1414754           Japan  Regex_institution
# 21150  1414761           Japan  Regex_institution
# 21154  1414774   United States  Regex_institution
# 21155  1414776   United States  Regex_institution
# 21171  1414824   United States  Regex_institution
# 21183  1415042   United States  Regex_institution
# 21250  1415500   United States  Regex_institution
# 21262  1415903   United States  Regex_institution
# 21284  1416146   United States  Regex_institution
# 21342  1416813   United States  Regex_institution
# 21352  1417007           Japan  Regex_institution
# 21354  1417009           Japan  Regex_institution
# 21388  1417225   United States  Regex_institution
# 21395  1417305   United States  Regex_institution
# 21397  1417445   United States  Regex_institution
# 21398  1417447   United States  Regex_institution
# 21400  1417449   United States  Regex_institution
# 21405  1417493   United States  Regex_institution
# 21424  1417887           Japan  Regex_institution
# 21437  1418122   United States  Regex_institution
# 21463  1418445   United States  Regex_institution
# 21465  1418597   United States  Regex_institution
# 21467  1418611   United States  Regex_institution
# 21496  1418894   United States  Regex_institution
# 21497  1418895   United States  Regex_institution
# 21511  1419031   United States  Regex_institution
# 21512  1419032   United States  Regex_institution
# 21513  1419033   United States  Regex_institution
# 21514  1419034   United States  Regex_institution
# 21515  1419035   United States  Regex_institution
# 21546  1419171           Japan  Regex_institution
# 21581  1419305   United States  Regex_institution
# 21611  1419578   United States  Regex_institution
# 21615  1419582   United States  Regex_institution
# 21619  1419586   United States  Regex_institution
# 21622  1419589   United States  Regex_institution
# 21698  1419814   United States  Regex_institution
# 21707  1419837   United States  Regex_institution
# 21755  1420282   United States  Regex_institution
# 21854  1421367   United States  Regex_institution
# 21866  1421400   United States  Regex_institution
# 21875  1421415   United States  Regex_institution
# 21935  1421740   United States  Regex_institution
# 21972  1422295   United States  Regex_institution
# 21986  1422472  United Kingdom  Regex_institution
# 21995  1422483   United States  Regex_institution
# ...
# 92906  1942524           Japan  Regex_institution
# 92910  1942529           Japan  Regex_institution
# 92911  1942530           Japan  Regex_institution
# 92913  1942532           Japan  Regex_institution
# 92915  1942535           Japan  Regex_institution
# 92920  1942543           Japan  Regex_institution
# 92922  1942546           Japan  Regex_institution
# 92927  1942551           Japan  Regex_institution
# 92934  1942558           Japan  Regex_institution
# 92939  1942568           Japan  Regex_institution
# 92941  1942580           Japan  Regex_institution
# 92942  1942581           Japan  Regex_institution
# 92943  1942589           Japan  Regex_institution
# 92959  1942687           Japan  Regex_institution
# 92967  1942709           Japan  Regex_institution
# 92968  1942710           Japan  Regex_institution
# 93005  1943001           Japan  Regex_institution
# 93065  1943443   United States  Regex_institution
# 93203  1944345   United States  Regex_institution
# 93223  1944622   United States  Regex_institution
# 93224  1944623   United States  Regex_institution
# 93235  1944697   United States  Regex_institution
# 93241  1944780           Japan  Regex_institution
# 93242  1944785           Japan  Regex_institution
# 93243  1944786           Japan  Regex_institution
# 93244  1944787           Japan  Regex_institution
# 93246  1944795           Japan  Regex_institution
# 93255  1944830   United States  Regex_institution
# 93269  1944906   United States  Regex_institution
# 93301  1945073   United States  Regex_institution
# 93314  1945224   United States  Regex_institution
# 93343  1945769           Japan  Regex_institution
# 93345  1945776     South Korea  Regex_institution
# 93347  1945778           Japan  Regex_institution
# 93366  1945966   United States  Regex_institution
# 93371  1945971   United States  Regex_institution
# 93414  1946376   United States  Regex_institution
# 93477  1947008   United States  Regex_institution
# 93491  1947090   United States  Regex_institution
# 93494  1947093   United States  Regex_institution
# 93497  1947102   United States  Regex_institution
# 93498  1947103   United States  Regex_institution
# 93557  1947300   United States  Regex_institution
# 93558  1947301   United States  Regex_institution
# 93561  1947313   United States  Regex_institution
# 93562  1947314   United States  Regex_institution
# 93563  1947324   United States  Regex_institution
# 93564  1947325   United States  Regex_institution
# 93581  1947412   United States  Regex_institution
# 93602  1947521   United States  Regex_institution
# 93673  1948127   United States  Regex_institution
# 93680  1948134   United States  Regex_institution
# 93685  1948216   United States  Regex_institution
# 93711  1948451           Japan  Regex_institution
# 93726  1948562   United States  Regex_institution
# 93727  1948563   United States  Regex_institution
# 93733  1948604   United States  Regex_institution
# 93746  1948631   United States  Regex_institution
# 93838  1949397   United States  Regex_institution
# 93862  1949565   United States  Regex_institution
# 93878  1949753   United States  Regex_institution
# 93879  1949756   United States  Regex_institution
# 93999  1950729   United States  Regex_institution
# 94024  1950915   United States  Regex_institution
# 94025  1950932   United States  Regex_institution
# 94042  1951174   United States  Regex_institution
# 94049  1951181   United States  Regex_institution
# 94063  1951269   United States  Regex_institution
# 94148  1951900   United States  Regex_institution
# 94166  1951989   United States  Regex_institution
# 94188  1952586    South Africa  Regex_institution
# 94191  1952643   United States  Regex_institution
# 94195  1952667   United States  Regex_institution
# 94196  1952669   United States  Regex_institution
# 94211  1952823   United States  Regex_institution
# 94220  1952960           Japan  Regex_institution
# 94225  1952965           Japan  Regex_institution
# 94227  1952969   United States  Regex_institution
# 94228  1952970   United States  Regex_institution
# 94235  1952982   United States  Regex_institution
# 94254  1953093   United States  Regex_institution
# 94273  1953220   United States  Regex_institution
# 94306  1953656  United Kingdom  Regex_institution
# 94307  1953710   United States  Regex_institution
# 94360  1954338   United States  Regex_institution
# 94362  1954343   United States  Regex_institution
# 94374  1954376   United States  Regex_institution
# 94384  1954456           Ghana  Regex_institution
# 94417  1954826   United States  Regex_institution
# 94430  1954924   United States  Regex_institution
# 94460  1955181   United States  Regex_institution
# 94466  1955187   United States  Regex_institution
# 94483  1955248   United States  Regex_institution
# 94494  1955374           Japan  Regex_institution
# 94541  1955781           Japan  Regex_institution
# 94543  1955783           Japan  Regex_institution
# 94544  1955784           Japan  Regex_institution
# 94545  1955785           Japan  Regex_institution
# 94547  1955789           Japan  Regex_institution
# 94562  1955962   United States  Regex_institution
# 94566  1956010   United States  Regex_institution
# 94583  1956133           Japan  Regex_institution
# 94676  1957166   United States  Regex_institution
# 94726  1957731           Japan  Regex_institution
# 94734  1957740           Japan  Regex_institution
# 94736  1957778   United States  Regex_institution
# 94742  1957838   United States  Regex_institution
# 94750  1957862   United States  Regex_institution
# 94782  1958263   United States  Regex_institution
# 94784  1958290   United States  Regex_institution
# 94827  1958509   United States  Regex_institution
# 94853  1958632           Japan  Regex_institution
# 94859  1958709   United States  Regex_institution
# 94877  1958848   United States  Regex_institution
# 94964  1959712   United States  Regex_institution
# 94982  1959788   United States  Regex_institution
# 94992  1959820   United States  Regex_institution
# 95033  1960151           India  Regex_institution
# 95113  1960753   United States  Regex_institution
# 95130  1960859           Japan  Regex_institution
# 95152  1961008   United States  Regex_institution
# 95164  1961021   United States  Regex_institution
# 95214  1961192           Japan  Regex_institution
# 95215  1961194           Japan  Regex_institution
# 95302  1962250   United States  Regex_institution
# 95343  1962588   United States  Regex_institution
# 95368  1962743   United States  Regex_institution
# 95398  1962829           Japan  Regex_institution
# 95404  1962872   United States  Regex_institution
# 95426  1963031           Japan  Regex_institution
# 95428  1963052           Japan  Regex_institution
# 95446  1963176   United States  Regex_institution
# 95549  1963757           Japan  Regex_institution
# 95583  1963910           Japan  Regex_institution
# 95630  1964186           Japan  Regex_institution
# 95633  1964199   United States  Regex_institution
# 95660  1964358   United States  Regex_institution
# 95730  1964678    South Africa  Regex_institution
# 95790  1964962   United States  Regex_institution
# 95802  1965025           Japan  Regex_institution
# 95803  1965032   United States  Regex_institution
# 95828  1965155   United States  Regex_institution
# 95831  1965176   United States  Regex_institution
# 95841  1965228           Japan  Regex_institution
# 95849  1965292   United States  Regex_institution
# 95892  1965494         Nigeria  Regex_institution
# 95965  1965805         Croatia  Regex_institution
# 96049  1966267    South Africa  Regex_institution
# 96085  1966364         Germany  Regex_institution
# 96186  1966888  United Kingdom  Regex_institution
# 96226  1967063   United States  Regex_institution
# 96238  1967148   United States  Regex_institution
# 96242  1967159   United States  Regex_institution
# 96254  1967224   United States  Regex_institution
# 96269  1967287   United States  Regex_institution
# 96337  1967653   United States  Regex_institution
# 96363  1967929   United States  Regex_institution
# 96376  1967982   United States  Regex_institution
# 96390  1968054   United States  Regex_institution
# 96424  1968230   United States  Regex_institution
# 96428  1968253   United States  Regex_institution
# 96457  1968493   United States  Regex_institution
# 96475  1968621   United States  Regex_institution
# 96477  1968626   United States  Regex_institution
# 96484  1968709   United States  Regex_institution
# 96558  1969147   United States  Regex_institution
# 96590  1969325   United States  Regex_institution
# 96607  1969451   United States  Regex_institution
# 96641  1969730   United States  Regex_institution
# 96698  1970113           Japan  Regex_institution
# 96700  1970151   United States  Regex_institution
# 96759  1970714   United States  Regex_institution
# 96799  1971145   United States  Regex_institution
# 96814  1971266   United States  Regex_institution
# 96839  1971559   United States  Regex_institution
# 96853  1971752   United States  Regex_institution
# 96901  1972161   United States  Regex_institution
# 96930  1972414           Japan  Regex_institution
# 96932  1972418           Japan  Regex_institution
# 96933  1972419           Japan  Regex_institution
# 97005  1972875   United States  Regex_institution
# 97020  1973074   United States  Regex_institution
# 97021  1973084   United States  Regex_institution
# 97048  1973283   United States  Regex_institution
# 97052  1973345           Japan  Regex_institution
# 97053  1973346           Japan  Regex_institution
# 97095  1973695   United States  Regex_institution
# 97134  1973950           Japan  Regex_institution
# 97146  1974168   United States  Regex_institution
# 97302  1975612   United States  Regex_institution
# 97312  1975696   United States  Regex_institution
# 97330  1975822   United States  Regex_institution
# 97347  1975943           Japan  Regex_institution
# 97361  1976040   United States  Regex_institution
# 97368  1976118           Japan  Regex_institution
# 97525  1977308   United States  Regex_institution
# 97582  1977604   United States  Regex_institution
# 97590  1977643        Malaysia  Regex_institution
# 97604  1977729           Japan  Regex_institution
# 97608  1977756   United States  Regex_institution
# 97676  1978381   United States  Regex_institution
# 97690  1978615   United States  Regex_institution
# 97702  1978757   United States  Regex_institution
# 97761  1979168   United States  Regex_institution
# 97806  1979588           Japan  Regex_institution
# 97819  1979714   United States  Regex_institution
# 97940  1980824   United States  Regex_institution
# 97946  1980932           Japan  Regex_institution
# 97947  1980959   United States  Regex_institution
# 97970  1981125           Japan  Regex_institution
# 98020  1981830   United States  Regex_institution
# 98059  1982324           Japan  Regex_institution
# 98068  1982529   United States  Regex_institution
# 98135  1983386   United States  Regex_institution
# 98202  1983720   United States  Regex_institution
# 98225  1983898   United States  Regex_institution
# 98230  1983953   United States  Regex_institution
# 98231  1983959   United States  Regex_institution
# 98246  1984090   United States  Regex_institution
# 98265  1984210   United States  Regex_institution
# 98273  1984293   United States  Regex_institution
# 98285  1984328   United States  Regex_institution
# 98308  1984504   United States  Regex_institution
# 98314  1984518   United States  Regex_institution
# 98319  1984538   United States  Regex_institution
# 98341  1984796   United States  Regex_institution
# 98352  1984830   United States  Regex_institution
# 98379  1984904   United States  Regex_institution
# 98381  1984907   United States  Regex_institution
# 98392  1984936   United States  Regex_institution
# 98416  1985079   United States  Regex_institution
# 98453  1985242   United States  Regex_institution
# 98459  1985295   United States  Regex_institution
# 98473  1985393   United States  Regex_institution
# 98495  1985527   United States  Regex_institution
# 98513  1985610   United States  Regex_institution
# 98520  1985699   United States  Regex_institution
# 98545  1985728   United States  Regex_institution
# 98678  1986290   United States  Regex_institution
# 98684  1986382   United States  Regex_institution
# 98693  1986427   United States  Regex_institution
# 98715  1986625   United States  Regex_institution
# 98721  1986709   United States  Regex_institution
# 98722  1986711   United States  Regex_institution
# 98746  1986858   United States  Regex_institution
# 98752  1986917   United States  Regex_institution
# 98765  1987187   United States  Regex_institution
# 98770  1987196   United States  Regex_institution
# 98843  1987739   United States  Regex_institution
# 98852  1987750   United States  Regex_institution
# 98880  1987901           Japan  Regex_institution
# 98933  1988112   United States  Regex_institution
# 98934  1988113   United States  Regex_institution
# 98955  1988134   United States  Regex_institution
# 98964  1988143   United States  Regex_institution
# 98977  1988180   United States  Regex_institution
# 98981  1988209   United States  Regex_institution
# 99016  1988454   United States  Regex_institution
# 99030  1988572   United States  Regex_institution
# 99072  1988703   United States  Regex_institution
# 99074  1988705   United States  Regex_institution
# 99092  1988765   United States  Regex_institution
# 99108  1988901    South Africa  Regex_institution
# 99123  1989118   United States  Regex_institution
# 99133  1989336   United States  Regex_institution
# 99139  1989434   United States  Regex_institution
# 99190  1989664   United States  Regex_institution
# 99200  1989785   United States  Regex_institution
# 99215  1989911   United States  Regex_institution
# 99220  1989916   United States  Regex_institution
# 99250  1990092          Serbia  Regex_institution
# 99269  1990261   United States  Regex_institution
# 99283  1990455   United States  Regex_institution
# 99296  1990623   United States  Regex_institution
# 99306  1990835   United States  Regex_institution
# 99322  1991024   United States  Regex_institution
# 99337  1991175   United States  Regex_institution
# 99382  1991287   United States  Regex_institution
# 99389  1991294   United States  Regex_institution
# 99394  1991299   United States  Regex_institution
# 99444  1991683   United States  Regex_institution
# 99451  1991690   United States  Regex_institution
# 99453  1991693   United States  Regex_institution
# 99454  1991694   United States  Regex_institution
# 99459  1991702   United States  Regex_institution
# 99460  1991703   United States  Regex_institution
# 99473  1991846   United States  Regex_institution
# 99482  1991961   United States  Regex_institution
# 99529  1992219   United States  Regex_institution
# 99536  1992260   United States  Regex_institution
# 99537  1992261   United States  Regex_institution
# 99547  1992376   United States  Regex_institution
# 99599  1992544   United States  Regex_institution
# 99606  1992568   United States  Regex_institution
# 99611  1992573   United States  Regex_institution
# 99617  1992580   United States  Regex_institution
# 99631  1992606   United States  Regex_institution
# 99636  1992613   United States  Regex_institution
# 99646  1992704   United States  Regex_institution
# 99665  1992903   United States  Regex_institution
# 99669  1992909           Japan  Regex_institution
# 99671  1992911           Japan  Regex_institution
# 99673  1992913           Japan  Regex_institution
# 99678  1992919           Japan  Regex_institution
# 99689  1992936   United States  Regex_institution
# 99697  1992974   United States  Regex_institution
# 99706  1992986   United States  Regex_institution
# 99761  1993312    South Africa  Regex_institution
# 99816  1993623   United States  Regex_institution
# 99821  1993628   United States  Regex_institution
# 99822  1993629   United States  Regex_institution
# 99824  1993631   United States  Regex_institution
# 99826  1993634   United States  Regex_institution
# 99882  1994071   United States  Regex_institution
# 99904  1994319   United States  Regex_institution
# 99920  1994411   United States  Regex_institution
# 99924  1994421   United States  Regex_institution
# 99959  1994620   United States  Regex_institution
# 99980  1994701   United States  Regex_institution
# 99985  1994751   United States  Regex_institution

# %%
df_parsedX_100000.loc[df_parsedX_100000["PMID"] == 1983859, "Country"]
# Out:
# 98214    United States
# Name: Country, dtype: object

# %%
df_parsedX_100000.columns.to_list()
# Out:
# ['Type',
#  'PMID',
#  'DOI',
#  'Journal',
#  'Title',
#  'Abstract',
#  'Authors',
#  'MeshHeadings',
#  'Chemicals',
#  'PublicationTypes',
#  'PublicationDate',
#  'Language',
#  'Keywords',
#  'NER_lastAuthor',
#  'Country',
#  'Country_source',
#  'Cancer',
#  'Species',
#  'Undetermined_Cancer',
#  'Acute lymphoblastic leukemia',
#  'Acute myeloid leukemia',
#  'Adenocarcinoma of the colon',
#  'Adenocarcinoma of the pancreas',
#  'Adenocarcinoma',
#  'Adenoid cystic carcinoma',
#  'Adrenocortical carcinoma',
#  'Alveolar soft part sarcoma',
#  'Ampullary cancer',
#  'Ampullary carcinoma',
#  'Anal cancer',
#  'Anaplastic thyroid cancer',
#  'Angiosarcoma',
#  'Astrocytoma',
#  'Atypical chronic myeloid leukemia',
#  'Basal cell carcinoma',
#  'Bladder cancer',
#  'Bone cancer',
#  'Brain cancer',
#  'Breast cancer',
#  'Cervical cancer',
#  'Cholangiocarcinoma',
#  'Chondrosarcoma',
#  'Chordoma',
#  'Chronic lymphocytic leukemia',
#  'Chronic myeloid leukemia',
#  'Chronic neutrophilic leukemia',
#  'Clear cell carcinoma',
#  'Colon cancer',
#  'Colorectal cancer',
#  'Cutaneous mastocytosis',
#  'Desmoplastic small round cell tumor',
#  'Diffuse large B-cell lymphoma',
#  'Ductal carcinoma',
#  'Duodenal cancer',
#  'Endometrial cancer',
#  'Endometrial stromal sarcoma',
#  'Ependymoma',
#  'Epithelioid sarcoma',
#  'Esophageal cancer',
#  'Essential thrombocythemia',
#  'Ewing sarcoma',
#  'Extraskeletal chondrosarcoma',
#  'Extraskeletal myxoid chondrosarcoma',
#  'Extraskeletal osteosarcoma',
#  'Eye cancer',
#  'Fallopian tube cancer',
#  'Fibrolamellar carcinoma',
#  'Fibrosarcoma',
#  'Follicular lymphoma',
#  'Follicular thyroid cancer',
#  'Gallbladder cancer',
#  'Gastric adenocarcinoma',
#  'Gastrointestinal stromal tumor',
#  'Giant cell tumor of bone',
#  'Glioblastoma',
#  'Granulosa cell tumor',
#  'Hairy cell leukemia',
#  'Head and neck cancer',
#  'Hepatocellular carcinoma',
#  'Hodgkin lymphoma',
#  'Kaposi sarcoma',
#  'Kidney cancer',
#  'Laryngeal cancer',
#  'Leiomyoma',
#  'Leiomyosarcoma',
#  'Leukemia',
#  'Liposarcoma',
#  'Liver cancer',
#  'Lobular carcinoma',
#  'Lung cancer',
#  'Lymphoma',
#  'Malignant fibrous histiocytoma',
#  'Malignant mesenchymoma',
#  'Malignant peripheral nerve sheath tumor',
#  'Mantle cell lymphoma',
#  'Mast cell leukemia',
#  'Medullary thyroid cancer',
#  'Medulloblastoma',
#  'Melanoma',
#  'Meningioma',
#  'Merkel cell carcinoma',
#  'Mesothelioma',
#  'Mouth cancer',
#  'Mucinous adenocarcinoma',
#  'Mucinous carcinoma',
#  'Mucosa-associated lymphoid tissue lymphoma',
#  'Multiple myeloma',
#  'Myelodysplastic syndromes',
#  'Nasal cancer',
#  'Neuroblastoma',
#  'Neuroendocrine tumor',
#  'Neurofibroma',
#  'Non-Hodgkin lymphoma',
#  'Non-small cell lung cancer',
#  'Oligodendroglioma',
#  'Osteoblastoma',
#  'Osteochondroma',
#  'Osteosarcoma',
#  'Ovarian cancer',
#  'Pancreatic cancer',
#  'Papillary thyroid cancer',
#  'Parathyroid carcinoma',
#  'Penile cancer',
#  'Periosteal osteosarcoma',
#  'Peripheral T-cell lymphoma',
#  'Peritoneal cancer',
#  'Pleomorphic sarcoma',
#  'Polycythemia vera',
#  'Primary central nervous system lymphoma',
#  'Primary myelofibrosis',
#  'Primitive neuroectodermal tumor',
#  'Prostate cancer',
#  'Rectal cancer',
#  'Renal cell carcinoma',
#  'Rhabdomyosarcoma',
#  'Salivary gland cancer',
#  'Sarcoma',
#  'Schwannoma',
#  'Sebaceous carcinoma',
#  'Sebaceous gland carcinoma',
#  'Sertoli-Leydig cell tumor',
#  'Skin cancer',
#  'Small cell lung cancer',
#  'Solitary fibrous tumor',
#  'Squamous cell carcinoma of the skin',
#  'Squamous cell carcinoma',
#  'Stomach cancer',
#  'Synovial sarcoma',
#  'Systemic mastocytosis',
#  'Testicular cancer',
#  'Throat cancer',
#  'Thymic carcinoma',
#  'Thymoma',
#  'Thyroid cancer',
#  'Transitional cell carcinoma',
#  'Urothelial carcinoma',
#  'Uterine cancer',
#  'Vaginal cancer',
#  'Vulvar cancer',
#  'Wilms tumor',
#  'hemangiosarcoma',
#  'Undetermined_Species',
#  'Chimpanzee',
#  'D. melanogaster',
#  'Drosophila',
#  'Homo sapiens',
#  'M. musculus',
#  'Macaca fascicularis',
#  'Macaca mulatta',
#  'Mesocricetus auratus',
#  'Oryzias latipes',
#  'Pan troglodytes',
#  'Rattus norvegicus',
#  'Rhesus macaque',
#  'Rhesus monkey',
#  'Syrian hamster',
#  'fruit fly',
#  'guinea pig',
#  'human',
#  'macaque',
#  'medaka',
#  'mice',
#  'monkey',
#  'mouse',
#  'patient',
#  'primate',
#  'rabbit',
#  'rat',
#  'zebrafish']
